# %% [markdown]
# ### Final Project Requirements/notes: https://docs.google.com/document/d/1mwYbYJHkB7kpx4tNflKh54jN9_oOscw3p4k5fsmn3bc/edit

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# look into contains in pandas, and pandas mask

# %% [markdown]
# ### Link with all Data: https://www.sec.gov/dera/data/financial-statement-and-notes-data-set.html
# - using NUM file only for now (data set of all numeric XBRL facts presented on the primary financial statements)

# %%
import pandas as pd
quarter_numbers = pd.read_table('2012q1_notes/num.tsv', encoding ='latin1')
quarter_numbers = quarter_numbers.drop(columns=['footnote','coreg'])
quarter_numbers = quarter_numbers.dropna()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
quarter_numbers.head()
# Out:
#                     adsh                                     tag  \
# 8   0001376231-12-000002      RetainedEarningsAccumulatedDeficit
# 9   0001376231-12-000002      RetainedEarningsAccumulatedDeficit
# 13  0001193125-12-080059            DueFromRelatedPartiesCurrent
# 14  0001193125-12-080059            DueFromRelatedPartiesCurrent
# 15  0001193125-12-080059  IncreaseDecreaseInOtherAccountsPayable
#
#          version     ddate  qtrs  uom        dimh  iprx       value  footlen  \
# 8   us-gaap/2011  20101231     0  USD  0x00000000   0.0   -107439.0        0
# 9   us-gaap/2011  20111231     0  USD  0x00000000   0.0   -112835.0        0
# 13  us-gaap/2011  20111231     0  USD  0x00000000   0.0   5903000.0        0
# 14  us-gaap/2011  20101231     0  USD  0x00000000   0.0   4921000.0        0
# 15  us-gaap/2011  20111231     4  USD  0x00000000   0.0  14577000.0        0
#
#     dimn      durp  datp  dcml
# 8      0  0.000000   0.0   0.0
# 9      0  0.000000   0.0   0.0
# 13     0  0.000000   0.0  -3.0
# 14     0  0.000000   0.0  -3.0
# 15     0  0.010959   0.0  -3.0

# %%
quarter_numbers.qtrs.unique()
# Out:
# array([   0,    4,    1,   30,    2,   22,    3,   32,   20,    7,   12,
#          25,   24,  129,  100,   44,   54,   71,   43,   14,   16,   40,
#          18,   26,   17,   27,   41,   61,   11,   37,   19,   91,   28,
#         126,  114,   15,   23,   10,   13,   36,   42,   53,  211,    8,
#           6,   31,   38,   21,   51,   96,   57,   83,   29,   49,  103,
#          45,   50,  138,   48,   80,   34,   33,   65,   39,   69,   62,
#           5,   52,   64,   35,   77,   46,   90,    9,   63,  105,   82,
#          94,   60,   55,   47,   66,   98,  104,   72,   56,   58,   84,
#          87,   70,  110,   78,  340,   73,   59,  134,   88,  179,   81,
#          86,  106,   92, 1201,  128])

# %%
fraud_example = quarter_numbers.loc[quarter_numbers['adsh'] == '0001193125-12-117573']
fraud_example = fraud_example.loc[fraud_example['ddate'] == 20111231]
fraud_example.head()
# Out:
#                        adsh  \
# 23217  0001193125-12-117573
# 23219  0001193125-12-117573
# 23222  0001193125-12-117573
# 89081  0001193125-12-117573
# 89084  0001193125-12-117573
#
#                                                      tag       version  \
# 23217                          CostOfServicesDirectLabor  us-gaap/2011
# 23219                                           Goodwill  us-gaap/2011
# 23222   IncreaseDecreaseInWorkersCompensationLiabilities  us-gaap/2011
# 89081             SellingGeneralAndAdministrativeExpense  us-gaap/2011
# 89084  StockIssuedDuringPeriodValueShareBasedCompensa...  us-gaap/2011
#
#           ddate  qtrs  uom        dimh  iprx       value  footlen  dimn  \
# 23217  20111231     4  USD  0x00000000   0.0  94568000.0        0     0
# 23219  20111231     0  USD  0x00000000   0.0  47820000.0        0     0
# 23222  20111231     4  USD  0x00000000   0.0  12839000.0        0     0
# 89081  20111231     4  USD  0x00000000   0.0  38174000.0        0     0
# 89084  20111231     4  USD  0x00000000   0.0    473000.0        0     0
#
#            durp  datp  dcml
# 23217  0.010959   0.0  -3.0
# 23219  0.000000   0.0  -3.0
# 23222  0.010959   0.0  -3.0
# 89081  0.010959   0.0  -3.0
# 89084  0.010959   0.0  -3.0

# %% [markdown]
# # 1. Extract just the 2011 Data

# %%
nums_2011 = quarter_numbers.loc[quarter_numbers['ddate'] == 20111231]
nums_2011 = nums_2011.loc[nums_2011['uom'] == 'USD'] #limit for just those that have USD
# nums_2011 = nums_2011.loc[nums_2011['qtrs'] == 4] 
nums_2011.columns
# Out:
# Index(['adsh', 'tag', 'version', 'ddate', 'qtrs', 'uom', 'dimh', 'iprx',
#        'value', 'footlen', 'dimn', 'durp', 'datp', 'dcml'],
#       dtype='object')

# %%
nums_2011 = nums_2011[['adsh', 'tag','value']] #just retain these columns for manipulation
nums_2011.head()
# Out:
#                     adsh                                                tag  \
# 15  0001193125-12-080059             IncreaseDecreaseInOtherAccountsPayable
# 20  0001193125-12-080059  OtherComprehensiveIncomeDerivativesQualifyingA...
# 21  0001193125-12-080059  NetCashProvidedByUsedInFinancingActivitiesCont...
# 24  0001193125-12-080059                       ProceedsFromIncomeTaxRefunds
# 29  0001193125-12-080059                  LoansToParentReclassifiedToEquity
#
#          value
# 15  14577000.0
# 20   -519000.0
# 21 -40009000.0
# 24         0.0
# 29         0.0

# %%
len(nums_2011) #length of df
# Out:
# 580962

# %%
import numpy as np
tags = sorted(nums_2011.tag.unique().tolist())
len(tags)
# Out:
# 55515

# %% [markdown]
# # 2. Lowercase all values in tag column

# %%
nums_2011['tag'] = nums_2011['tag'].str.lower()

# %%
len(test.adsh.unique()) #number of initial unique 'tag' values
# Out:
# 4601

# %% [markdown]
# # 3. Rename tags based on current tag containing words (separated by | )

# %%
expenses = "accretion|expense|401k|expenses|interestpaid|transportation|utilities|rent|wages|costs|fee|fees|legal|accounting|accident"

nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains(expenses)].index, 'tag', 'Expenses')
tags = sorted(nums_2011.tag.unique().tolist())
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("allowance|receivables|receivable|accountsreceivable|interestreceivable|accountreceivable|accountsandnotesreceivable|writeoff|writtenoff")].
                                index, 'tag', 'AccountsReceivable')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("accountspayable|accountpayable")].
                                index, 'tag', 'AccountsPayable')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("interestpayable")].
                                index, 'tag', 'InterestPayable')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("abandon")].
                                index, 'tag', 'AbandonedCosts')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("depreciation|depreciated")].
                                index, 'tag', 'Depreciation')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("amortization")].
                                index, 'tag', 'Amortization')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("equity")].
                                index, 'tag', 'Equity')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("revenue")].
                                index, 'tag', 'Revenue')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("gain|gains")].
                                index, 'tag', 'Gains')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("prepaidexpenses")].
                                index, 'tag', 'PrepaidExpenses')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("losses")].
                                index, 'tag', 'Losses')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("comprehensiveincome")].
                                index, 'tag', 'OtherComprehensiveIncome')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("accuredinterest|accruedinterest|notepayable|notespayable")].
                                index, 'tag', 'ShortTermLiabilities')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("otherliabilit|losscontingenc|accrualforlosscontingenc|accrualfor|accrued")].
                                index, 'tag', 'Liabilities')
nums_2011 = nums_2011.set_value(nums_2011.loc[nums_2011['tag'].str.contains("taxbenefit|cash|proceeds|increaselineofcredit|corporatebonds")].
                                index, 'tag', 'Asset')

# %%
tags = sorted(nums_2011.tag.unique().tolist())
print(len(tags))
tags[20:10000]
# Out:
# 26475
# ['accelerateddeferredloss',
#  'acceleratedpaymentsofdealerholdback',
#  'acceleratedsharerepurchaseprogramadjustment',
#  'acceleratedsharerepurchasesfinalpricepaidpershare',
#  'acceleratedsharerepurchasesinitialpricepaidpershare',
#  'accelerationofociamountsreclassifiedtoincome',
#  'accelerationofociamountsreclassifiedtoincomethatrelatedtopreviouslyterminatedhedges',
#  'accelerationofvestingofrestrictedstock',
#  'accountpresentationservices',
#  'accrectiononpreferredstock',
#  'accretablebalanceofstructuredinvestmentsecuritiesdisposals',
#  'accretablebalanceofstructuredinvestmentsecuritiesother',
#  'accretablediscountrelatedtoacquisition',
#  'accretedinterestonzerocouponsubordinatednotes',
#  'accreteofpreferredunitstoredemption',
#  'accrualassociatedwithconstructionandcapitalexpenditures',
#  'accrualassociatedwithconstructioncapitalexpendituresandretainage',
#  'accrualestimatechangeintaxstepupbasis',
#  'accrualofacquisitionrelatedliabilities',
#  'accrualofassetretirementobligation',
#  'accrualofcovenantnottocompete',
#  'accrualofderivativeliability',
#  'accrualofdistributionspayabletocommonunitholders',
#  'accrualofdividendonseriesbpreferredstock',
#  'accrualofdividendsanddistributions',
#  'accrualofdividendspayable',
#  'accrualofemployeestockownershipplan',
#  'accrualofgoodwillandrelatedliability',
#  'accrualofinterestonoldpiknotes',
#  'accrualofissuancecostofredeemableseriesdconvertiblepreferredstocks',
#  'accrualofpaymentofworkingcapitaladjustmenttosellers',
#  'accrualofpotentialsettlementrelatedtomortgageactivities',
#  'accrualofpreferredstockdividend',
#  'accrualofretentionobligation',
#  'accrualrelatedtomaritimeandnonmaritimecasesgross',
#  'accrualrelatedtomaritimeandnonmaritimecasesnet',
#  'accrualsexpirationsforwarrantiesissuedexpiredduringperiod',
#  'accrualsforshareswithheldfortaxes',
#  'accumulatedbutundeclareddividendrequirementonpreferredstockissuedtoprincipalstockholdersfamily',
#  'accumulatedcomprehensiveloss',
#  'accumulateddividendonpreferredstockvalue',
#  'accumulatedearningsofforeignsubsidiarieswithholdingtaxesnotprovidedon',
#  'accumulatedforeignearnings',
#  'accumulatedforeignearningsconsideredpermanentlyreinvested',
#  'accumulatedimpairmentdisposition',
#  'accumulatedimpairmentsrelatedtoforeigncurrencytranslationandother',
#  'accumulatedndrreservereflectedasotherregulatoryliabilitiesdeferred',
#  'accumulatedothercomprehensiveearningsunfundedpostretirementbenefitobligation',
#  'accumulatedothercomprehensiveloss',
#  'accumulatedothercomprehensivelossbeginningbalance',
#  'accumulatedothercomprehensivelossendingbalance',
#  'accumulatedothercomprehensivelossnetoftax',
#  'accumulatedotherthantemporaryimpairment',
#  'accumulatedpaymentstoacquireinterestinjointventure',
#  'accumulatedpostretirementbenefitobligationadjustment',
#  'accumulatedpostretirementbenefitobligationforfullyeligibleemployees',
#  'accumulatedpostretirementbenefitobligationforotherparticipants',
#  'accumulatedpostretirementbenefitobligationforretirees',
#  'accumulatedunremittedforeignearnings',
#  'acquiredabovebelowmarketleasesnet',
#  'acquiredadditionalinterestofmajorityownedsubsidiaries',
#  'acquiredbalances',
#  'acquiredcoalreservesremainingcommitmentamount',
#  'acquiredcontracts',
#  'acquiredfinitelivedintangibleassetacquisitionofbusinesses',
#  'acquiredfinitelivedintangibleassetamount1',
#  'acquiredfinitelivedintangibleassetamountduringyear',
#  'acquiredfinitelivedintangibleassetduringperiod',
#  'acquiredfinitelivedintangibleassetsamount',
#  'acquiredfinitelivedintangibleassetweightedaverageusefullife',
#  'acquiredinprocessresearchanddevelopment',
#  'acquiredinprocessresearchanddevelopmentnetoftax',
#  'acquiredinprocessresearchanddevelopmentnotpaidinperiod',
#  'acquiredintangibleassetamount',
#  'acquiredintangibleassettotalamount',
#  'acquiredjointventureoperatingincome',
#  'acquirednoncontrollinginterest',
#  'acquiredpropertyplantandequipment',
#  'acquiredtaxpositions',
#  'acquiredthroughbusinesscombinations',
#  'acquirenoncontrollinginterestsinamericanindependencecorp',
#  'acquirenoncontrollinginterestsinwisconsinunderwritingassociates',
#  'acquisitionamountperagreement',
#  'acquisitionanddevelopmentofoilandgasproperties',
#  'acquisitionanddevelopmentofoilandgasthroughassetretirementobligations',
#  'acquisitionandintegrationrelatedchargesnetofincometaxes',
#  'acquisitionandrestructuring',
#  'acquisitionandretirementofconvertibleseniordebenturesandseniorunsecurednotes',
#  'acquisitionandsurrenderofcommonshares',
#  'acquisitionbyesopofarrowstock',
#  'acquisitionconsiderationpayable',
#  'acquisitioncostbutnotyetpaid',
#  'acquisitioncostinconsolidatinginvestments',
#  'acquisitioncostintangibles',
#  'acquisitioncostofacquiredentitiesandinterestinaffiliates',
#  'acquisitioncostrealestatefacilities',
#  'acquisitiondatefairvalueofredeemablenoncontrollinginterestinjointventure',
#  'acquisitiondeposit',
#  'acquisitiondepositsappliedtorealestateacquisitions',
#  'acquisitionintangibleassetotherthangoodwill',
#  'acquisitionintegrationaftertaxcharges',
#  'acquisitionintegrationchargespercommonshare',
#  'acquisitionliabilitiesincurredbutnotyetpaid',
#  'acquisitionloans',
#  'acquisitionnoncontrollinginterestspartiallyownedproperties',
#  'acquisitionnoterelated',
#  'acquisitionobligations',
#  'acquisitionofadditionalbusinessinterest',
#  'acquisitionofassetheldforsale',
#  'acquisitionofassets',
#  'acquisitionofassetsforcommonshares',
#  'acquisitionofassetsincludedinpayables',
#  'acquisitionofassetsinexchangeforissuanceofnoncontrollinginterestshares',
#  'acquisitionofassetsthroughassumptionofdebtandpropertypurchasedwithfinancing',
#  'acquisitionofassetsundercommoncontrol',
#  'acquisitionofbusinesscontingentconsideration',
#  'acquisitionofcafe',
#  'acquisitionofcommoncontrolsubsidiary',
#  'acquisitionofcommonstockbyemployeestockownershipplan',
#  'acquisitionofcommonstockfortaxwithholdingobligationundertwothousandfivecontingentstockplan',
#  'acquisitionofcompany',
#  'acquisitionofentity',
#  'acquisitionofequipment',
#  'acquisitionofequipmentwithcapitalleasefinancing',
#  'acquisitionoffurniturefixtureandequipmentinterestinunconsolidatedjointventures',
#  'acquisitionofhdi',
#  'acquisitionofintangibleassets',
#  'acquisitionofintangibleassetsandintellectualproperty',
#  'acquisitionofintangibleassetsthroughcontingentconsideration',
#  'acquisitionofinterest',
#  'acquisitionofinterestinunconsolidatedaffiliateassumptionofmortgagedebt',
#  'acquisitionofinterestinunconsolidatedaffiliateinvestmentinunconsolidatedaffiliates',
#  'acquisitionofinterestinunconsolidatedaffiliateotherassetsandliabilities',
#  'acquisitionofinterestinunconsolidatedaffiliaterealestatenet',
#  'acquisitionofinvestments',
#  'acquisitionofleasedpremises',
#  'acquisitionofleaseholdpaidbylandlord',
#  'acquisitionofmanagementagreement',
#  'acquisitionofmhp',
#  'acquisitionofnetassetsinnoncontrollinginterest',
#  'acquisitionofnetworkequipmentundercapitallease',
#  'acquisitionofnewsubsidiaries',
#  'acquisitionofnoncontrollinginterest',
#  'acquisitionofnoncontrollinginterestanddispositionofownershipinterestinsubsidiaries',
#  'acquisitionofnoncontrollinginterestinconsolidatedaffiliate',
#  'acquisitionofnoncontrollinginterests',
#  'acquisitionofnoncontrollinginterestsinshuangshengpaper',
#  'acquisitionofnonperformingloan',
#  'acquisitionofofairholdingscorporation',
#  'acquisitionofoperatingassets',
#  'acquisitionofotherassetsandliabilitiesnetinterestinunconsolidatedjointventures',
#  'acquisitionofotherrealestateownedthroughforeclosure',
#  'acquisitionofotherrepossessedassetsandrealestatethroughforeclosure',
#  'acquisitionofpermanentnoncontrollinginterestsinsubsidiaries',
#  'acquisitionofphs',
#  'acquisitionofplantandequipmentundercapitallease',
#  'acquisitionofpropertyandequipment',
#  'acquisitionofpropertyandequipmentbycapitalleases',
#  'acquisitionofpropertyandequipmentthroughleaseincentives',
#  'acquisitionofpropertyandequipmentundercapitalleases',
#  'acquisitionofpropertyplantandequipment',
#  'acquisitionofpropertyplantandequipmentandintangibles',
#  'acquisitionofpropertyplantandequipmentincludedinpayables',
#  'acquisitionofpropertywithcapitalleaseobligation',
#  'acquisitionofprudentrx',
#  'acquisitionofrapidnetofearnout',
#  'acquisitionofrealestateassetsnetofliabilitiesassumedandinitialcapitalexpenditures',
#  'acquisitionofrealestateinvestments',
#  'acquisitionofrealestatethroughexchangetransaction',
#  'acquisitionofremaininginterest',
#  'acquisitionofremainingportionofnoncontrollinginteresttax',
#  'acquisitionofresidualportfolios',
#  'acquisitionofrestrictedsecuritiesandotherinvestments',
#  'acquisitionofsoftwarelicensesunderlongtermpaymentcontracts',
#  'acquisitionofstockbybenefitplans',
#  'acquisitionofstockforstockbenefitplans',
#  'acquisitionofsubsidiary',
#  'acquisitionofsupplyrequirements',
#  'acquisitionoftangibleassetsthroughrestructureofloan',
#  'acquisitionoftelevisionstationandrelatedequipment',
#  'acquisitionoftreasurystock',
#  'acquisitionoftreasurystockforoptionsexercised',
#  'acquisitionoftreasurystockunderemployeestockplans',
#  'acquisitionofunconsolidatedaffiliate',
#  'acquisitionofunitedrotorcraftsolutions',
#  'acquisitionofutilitypropertyvermontmarbleandreadsboro',
#  'acquisitionrelatedactivity',
#  'acquisitionrelatedandothercharges',
#  'acquisitionrelatedcompensationcharges',
#  'acquisitionrelatedcontingentconsiderationpaidtoshareholders',
#  'acquisitionrelatedcontingentconsiderationperiodincreasegoodwill',
#  'acquisitionrelatedliabilitiesadjustment',
#  'acquisitionrelatedpayments',
#  'acquisitionrelatedprepaidcontingentcompensation',
#  'acquisitionrelatedrestructuringcharges',
#  'acquisitionsadditionalpaidincapital',
#  'acquisitionsanddisposalsofinvestments',
#  'acquisitionsanddivestiturestononcontrollinginterest',
#  'acquisitionsandinvestmentsprincipallybeverageandbottlingcompaniesandtrademarks',
#  'acquisitionsandother',
#  'acquisitionsandotherinvestingactivities',
#  'acquisitionsandtransfersfromjointventures',
#  'acquisitionscommonstockissued',
#  'acquisitionscontingentconsiderations',
#  'acquisitionsdebtandliabilitiesissuedorassumednetofdebtdiscount',
#  'acquisitionsdispositionsofbusinessesnet',
#  'acquisitionsgoodwillacquired',
#  'acquisitionsintangibleassetsacquired',
#  'acquisitionslongtermdebtissued',
#  'acquisitionsofandinvestmentsinjointventures',
#  'acquisitionsofassetsandbusinesscombinationstotal',
#  'acquisitionsofnoncontrollinginterests',
#  'acquisitionsofpatentassets',
#  'acquisitionspropertyandequipmentacquired',
#  'acquisitionsrelatedearnoutpayments',
#  'acquisitionsurrenderofadditionalunitsofconsolidatedsubsidiarynet',
#  'acquisitionvalueofacquiredtechnology',
#  'acquisitionvessels',
#  'acquisitonpricepershare',
#  'acquistionofproductlicensecontractpayable',
#  'acreagereimbursements',
#  'activityrelatedtononvestedsharesvalue',
#  'activityunderotherstockplansvalue',
#  'activityunderstockplans',
#  'actualbenefitspaidotherpayments',
#  'actualbenefitspaidsettlementpayments',
#  'actualcapitalexpendituresandothercapitaladditionsincludingcapitalizedinterest',
#  'actualdamagescoveredbysepcossupersedeasbond',
#  'actualinvestmentstaxcreditsrecorded',
#  'actualpaymentsforpurchasesrelatedtoactivepharmaceuticalingredients',
#  'actualpurchasedpowercostrecoveryfromapprovedsettlement',
#  'actualreturnassetssoldduringperiod',
#  'actualreturnonassetsstillheld',
#  'actualrunoffofguaranteedinvestmentcontractsliabilities',
#  'actualrunoffofsinglepremiumannuities',
#  'actualsalescreditspriorperiod',
#  'actualsalesreturns',
#  'actuarialchangesinbenefitobligationdeferredtaxes',
#  'actuariallossandother',
#  'actuariallossdueprimarilytolossrelatedtochangeindiscountrate',
#  'addbackincometaxesapplicabletosegmentprofitability',
#  'additionalaggregateprincipalamount',
#  'additionalamountbywhichcreditfacilitycanbeincreased',
#  'additionalamountcommittedtoinvestincapitalexpendituresandimprovements',
#  'additionalamountondistributionoftariffscollected',
#  'additionalamountpaidforcreditdefaultswapsterminatedduringperiod',
#  'additionalamountrelatedtolossindemnificationclaimsforresidentialmortgageloanspreviouslysoldtoinvestors',
#  'additionalamounttobepaidifpricepershareexceedsdeterminedpricefordebtconversion',
#  'additionalamounttosettleworkingcapital',
#  'additionalassetimpairmentcharges',
#  'additionalborrowingcapacityunderrevolvingcreditfacility',
#  'additionalborrowingsinfinancingactivities',
#  'additionalborrowingtermloan',
#  'additionalcapacityofinvestment',
#  'additionalcapitalcontributionbyrelatedparty',
#  'additionalchargesandunallocatedcostofsalesduetochangesinclaimsdataandhistoricalexperience',
#  'additionalcommonunitsacquired',
#  'additionalcompensationcostduetoincreaseinsharepriceprimarilyrelatedtomergeragreement',
#  'additionalconsideration',
#  'additionalconsiderationpaid',
#  'additionalcontingentconsiderationforbusinessacquisition',
#  'additionalcontributiontosinotop',
#  'additionalcontributionwithshareexchange',
#  'additionalcostassociatedwithconditionalmarketingauthorization',
#  'additionalcreditrelatedottiwasnotpreviouslyrecognized',
#  'additionaldamagecoverageforterroristevent',
#  'additionaldamagesincurredforfutureshortfalls',
#  'additionaldebtdiscount',
#  'additionaldilutedundistributedearningsallocatedtoincrementaloptionshares',
#  'additionaldiscretionarycontributionstodefinedcontributionpensionplans',
#  'additionalestimatedcreditimpairmentoncmbsderivatives',
#  'additionalexpectedprojectexpenditureshighestimate',
#  'additionalexpectedprojectexpenditureslowestimate',
#  'additionalexpectedrepatriation',
#  'additionalfixedrateseniorsecurednote',
#  'additionalfundscommittedtoborrowersintroubleddebtrestructuringstatus',
#  'additionalfuturepretaxincomeneededtofullyrealizenetdeferredtaxasset',
#  'additionalincometaxesnetofforeigntaxcreditadjustments',
#  'additionalincreaseinbaseratesforbillsrenderedfromspecifiedperiod',
#  'additionalincrementaltermloan',
#  'additionalinterestcharges',
#  'additionalinterestcreditsauthorizedbyreportingentity',
#  'additionalinvestmentbyholdings',
#  'additionalinvestmentinotherrealestateowned',
#  'additionalinvestmentinvariableinterestentity',
#  'additionalinvestmentrightvalue',
#  'additionalinvestmentsandadvances',
#  'additionalinvestmentstobedonethroughcollaborationfunding',
#  'additionalinvestmenttomodernizesystemandsmartgridtechnology',
#  'additionallettersofcredit',
#  'additionallongtermpurchasecommitmentamountminimum',
#  'additionallumpsumcontributionsemployeesthatvoluntarilyconverttoenhanceddefinedcontributionperyear',
#  'additionalmilestonepayment',
#  'additionalminimumremunerationpaidamount',
#  'additionalnoncontrollinginterest',
#  'additionalpaidincapitalarisingfromearlyextinguishmentofdebt',
#  'additionalpaidincapitalarisingfromredemptionofpreferredstock',
#  'additionalpaidincapitalchangeofownership',
#  'additionalpaidincapitalcontributedcapital',
#  'additionalpaidincapitalfakei',
#  'additionalpaidincapitalfromearlyextinguishmentofdebt',
#  'additionalpaidincapitalinnoncontrollinginterest',
#  'additionalpaidincapitalinnoncontrollinginterestnet',
#  'additionalpaidincapitalotheradjustments',
#  'additionalpaidincapitalpurchaseofclaimsinshares',
#  'additionalpaidincapitalvestingofearlyexercisedstockoptions',
#  'additionalpaymentsforextinguishingdebt',
#  'additionalpaymentsonsecureddebt',
#  'additionalpaymentstorelatedparty',
#  'additionalpaymenttobemadeforacquisitionofsubsequentaircraft',
#  'additionalpaymenttobemadetothirdpartiestoacquiretowers',
#  'additionalpreferenceperpreferencesharebasic',
#  'additionalpreferenceperpreferencesharediluted',
#  'additionalprofitcommissionsoncontracts',
#  'additionalprofitloss',
#  'additionalprovisionforbaddebt',
#  'additionalprovisionsreversals',
#  'additionalpurchaseobligationsinconnectionwithresearchanddevelopmenttorelatedparty',
#  'additionalrightsissuedtooutstandingcommonshares',
#  'additionalseperationdistributionfafc',
#  'additionalsettlementcost',
#  'additionalstockbasedcompensationthatwouldhavebeenrecordedifoperatingincometargetshadbeendeemedprobable',
#  'additioninrestructuredloans',
#  'additionofassetstodenominatorusedincalculatingregulatoryratiosapproximately',
#  'additionsduetoacquisitionsandotheradjustmentsrelatedtoassetretirementobligations',
#  'additionsduringperiodotheracquisitionsimprovementstotal',
#  'additionsfortaxpositionofotheroperations',
#  'additionsfortaxpositionsofprioryearsnet',
#  'additionsoffinitelivedintangibleassetsfromacquisitionsduringyear',
#  'additionsprovisionrelatedtopriorperiodsales',
#  'additionsreductionstononcontrollinginterests',
#  'additionsrelatingtoacquisitiongross',
#  'additionsrelatingtoacquisitionnet',
#  'additionsthroughcontingentliabilities',
#  'additionstoadvanceandsecuritydeposits',
#  'additionstoaroasset',
#  'additionstobankpremisesandequipment',
#  'additionstocapitalexpenditures',
#  'additionstocapitalizedsoftware',
#  'additionstocontractholdersfunds',
#  'additionstodepositliabilitycontracts',
#  'additionstodevelopedpropertiesforretirementobligations',
#  'additionstoestimatedacquisitionearnoutpayables',
#  'additionstofundsrestrictedforconstructionactivity',
#  'additionstoimpairedloans',
#  'additionstoinstruments',
#  'additionstoinventoryreserves',
#  'additionstoleasemerchandise',
#  'additionstoloanservicingportfolioassociatedwithcapitalizedservicingrights',
#  'additionstoloansheldforsale',
#  'additionstolonglivedassetscorporate',
#  'additionstolonglivedassetsunallocated',
#  'additionstomineralproperties',
#  'additionstomortgageloansbasedonperformance',
#  'additionstomsrs',
#  'additionstonaturalgasandoilproperties',
#  'additionstononperformingassets',
#  'additionstooilandgasproperties',
#  'additionstooilandnaturalgaspropertiesgatheringsystemsandequipmentandpropertyacquisitions',
#  'additionstootherassetsamount',
#  'additionstoportfoliotermfinancings',
#  'additionstopredevelopment',
#  'additionstopremisesandequipmentnet',
#  'additionstopropertyplantandequipmentundercapitalleasearrangement',
#  'additionstoredeemablecommonstock',
#  'additionstorestrictedassets',
#  'additionstoselfinsurancereserves',
#  'additionstostreamingcontentlibrary',
#  'additionstovesselcost',
#  'additionstovineyarddevelopment',
#  'additionstransfersfromrigsunderconstruction',
#  'additionstransfersfromvesselsunderconstruction',
#  'additiontoassetretirementobligationandlongtermreclamationliability',
#  'additiontodeferredtaxliability',
#  'additiontofinitelivedintangibleassets',
#  'additiontoindefinitelivedintangibleassets',
#  'additiontointangibleassets',
#  'additiontopropertyplantandequipmentunderconstruction',
#  'additiontoredeemablenoncontrollinginterest',
#  'additurallocationamount',
#  'addotherthantemporaryadjustmentnetoftax',
#  'adjustedaverageassets',
#  'adjustedearningbeforeinterestandtax',
#  'adjustedearningsbeforeincometax',
#  'adjustedebit',
#  'adjustedebitda',
#  'adjustedebitdaattributabletononcontrollinginterest',
#  'adjustedincomefromdiscontinuingoperationsattributabletocontrollinginterests',
#  'adjustedincomelossbeforeincometax',
#  'adjustedincomelossfromcontinuingoperations',
#  'adjustedincomelossfromcontinuingoperationsavailabletocommonshares',
#  'adjustedincomelossfromdiscontinuedoperationsavailabletocommonsharesnetoftax',
#  'adjustedinterestrate',
#  'adjustednetincome',
#  'adjustednetincomeattributabletocontrollinginterestsincomenumerator',
#  'adjustednetincomeloss',
#  'adjustednetincomelossallocatedtononparticipatingcommonshareholdersbasicanddiluted',
#  'adjustednetincomelossavailabletocommonshareholdersdiluted',
#  'adjustednetlossattributabletocommonstockholders',
#  'adjustedoibda',
#  'adjustedpropertyebitda',
#  'adjustedreferencedividendofdebentures',
#  'adjustedroyaltiespayablelicensed',
#  'adjustedroyaltiespayablenonlicensed',
#  'adjustedsegmentebitda',
#  'adjustedsegmentincome',
#  'adjustedtaxableincome',
#  'adjustedtaxableincomesubjecttorealestateinvestmenttrustdividendrequirement',
#  'adjustmentassetimpairmentcharges',
#  'adjustmentassetretirementsandimpairments',
#  'adjustmentassociatedwithclasscommonstockissuableonnoncontingentbasis',
#  'adjustmentassocitedwithtaxmatterrelatedtopreviouslydiscontinuedoperation',
#  'adjustmentemployeecompensation',
#  'adjustmentforacqusitioncost',
#  'adjustmentforactualmedicarepremium',
#  'adjustmentforapplication',
#  'adjustmentforchangesinfairvalue',
#  'adjustmentforcommonunitholdersinoperatingpartnership',
#  'adjustmentfordeferredincometaxes',
#  'adjustmentfordividendsinexcessofcertainamount',
#  'adjustmentforearningsallocatedtononvestedrestrictedcommonstock',
#  'adjustmentforeffectsofforeigncurrencyexchangerate',
#  'adjustmentforitemsincludedinnetincomeaftertax',
#  'adjustmentforitemsincludedinnetincometax',
#  'adjustmentforlimitedpartnersownershipinoperatingpartnership',
#  'adjustmentforlongtermintercompanytransactionsgrossoftax',
#  'adjustmentforlongtermintercompanytransactionsnetoftax',
#  'adjustmentfornoncontrollinginterest',
#  'adjustmentfornoncontrollinginterestinotherconsolidatedpartnerships',
#  'adjustmentforpendingclaimsforunmetrepresentationsandwarranties',
#  'adjustmentforreversemergeroftheshellcompany',
#  'adjustmentforstockdividend',
#  'adjustmentforstockguaranteeagreement',
#  'adjustmentfortaxreturn',
#  'adjustmentgoodwillimpairmentloss',
#  'adjustmentincomelossfromdiscontinuedoperationsnetoftax',
#  'adjustmentofadditionalpaidincapitalandnoncontrollingfromexerciseofoption',
#  'adjustmentofcarryingvalueofforeclosedrealestate',
#  'adjustmentofdeferredtaxliabilityforforeignincometaxratechange',
#  'adjustmentofembeddedderivativeliabilityrelatedtoconvertiblepromissorynotes',
#  'adjustmentoffairvalueofdecommissioningliabilitiescapitalizedcreditedtooilandgasproperties',
#  'adjustmentofnoncontrollinginterestmeasurementamount',
#  'adjustmentofnoncontrollinginterestsfollowingexerciseofoptionsinsubsidiary',
#  'adjustmentofoperatingpartnershipunitstofairvalue',
#  'adjustmentofpropertycarryingvalues',
#  'adjustmentofredeemablecapitalsharestoredemptionvalue',
#  'adjustmentofredeemablecommonunitstofairvalue',
#  'adjustmentofredeemablecommonunitstofairvalueandcontributionsdistributionsfromtogeneralpartner',
#  'adjustmentofredeemablecommonunitstoredemptionvaluenet',
#  'adjustmentofredeemablenoncontrollinginteresttoredemptionvalue',
#  'adjustmentofredeemablepartnershipunitstoliquidationvalueatperiodend',
#  'adjustmentofredeemablesharestoredemptionvalue',
#  'adjustmentofreitdeferredtaxes',
#  'adjustmentofsharebasedawardssubjecttoredemption',
#  'adjustmentofwarrantsgrantedforservices',
#  'adjustmentotheroperatingactivities',
#  'adjustmentpaidtostockplanparticipantspershare',
#  'adjustmentprovisionfordoubtfulaccounts',
#  'adjustmentrelatedtochangeinownershipinsubsidiary',
#  'adjustments',
#  'adjustmentsduetochangesinourseleniumwatertreatmenttechnologyselection',
#  'adjustmentsforassumedchangesinliabilityforpolicyholderbenefitsandclaims',
#  'adjustmentsforbasisdifferencestaxesandintercompanyeliminations',
#  'adjustmentsofpermanentnoncontrollinginterestinsubsidiariestoliquidationvalue',
#  'adjustmentsofprovisionfordoubtfulaccounts',
#  'adjustmentsofstocksandwarrantsissuedforsharebasedcompensationandservices',
#  'adjustmentsoftaxestocompanyfinancials',
#  'adjustmentsrelatedtodeferredtaxliabilities',
#  'adjustmentsrelatedtotaxwithholdingforsharebasedcompensation',
#  'adjustmentssharebasedcompensationrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapital',
#  'adjustmentstoadditionalpaidincapitalacquisitionofnoncontrollinginterest',
#  'adjustmentstoadditionalpaidincapitalacquisitionofnoncontrollinginteresttax',
#  'adjustmentstoadditionalpaidincapitalacquisitions',
#  'adjustmentstoadditionalpaidincapitalaffiliatedassettransfers',
#  'adjustmentstoadditionalpaidincapitalandnoncontrollinginterestssharebasedcompensationrequisiteserviceperiodrecognitionvalue',
#  'adjustmentstoadditionalpaidincapitalandnoncontrollinginterestssharebaseddirectorsharesrenumerationrequisiteserviceperiodrecognitionvalue',
#  'adjustmentstoadditionalpaidincapitalassumptionofrestrictedshareunitsandoptionsuponacquisition',
#  'adjustmentstoadditionalpaidincapitalbeneficialconversionfeatureonpreferredstock',
#  'adjustmentstoadditionalpaidincapitalbenefitforsharebasedcompensationonstockoptionsexpired',
#  'adjustmentstoadditionalpaidincapitalbusinessacquisitionpurchaseprice',
#  'adjustmentstoadditionalpaidincapitalcalloptionsandwarrantnet',
#  'adjustmentstoadditionalpaidincapitalcancellationofoptionsandwarrantsextensions',
#  'adjustmentstoadditionalpaidincapitalcancellationofwarrantsissuedforservices',
#  'adjustmentstoadditionalpaidincapitalcapitalcontribution',
#  'adjustmentstoadditionalpaidincapitalcarryingvaluelessthanredemptionvalueonredeemednoncontrollinginterest',
#  'adjustmentstoadditionalpaidincapitalchangeincarryingamountofredeemablenoncontrollinginterest',
#  'adjustmentstoadditionalpaidincapitalchangeininvestmentofunconsolidatedsubsidiaries',
#  'adjustmentstoadditionalpaidincapitalcommonstockdividends',
#  'adjustmentstoadditionalpaidincapitalcommonstockwarrants',
#  'adjustmentstoadditionalpaidincapitalcontributiontostockbenefitplans',
#  'adjustmentstoadditionalpaidincapitalconversionofconvertibledebt',
#  'adjustmentstoadditionalpaidincapitalconvertibleconversionwarrants',
#  'adjustmentstoadditionalpaidincapitalconvertibledebt',
#  'adjustmentstoadditionalpaidincapitalconvertibledebthedgeandwarrantsnet',
#  'adjustmentstoadditionalpaidincapitalconvertibledebtrepurchase',
#  'adjustmentstoadditionalpaidincapitalconvertibledebtwithconversionfeature',
#  'adjustmentstoadditionalpaidincapitalconvertiblenoteoptionsextinguishment',
#  'adjustmentstoadditionalpaidincapitaldebtdiscountonwarrantsassociatedwithdebt',
#  'adjustmentstoadditionalpaidincapitaldebtissuancenetoftax',
#  'adjustmentstoadditionalpaidincapitaldebtwithdetachablestockpurchasewarrantissued',
#  'adjustmentstoadditionalpaidincapitaldeemeddividenddistribution',
#  'adjustmentstoadditionalpaidincapitaldeemeddividenddistributionrelatedtobusinessacquisition',
#  'adjustmentstoadditionalpaidincapitaldeemeddividends',
#  'adjustmentstoadditionalpaidincapitaldeferredcompensation',
#  'adjustmentstoadditionalpaidincapitaldeferreddirectorscompensation',
#  'adjustmentstoadditionalpaidincapitalderivativeconnectedwithconvertiblesecurities',
#  'adjustmentstoadditionalpaidincapitalderivativeliabilityassociatedwithpreferredstockseriescoffering',
#  'adjustmentstoadditionalpaidincapitaldilutionimpactofshareissuance',
#  'adjustmentstoadditionalpaidincapitaldirectorsdeferredcompensation',
#  'adjustmentstoadditionalpaidincapitaldividendpayableforfeited',
#  'adjustmentstoadditionalpaidincapitaldividendspayableonrestrictedstock',
#  'adjustmentstoadditionalpaidincapitaldividendspreferredstock',
#  'adjustmentstoadditionalpaidincapitalearlyrepaymentsofconvertibledebt',
#  'adjustmentstoadditionalpaidincapitalearnedportionofnonvestedstock',
#  'adjustmentstoadditionalpaidincapitaleffectofchangeintermsofwarrants',
#  'adjustmentstoadditionalpaidincapitalemployeecompensationfromstockoptionsvalue',
#  'adjustmentstoadditionalpaidincapitalemployeesharebasedcompensationrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalemployeestockoptionsgranted',
#  'adjustmentstoadditionalpaidincapitalesopsharesearned',
#  'adjustmentstoadditionalpaidincapitalesopsharesreleased',
#  'adjustmentstoadditionalpaidincapitalexchangeofwarrants',
#  'adjustmentstoadditionalpaidincapitalexerciseofstockoptionstoredeemablecommonstock',
#  'adjustmentstoadditionalpaidincapitalexerciseofwarrantstoredeemablecommonstock',
#  'adjustmentstoadditionalpaidincapitalextensionofstockwarrants',
#  'adjustmentstoadditionalpaidincapitalextensionsofexpirationdatesofoptions',
#  'adjustmentstoadditionalpaidincapitalfairvalueadjustmentofsubordinatednotes',
#  'adjustmentstoadditionalpaidincapitalforsharebasedcompensationandemployeestockpurchaseplan',
#  'adjustmentstoadditionalpaidincapitalforwardstockbuybackprepayment',
#  'adjustmentstoadditionalpaidincapitalfromtaxcreditcarryforwards',
#  'adjustmentstoadditionalpaidincapitalgrantofrestrictedstockunits',
#  'adjustmentstoadditionalpaidincapitalimpactofdebtredemptionnetofdeferredtaxes',
#  'adjustmentstoadditionalpaidincapitalincometaxdeficiencyfromsharebasedcompensation',
#  'adjustmentstoadditionalpaidincapitalincreasedecreaseincarryingamountofredeemablenoncontrollinginterest',
#  'adjustmentstoadditionalpaidincapitalincreasedecreaseincarryingamountofredeemablenoncontrollinginterests',
#  'adjustmentstoadditionalpaidincapitalincreasedecreaseinfairvalueofinvestmentinjointventure',
#  'adjustmentstoadditionalpaidincapitalincreaseincarryingamountofredeemablecommonstock',
#  'adjustmentstoadditionalpaidincapitalincreaseincarryingamountofredeemablenoncontrollinginterest',
#  'adjustmentstoadditionalpaidincapitalincreaseincarryingamountofredeemablepreferredstock',
#  'adjustmentstoadditionalpaidincapitalinterest',
#  'adjustmentstoadditionalpaidincapitalissuanceofconvertibledebenturewithbeneficialconversionfeatureandwarrants',
#  'adjustmentstoadditionalpaidincapitalissuanceofconvertiblepreferredstock',
#  'adjustmentstoadditionalpaidincapitalissuanceofoptions',
#  'adjustmentstoadditionalpaidincapitalissuanceofpreferredstockforplacementagentwarrants',
#  'adjustmentstoadditionalpaidincapitalmanagementrecognitionplanshares',
#  'adjustmentstoadditionalpaidincapitalmarktomarket',
#  'adjustmentstoadditionalpaidincapitalmarktomarketgross',
#  'adjustmentstoadditionalpaidincapitalmarktomarkettax',
#  'adjustmentstoadditionalpaidincapitalneteffectofsubsidiariescapitaltransactionsattributabletocompany',
#  'adjustmentstoadditionalpaidincapitalnoncontrollinginterestmeasurementamount',
#  'adjustmentstoadditionalpaidincapitalnoncontrollinginterestownershipinoperatingpartnership',
#  'adjustmentstoadditionalpaidincapitalnonemployeesharebasedcompensation',
#  'adjustmentstoadditionalpaidincapitalnonemployeesharebasedcompensationrelatedtoconsultants',
#  'adjustmentstoadditionalpaidincapitalnonemployeesharebasedcompensationrelatedtoformerceo',
#  'adjustmentstoadditionalpaidincapitalnonemployeesharebasedconsulting',
#  'adjustmentstoadditionalpaidincapitalnonemployeestockoptionsgranted',
#  'adjustmentstoadditionalpaidincapitaloptiongrantednonemployeestockoptions',
#  'adjustmentstoadditionalpaidincapitaloptionissued',
#  'adjustmentstoadditionalpaidincapitaloptionsandwarrantissued',
#  'adjustmentstoadditionalpaidincapitaloptionsandwarrantissuedforservices',
#  'adjustmentstoadditionalpaidincapitaloriginalissuediscount',
#  'adjustmentstoadditionalpaidincapitalother',
#  'adjustmentstoadditionalpaidincapitalothersharebasedcompensationrequisiteserviceperiodrecognitionvalue',
#  'adjustmentstoadditionalpaidincapitalpartialsettlementofdividendequivalentrights',
#  'adjustmentstoadditionalpaidincapitalpreferredsharespurchasedbysubsidiary',
#  'adjustmentstoadditionalpaidincapitalpreferredstockdividend',
#  'adjustmentstoadditionalpaidincapitalpreferredstockdividends',
#  'adjustmentstoadditionalpaidincapitalpreferredstockissuancecost',
#  'adjustmentstoadditionalpaidincapitalpreferredstockissued',
#  'adjustmentstoadditionalpaidincapitalpreferredstockredeemed',
#  'adjustmentstoadditionalpaidincapitalpreferredstockredemptionchargenetofdiscountonrepurchase',
#  'adjustmentstoadditionalpaidincapitalpurchaseofstockwarrants',
#  'adjustmentstoadditionalpaidincapitalpurchaseofunitsfromunderwriters',
#  'adjustmentstoadditionalpaidincapitalpurchaserightsexercised',
#  'adjustmentstoadditionalpaidincapitalpurchaserightsexercisednetofparvalue',
#  'adjustmentstoadditionalpaidincapitalpurchaserightsexercisedparvalue',
#  'adjustmentstoadditionalpaidincapitalreallocationofminorityinterest',
#  'adjustmentstoadditionalpaidincapitalreclassificationexcerciseofstockoption',
#  'adjustmentstoadditionalpaidincapitalreclassificationfromliabilityrelatedtodeferredpurchaseprice',
#  'adjustmentstoadditionalpaidincapitalreclassificationofdeferredshareunits',
#  'adjustmentstoadditionalpaidincapitalreclassificationofprioryearliabilityclassifiedstockbasedcompensationuponissuanceofawards',
#  'adjustmentstoadditionalpaidincapitalreclassificationofrestrictedstockunitsissuedasstockbasedawards',
#  'adjustmentstoadditionalpaidincapitalreclassificationoftimevestingawardstostockbasedcompensationliabilities',
#  'adjustmentstoadditionalpaidincapitalreclassificationofvestedsharebasedawards',
#  'adjustmentstoadditionalpaidincapitalreclassificationofwarranttopurchasesharesofredeemableandconvertiblepreferredstockintowarranttopurchasecommonstock',
#  'adjustmentstoadditionalpaidincapitalreclassificationstockoptionliability',
#  'adjustmentstoadditionalpaidincapitalredeemablenoncontrollinginterests',
#  'adjustmentstoadditionalpaidincapitalreleaseofredemptionofpreferredstock',
#  'adjustmentstoadditionalpaidincapitalrepurchaseofconvertiblenotes',
#  'adjustmentstoadditionalpaidincapitalrepurchaseofwarrant',
#  'adjustmentstoadditionalpaidincapitalrepurchaseofwarrants',
#  'adjustmentstoadditionalpaidincapitalrestrictedstocksharesvalue',
#  'adjustmentstoadditionalpaidincapitalrestrictedstockvalue',
#  'adjustmentstoadditionalpaidincapitalretirementofshares',
#  'adjustmentstoadditionalpaidincapitalreturnoncapital',
#  'adjustmentstoadditionalpaidincapitalreversaloftaxcontingency',
#  'adjustmentstoadditionalpaidincapitalsaleofstockheldunderemployeecompensationbenifittrust',
#  'adjustmentstoadditionalpaidincapitalsaleofsubsidiarycommonstock',
#  'adjustmentstoadditionalpaidincapitalseniorconvertiblenotesconverted',
#  'adjustmentstoadditionalpaidincapitalservicescontributedbyofficers',
#  'adjustmentstoadditionalpaidincapitalservicescontributedbystockholders',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationandexerciseofstockoptions',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationawardsissuedinconnectionwithacquisition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationcapitalized',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationcommonstocksubjecttorescissionrights',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationcontinuingoperations',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationdiscontinuedoperations',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationemployeebenefitplan',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationemployeestockpurchaseprogramrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationexerciseofstockoptionsandvestingofrestrictedstock',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationforservices',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationnonemployee',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationnonemployeesrestrictedstockrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationnonemployeesstockoptionsrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationnonvestedsharesrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationotherlongtermincentiveplansrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationrelatedpartyvalue',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationrequisiteserviceperiodrecognitionvalue',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationrequisiteserviceperiodrecognitionvalueallocation',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationrequisiteserviceperiodrecognitionvalueandstockvalue',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationrequisiteserviceperiodrecognitionvaluerestrictedstock',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationrestrictedstockrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationrestrictedstockunitsandstockoptionsrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationrestrictedstockunitsrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationrestrictedstockunitsrestrictedshareawardsrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationstockawards',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationstockoptionrightrequisiteserviceperiodrecognitionvalue',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationstockoptionsandrestrictedstockrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationstockoptionsissuedtoconsultants',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationstockoptionsrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationstockoptionsrequisiteserviceperiodrecognitionfromaffiliates',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationstockoptionsvested',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationstockwarrantsvested',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationtocfoanddirectors',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationtoemployees',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationtoemployeesrequisiteserviceperiodrecognition',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationtoemployeesresultingfrommodificationofexercisepriceofgrantsmadeinpriorperiods',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationtomanagerrelatedparty',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationtononemployeesrequisiteserviceperiodrecognitionextended508',
#  'adjustmentstoadditionalpaidincapitalsharebasedcompensationvalue',
#  'adjustmentstoadditionalpaidincapitalsharebasedpaymentsassociatedwithfinancingagreements',
#  'adjustmentstoadditionalpaidincapitalsharebasedpaymentsforservicesvested',
#  'adjustmentstoadditionalpaidincapitalstockcompensationandothernet',
#  'adjustmentstoadditionalpaidincapitalstockissuedunderwriterdiscount',
#  'adjustmentstoadditionalpaidincapitalstockoptionexercised',
#  'adjustmentstoadditionalpaidincapitalstockoptiongrantedvalue',
#  'adjustmentstoadditionalpaidincapitalstockoptionsassumedforacquisition',
#  'adjustmentstoadditionalpaidincapitalstockoptionsgranted',
#  'adjustmentstoadditionalpaidincapitalstockoptiontermination',
#  'adjustmentstoadditionalpaidincapitalstockpurchaseandoptionplan',
#  'adjustmentstoadditionalpaidincapitalstockpurchaseoflimitedpartnershipunits',
#  'adjustmentstoadditionalpaidincapitalstockrepurchasedoptionpremiumspaid',
#  'adjustmentstoadditionalpaidincapitalstockrepurchasedoptionpremiumsreceived',
#  'adjustmentstoadditionalpaidincapitalstocksalebyvariableinterestentity',
#  'adjustmentstoadditionalpaidincapitalstocksplit',
#  'adjustmentstoadditionalpaidincapitalstocktobeissued',
#  'adjustmentstoadditionalpaidincapitaltaxeffectanddividendsfromsharebasedcompensation',
#  'adjustmentstoadditionalpaidincapitaltaxeffectassociatedwithoptionexercisesfromstockplans',
#  'adjustmentstoadditionalpaidincapitaltaxeffectfromdefinedcontributionplans',
#  'adjustmentstoadditionalpaidincapitaltaxeffectfromexchangeandacquisitionofunits',
#  'adjustmentstoadditionalpaidincapitaltaxeffectfromrepurchaseofconvertibledebentures',
#  'adjustmentstoadditionalpaidincapitaltaxeffectfromrestrictedstockdividendcompensationfromnonqualifiedstockoptions',
#  'adjustmentstoadditionalpaidincapitaltaxeffectfromsharebasedcompensation',
#  'adjustmentstoadditionalpaidincapitaltaxeffectfromsharebasedcompensationandother',
#  'adjustmentstoadditionalpaidincapitaltaxeffectfromsharebasedcompensationexpected',
#  'adjustmentstoadditionalpaidincapitaltaxeswithheldfrominitialpublicoffering',
#  'adjustmentstoadditionalpaidincapitaltaximpactfromissuanceofconvertiblenotes',
#  'adjustmentstoadditionalpaidincapitaltaxsharingarrangement',
#  'adjustmentstoadditionalpaidincapitaltaxwithholdingfromsharebasedcompensation',
#  'adjustmentstoadditionalpaidincapitalterminationofscorporationelection',
#  'adjustmentstoadditionalpaidincapitaltimevestingawardssettledinrestrictedstock',
#  'adjustmentstoadditionalpaidincapitaltransferstoredeemablecommonstock',
#  'adjustmentstoadditionalpaidincapitaltreasurystockissued',
#  'adjustmentstoadditionalpaidincapitaltreasurystockpurchase',
#  'adjustmentstoadditionalpaidincapitalunderwriterspurchaseoption',
#  'adjustmentstoadditionalpaidincapitalunwindbondhedge',
#  'adjustmentstoadditionalpaidincapitalvalue',
#  'adjustmentstoadditionalpaidincapitalvestingofearlyexercisedstockoptions',
#  'adjustmentstoadditionalpaidincapitalvestingsharebasedawards',
#  'adjustmentstoadditionalpaidincapitalwarrantexpired',
#  'adjustmentstoadditionalpaidincapitalwarrantforfeited',
#  'adjustmentstoadditionalpaidincapitalwarrantissued',
#  'adjustmentstoadditionalpaidincapitalwarrantissuedandbeneficialconversionfeature',
#  'adjustmentstoadditionalpaidincapitalwarrantissuedconversionofconvertiblepreferredstockwarrants',
#  'adjustmentstoadditionalpaidincapitalwarrantissuedforprivateplacement',
#  'adjustmentstoadditionalpaidincapitalwarrantissuedforservice',
#  'adjustmentstoadditionalpaidincapitalwarrantissuedforservices',
#  'adjustmentstoadditionalpaidincapitalwarrantissuedforservicesrendered',
#  'adjustmentstoadditionalpaidincapitalwarrantissuedinconnectionwithdebtconversion',
#  'adjustmentstoadditionalpaidincapitalwarrantissuedinconnectionwithdebtfinancing',
#  'adjustmentstoadditionalpaidincapitalwarrantissuedinconnectionwithissuanceofdebt',
#  'adjustmentstoadditionalpaidincapitalwarrantissuedinconnectionwithpreferredstock',
#  'adjustmentstoadditionalpaidincapitalwarrantliability',
#  'adjustmentstoadditionalpaidincapitalwarrantliabilityforfeited',
#  'adjustmentstoadditionalpaidincapitalwarrantpurchased',
#  'adjustmentstoadditionalpaidincapitalwarrantrepurchase',
#  'adjustmentstoadditionalpaidincapitalwarrantrepurchased',
#  'adjustmentstoadditionalpaidincapitalwarrants',
#  'adjustmentstoadditionalpaidincapitalwarrantsexercised',
#  'adjustmentstoadditionalpaidincapitalwarrantsexercisedcontrolledsubsidiary',
#  'adjustmentstoadditionalpaidincapitalwarrantsissuedandbeneficialconversionfeatureassociatedwithshareholdernotes',
#  'adjustmentstoadditionalpaidincapitalwarrantsliabilityreclassified',
#  'adjustmentstoadditionalpaidincapitalwarrantsoptionsissuedtononemployeesforservices',
#  'adjustmentstoadditionalpaidincapitalwarrantsreclassifiedtoderivativeliability',
#  'adjustmentstoadditionalpaidincapitalwarrantsrepurchased',
#  'adjustmentstoadditionalpaidincapitalwarrantsrepurchasedandretired',
#  'adjustmentstoadditionalpaidincapitalwithholdingtaxeffectfromcancellationofrestrictedstock',
#  'adjustmentstoapicwarrantsissued',
#  'adjustmentstoassetsmeasuredatfairvalueonnonrecurringbasis',
#  'adjustmentstocapitalrestructuring',
#  'adjustmentstocommonstockandadditionalpaidincapitalsharebasedcompensationrequisiteserviceperiodrecognitionvalue',
#  'adjustmentstocommonstocksharebasedcompensation',
#  'adjustmentstocommonstockvaluesharebasedcompensationrestrictedsharerequisiteserviceperiodrecognition',
#  'adjustmentstoindemnityreservesonloanssold',
#  'adjustmentstononcontrollinginterestinoperatingpartnership',
#  'adjustmentstononcontrollinginterestsharebasedcompensationstockoptionsrequisiteserviceperiodrecognition',
#  'adjustmentstopensionliabilities',
#  'adjustmentstopriorperiodestimatesandforeignsubsidiarystaxauditsettlement',
#  'adjustmentstoprovisionalvalues',
#  'adjustmentstoreconciletoincomelossfromdiscontinuingoperations',
#  'adjustmentstoredeemablenoncontrollinginterests',
#  'adjustmentstoredeemablepartnershipunits',
#  'adjustmentstoredemptionvalueofredeemablenoncontrollinginterestsperbasicshare',
#  'adjustmentstoredemptionvalueofredeemablenoncontrollinginterestsperdilutedshare',
#  'adjustmentstoreflectredeemableclassoperatingpartnershipunits',
#  'adjustmenttoacquiredfairvalue',
#  'adjustmenttoadditionalpaidincapital',
#  'adjustmenttoadditionalpaidincapitalantidilutionsharescontingentlyissuabletorelatedparty',
#  'adjustmenttoadditionalpaidincapitalbeneficialconversion',
#  'adjustmenttoadditionalpaidincapitalboardofdirectorsdeferredcompensation',
#  'adjustmenttoadditionalpaidincapitalcompensationcostrelatedtorestrictedstockawards',
#  'adjustmenttoadditionalpaidincapitalcontributionofcapital',
#  'adjustmenttoadditionalpaidincapitalconversionofconvertiblepreferredstockwarrantstocommonstockandcommonstockwarrants',
#  'adjustmenttoadditionalpaidincapitalconversionofpreferredstockwarranttocommonstockwarrant',
#  'adjustmenttoadditionalpaidincapitalcostofconvertiblenotehedge',
#  'adjustmenttoadditionalpaidincapitaldeferredincometaximpact',
#  'adjustmenttoadditionalpaidincapitaldeferredtax',
#  'adjustmenttoadditionalpaidincapitaldividends',
#  'adjustmenttoadditionalpaidincapitalduetopurchaseofconvertiblenotes',
#  'adjustmenttoadditionalpaidincapitalfairvalueofstockoptionsandwarrantsissuedtodirectorsandconsultants',
#  'adjustmenttoadditionalpaidincapitalforbeneficialconversionfeatureonissuanceofseriescconvertiblepreferredstockandstockwarrants',
#  'adjustmenttoadditionalpaidincapitalforgivenessofdebt',
#  'adjustmenttoadditionalpaidincapitalimpactofnetsettledsharesforvestedgrants',
#  'adjustmenttoadditionalpaidincapitalincometaxeffectfromsharebasedcompensationnet',
#  'adjustmenttoadditionalpaidincapitalnegotiatedexchanges',
#  'adjustmenttoadditionalpaidincapitalnetsettlementofoptions',
#  'adjustmenttoadditionalpaidincapitaloffairvalueincrementovercarryingvalueoflocationscontributedtojointventure',
#  'adjustmenttoadditionalpaidincapitalownercontribution',
#  'adjustmenttoadditionalpaidincapitalreclassificationofderivativeliabilityduetoexerciseofwarrants',
#  'adjustmenttoadditionalpaidincapitalrelatedtoacquisitionofproperty',
#  'adjustmenttoadditionalpaidincapitalrevaluationofredeemableshares',
#  'adjustmenttoadditionalpaidincapitalsaleofnoncontrollinginterestandwarrants',
#  'adjustmenttoadditionalpaidincapitalsharebasedcompensation',
#  'adjustmenttoadditionalpaidincapitalsharebasedcompensationrequisiteserviceperiodrecognitionvalue',
#  'adjustmenttoadditionalpaidincapitalsharetransactionunderstockplanshares',
#  'adjustmenttoadditionalpaidincapitalshortswingprofitrecovery',
#  'adjustmenttoadditionalpaidincapitalstockissuedonsaleofbuilding',
#  'adjustmenttoadditionalpaidincapitalsurrenderoffullyvestedoptions',
#  'adjustmenttoadditionalpaidincapitaltaxeffectfromsharebasedcompensation',
#  'adjustmenttoadditionalpaidincapitalvaluecommonstockissuedbycontrolledsubsidiaryforconsultingservices',
#  'adjustmenttoadditionalpaidincapitalvestingofrestrictedstocknolongersubjecttorepurchase',
#  'adjustmenttoadditionalpaidincapitalwarrantsissuedindebtconversion',
#  'adjustmenttoadditionalpaidincapitldebtdiscountondebtinstrument',
#  'adjustmenttoadditionalpaidincaptialsettlementofstockbasedcompensationplan',
#  'adjustmenttoadditionalpaidintreasurystocktransaction',
#  'adjustmenttoadditonalpaidincapitalwarrantexercised',
#  'adjustmenttoassetretirementliabilityduetoacquisitions',
#  'adjustmenttobeginningbalance',
#  'adjustmenttobenefitreserves',
#  'adjustmenttobusinessacquisitionpurchasepriceallocationdeferredincometaxamount',
#  'adjustmenttobusinessacquisitionpurchasepriceallocationgoodwillamount',
#  'adjustmenttobusinessacquisitionpurchasepriceallocationiprdamount',
#  'adjustmenttocontingentconsideration',
#  'adjustmenttocontingentearnoutliability',
#  'adjustmenttocontingentpurchaseprice',
#  'adjustmenttocostbasisoflandsalespretax',
#  'adjustmenttoestimateofperformanceshareunitstobeearnedweightedaveragegrantdatefairvalue',
#  'adjustmenttofairvalueoffixedassets',
#  'adjustmenttofairvalueofredeemablenoncontrollinginterest',
#  'adjustmenttofederaldepositinsurancecorporationindemnificationasset',
#  'adjustmenttofuelcostrecoveryrateifunderrecoveredfuelbalanceexceedsbudget',
#  'adjustmenttolimitedpartnersinterestfromincreasedownershipinoperatingpartnership',
#  'adjustmenttonetincomelossforearningspersharecalculation',
#  'adjustmenttononcontrollinginterestscommonunits',
#  'adjustmenttononcontrollinginterestspaidincapital',
#  'adjustmenttooptionsforstocksplitweightedaverageexerciseprice',
#  'adjustmenttopaidincapitalresultingfromincreasedecreaseinfairvalueofunhedgedderivativeinstruments',
#  'adjustmenttoparvalueincludingreversestocksplitamount',
#  'adjustmenttopensionliability',
#  'adjustmenttopreviouslyrecordedpbrreserve',
#  'adjustmenttoprincipalamountsoflongtermdebtduetoprincipal',
#  'adjustmenttoprincipalamountsoflongtermdebtduetounamortizedissuediscounts',
#  'adjustmenttopropertyandassetretirementobligation',
#  'adjustmenttoredeemablenoncontrollinginterestsfinancingactivities',
#  'adjustmenttoredeemablenoncontrollinginterestsoperatingpartnership',
#  'adjustmenttoredeemablenoncontrollinginterestsoperatingpartnerships',
#  'adjustmenttoredemptionvaluefornoncontrollinginterest',
#  'adjustmenttoredemptionvalueofredeemablenoncontrollinginterests',
#  'adjustmenttoreducecarryingamountofproperties',
#  'adjustmenttoreverseotherthantemporaryimpairmentonsecuritiesheldtomaturityduetodeconsolidationofvie',
#  'adjustmenttospinoffdistribution',
#  'adjustmenttostatutoryandnonstatutoryreserves',
#  'adjustnetassetstofairvalueonliquidationbasis',
#  'administrativeandmarketing',
#  'administrativecharges',
#  'administrativepenalty',
#  'administrativeservicescontractmembercopaymentsandplansponsorreimbursements',
#  'admissionsadvisory',
#  'adoptionoffairvalueoptiononmortgageservicingrights',
#  'adustmentstoadditionalpaidupcapitalwarrantsrepurchased',
#  'advaloremandfranchisetaxes',
#  'advancedpaymentstoacquirepropertyplantandequipment',
#  'advancefromcustomersarelatedparty',
#  'advancefromreplacementcreditfacilityofconsolidatedsubsidiary',
#  'advancepaymentforjointoperations',
#  'advancepaymentsbyborrowerstaxesandinsurance',
#  'advancepaymentsforpropertyplantandequipmentperiodincreasedecrease',
#  'advancepaymentstoacquirepropertyplantandequipment',
#  'advanceroyaltyperyear',
#  'advancesandinvestmentswithaffiliates',
#  'advancesbyborrowersfortaxesandinsurancenetofacquisition',
#  'advancesettledwithcommonstock',
#  'advancesexpectedtobereceivedfromjointventureinnextfiscalyear',
#  'advancesforacquisition',
#  'advancesforcustomerenergyefficiencyprojects',
#  'advancesforvesselsdrillshipsunderconstruction',
#  'advancesfromaffiliate',
#  'advancesfromborrowersfortaxesandinsurance',
#  'advancesfromcoownerschangesinworkingcapitalaccounts',
#  'advancesfromdirector',
#  'advancesfromothersforconstruction',
#  'advancesfrompartnersandcustomerdeposits',
#  'advancesfromrelatedparties',
#  'advancesfromrelatedparties3',
#  'advancesfromrelatedparty',
#  'advancesfromtoconsolidatedsubsidiaries',
#  'advancesmadetoshareholders',
#  'advancesofdeferredsalescommissions',
#  'advancesofloanstosubsidiaries',
#  'advancesonloans',
#  'advancesprovidedtoothersubsidiaries',
#  'advancesprovidedtoothersubsidiariesfinancingactivities',
#  'advancesreceivedfromcustomer',
#  'advancesreceivedfromothersubsidiaries',
#  'advancesreimbursementofadvancestojointventures',
#  'advancestoaffiliateinterestincome',
#  'advancestoaffiliatesnetofrepayments',
#  'advancestodealerpartners',
#  'advancestojointventures',
#  'advancestononcontrollinginterestpartner',
#  'advancestooperators',
#  'advancestoportfoliocompanies',
#  'advancestorelatedparties',
#  'advancestorelatedparty',
#  'advancestorepaymentbyjointventurenet',
#  'advancestosubsidiaries',
#  'advancestosubsidiariesnet',
#  'advancestosupplierschange',
#  'advancestotenantforpurchaseoftenantassets',
#  'advancestounconsolidatedaffiliate',
#  'advancestovendors',
#  'advancesusedforcapitalexpendituresinoilandgaspropertiesreclassified',
#  'advancesusedforcapitalexpendituresinoilandgaspropertiesreclassifiedtoprovedandunprovedproperties',
#  'advancesusedforcapitalexpendituresinoilandgaspropertiesreclassifiedtoprovedproperties',
#  'advancetoacquiredcompany',
#  'advancetoownerpreacquisition',
#  'advancetosecuremanufacturingcapacity',
#  'advancetothirdparty',
#  'adversedevelopmentexperiencedinfidelityclass',
#  'advertisingandbusinessdevelopment',
#  'advertisingcontributionsbycompanyownedstores',
#  'advertisingcontributionsbyfranchisees',
#  'advertisingreimbursements',
#  'advertisingsellinggeneralandadministrative',
#  'advisoryservicesandother',
#  'affilatedassettransfers',
#  'affiliatebanksaveragereservebalanceswithfederalreservebank',
#  'affiliatedassettransfers',
#  'affiliatedcompanytransactionunearnedinterestsupplementsfromtransactionswithaffiliatedentities',
#  'affiliateddividendscommonstock',
#  'affiliatedinterestincomenet',
#  'affiliatedleaseagreementmonthlypayments',
#  'affiliatefinancingofelmroad',
#  'affiliateinvestingactivitynet',
#  'affiliatereimbursementforuseofairplane',
#  'affiliatesapproximateshareofdisputednpmadjustment',
#  'affiliatescapitalaccountcontributions',
#  'affinityearnedpremiums',
#  'affordablehousinginvestmentsimpairment',
#  'affordablehousingprogramassessments',
#  'aftertaxadjustmenttoothercomprehensiveduetointerestrateswapagreement',
#  'aftertaxinterestrefunds',
#  'aftertaxpayrolldeductionsmaximumamountofcompensation',
#  'aftertaxquarterlypayments',
#  'aftertaxsettlementchargerelatedtofederalandstateincometaxes',
#  'agencydebenturescalled',
#  'agencyoperations',
#  'agencytitleinsurancepremiums',
#  'agentswarrants',
#  'agentswarrantsexercised',
#  'aggregateadditionalpaymentifoptiontoextendagreementsisexercisedlessthan',
#  'aggregateadditionalpaymentstocertainplanparticipants',
#  'aggregateamountforpaymentofdividendsandrepurchaseofcommonstock',
#  'aggregateamountforpaymentofdividendsandrepurchaseofcommonstockaftersatisfyingcertainleverageratio',
#  'aggregateamountinsuranceinforceoutstandingcededtoreinsurers',
#  'aggregateamountoffinesoughtbygovernmentalauthorities',
#  'aggregateamountofincometaxes',
#  'aggregateamountofintangibleassetsagreement',
#  'aggregateamountofpendingadministrativeprocessinginitiatedbygovernmentalauthority',
#  'aggregateamountpayableunderservicecontract',
#  'aggregateamountrecordedincostofsalesrelatedtostatesettlementagreementsandfederalequitabletobaccoreformact',
#  'aggregateannualsalesofadditionalbusinesses',
#  'aggregatearrangementconsiderationamount',
#  'aggregatebookvalueofnotecomponents',
#  'aggregatebudgetofpropertiesmovedoutofstabilization',
#  'aggregatebudgetsofpropertiesinprocessofstabilization',
#  'aggregatebudgettoconstructtwomedicalofficebuildingsandparkinggarage',
#  'aggregatechargestoearningsunderdefinedbenefitplan',
#  'aggregatechargestoearningsunderdefinedcontributionretirementplan',
#  'aggregatecollaborationagreementpayments',
#  'aggregatecontractualcapitalcommitmentsdueinoneyear',
#  'aggregatecontractualcapitalcommitmentsdueinthreeyears',
#  'aggregatecontractualcapitalcommitmentsdueintwoyears',
#  'aggregatecostofdiscountoffmarketvalueforsharesavailableunderemployeestockpurchaseplan',
#  'aggregatecostofdrillships',
#  'aggregatecostofrepurchasedcommonsharesforstatutorytaxwithholdingobligations',
#  'aggregatecostofsharescommonmembershipinterestspurchased',
#  'aggregatedeductionsrelatedtoexerciseofstockoptionsandvestingofrestrictedawards',
#  'aggregatedrillingrate',
#  'aggregatedundiscountedenvironmentalliabilities',
#  'aggregateexcessofpaymentsinunsecurednotes',
#  'aggregatefairvalueofrestrictedstockunitsthatvestedduringperiod',
#  'aggregatefairvaluerestrictedstockunitsgranteduponachievingcommonstockpricetarget',
#  'aggregatefavorabledevelopmentexperiencedincommercialandpersonalliabilityclasses',
#  'aggregatefavorabledevelopmentexperiencedinpersonalandcommercialpropertyclasses',
#  'aggregatefuturecommitmentrelatingtoleaseagreements',
#  'aggregategrantdatefairvalueofstockoptionsvested',
#  'aggregateincreaseofcommitmentamountavailable',
#  'aggregateinsurancecoveragelimit',
#  'aggregateintrinsicvalueofappreciationrightsexercised',
#  'aggregateintrinsicvalueofrestrictedstockunitsvested',
#  'aggregateintrinsicvalueofstockoptionsexercisable',
#  'aggregateintrinsicvalueofstockoptionsexercisableduringperiod',
#  'aggregateinvestmentinleasedoutpatientfacilities',
#  'aggregateinvestmentmadebypurchasers',
#  'aggregateitdcreditimpairmentoncmbsderivatives',
#  'aggregatelimitofliabilitiesarisesfromterroistactoutsidescopeoftrialssubjecttooneindustry',
#  'aggregatelimitremaining',
#  'aggregateliquidationpreferenceamountafterexchange',
#  'aggregatemarketvalueofrestrictedsharesgrantedtoemployee',
#  'aggregatemaximuminsurancelimit',
#  'aggregatemaximumlimitincommercialproperty',
#  'aggregatenotionalamountextendedmaturitiescapagreements',
#  'aggregatenotionalamountmaturedcapagreements',
#  'aggregatenotionalamountterminatedcappagreements',
#  'aggregateofproductionstartupexpenditures',
#  'aggregateparvalueofpreferredunitsrepurchased',
#  'aggregatepaymentforclaimsresultingfromterroristactsinoneyearperiod',
#  'aggregatepaymentsmadeonachievementofmilestones',
#  'aggregatepaymentunderagreementlessthan',
#  'aggregatepayout',
#  'aggregatepricepaidforpreferredinterest',
#  'aggregateprincipalamountofdebtexchanged',
#  'aggregateprincipalamountofnotesissuedbyaffiliatestorelatedpartyotherthanreportingentity',
#  'aggregateprincipalamountofrepurchasedseniordiscountnotes',
#  'aggregatepurchasepriceofacquisitionsincreasingdebttoebitdaratio',
#  'aggregatepurchasepriceofotheracquisitions',
#  'aggregatepurchasepriceofrights',
#  'aggregatepurchasepriceofseniornotes',
#  'aggregatereductionincommonstockduringstockrepurchases',
#  'aggregatereductiontoincome',
#  'aggregatereservesrelatingtochargebackactivity',
#  'aggregateresidualguaranteeamount',
#  'aggregateresultsofvariableannuityhedgeprogram',
#  'aggregaterewardsofoppawardsmaximumcap',
#  'aggregateselfinsuredexposureperoccurrence',
#  'aggregatetaxablelossoftaxablereitsubsidiaries',
#  'aggregateunderwritingdiscountonseniornotes',
#  'aggregateunrealizedlossotherstructuredfinancialproducts',
#  'aggregatevalueofassetsacquiredattributabletononcontrollinginterests',
#  'aggregatevalueofassetsacquiredincludingminorityinterests',
#  'aggregatevalueofissuanceofcommonstock',
#  'aggregatevalueofrestrictedstockunitsgranted',
#  'aggregatevalueofsharesrepurchased',
#  'aggregatevolumeprocessedbyelectronicpaymentservicesbusiness',
#  'agreedfundtobuyeramount',
#  'agreeduponfinancingrelatedtothirdpartybankruptcyfiling',
#  'agreementinprincipleamountmedicalmatter',
#  'agreementsfuturepaymentsdue',
#  'agreementsfuturepaymentsdueinfiveyears',
#  'agreementsfuturepaymentsdueinfouryears',
#  'agreementsfuturepaymentsdueinoneyear',
#  'agreementsfuturepaymentsdueinsixyearsandthereafter',
#  'agreementsfuturepaymentsdueinthreeyears',
#  'agreementsfuturepaymentsdueintwoyears',
#  'agreementstopurchasegroundlease',
#  'agreementtofundadditionaladvance',
#  'agreementtosettletppmatters',
#  'agriculturedisasterreliefpayment',
#  ...]

# %% [markdown]
# ### Old testing cells (ignore):

# %%
# for i,row in enumerate(nums_2011[0:10]):

#     if 'Assets' in row[1]:
#         nums_2011[i][1] = 'AccountsReceivable'

# %%
# temp.loc[temp['tag'].str.contains("accounts|assets")] = 'asset'

# %%
# temp.loc[temp['tag'].str.contains("accounts|assets")].index

# %%
# temp = temp.set_value(temp.loc[temp['tag'].str.contains("accounts|assets")].index, 'tag', 'assets')

# %%
temp
# Out:
#                     adsh                                                tag
# 9   0001376231-12-000002                 retainedearningsaccumulateddeficit
# 13  0001193125-12-080059                       duefromrelatedpartiescurrent
# 15  0001193125-12-080059                                             assets
# 20  0001193125-12-080059  othercomprehensiveincomederivativesqualifyinga...
# 21  0001193125-12-080059  netcashprovidedbyusedinfinancingactivitiescont...
# 24  0001193125-12-080059                       proceedsfromincometaxrefunds
# 29  0001193125-12-080059                  loanstoparentreclassifiedtoequity
# 31  0001144204-12-016089                                             assets
# 33  0001144204-12-016089                            commonstocksharesissued
# 35  0001144204-12-016089                      gainlossonsaleofsecuritiesnet

# %%
# a= tags_list
# for n, i in enumerate(a):
#     if i.lower().startswith(('accountsreceivable','accountreceivable')):
#         a[n] = 'AccountsReceivable'
# len(set(tags_list))

# %%
# type(tags)
# Out:
# numpy.ndarray

# %%
# tags_list = tags.tolist()

# %%
# sorted(tags_list)

# %%
# result2 = [i for i in tags_list if i.startswith('AccountsReceivable')]

# %%
# a= tags_list
# for n, i in enumerate(a):
#     if i.lower().startswith(('accountsreceivable','accountreceivable')):
# #         a[n] = 'AccountsReceivable'
# len(set(tags_list))
# Out:
# 189990

# %%
# a= tags_list
# for n, i in enumerate(a):
#     if (i.lower()).startswith(('accountspayable', 'accountpayable')):
#         a[n] = 'accountspayable'
# len(set(tags_list))
# Out:
# 189988

# %%
# a= tags_list
# for n, i in enumerate(a):
#     if (i.lower()).startswith('abandoned'):
#         a[n] = 'abandonedcosts'
# len(set(tags_list))

# %%
# result3 = [i for i in tags_list if ('Receivable') in i]

# %%
# a= tags_list
# for n, i in enumerate(a):
# #     if i.startswith('AccountsReceivable'):
#         a[n] = 'AccountsReceivable'
# len(set(tags_list))

# %%
#get details on all columns
# quarter_numbers.describe(include='all')
