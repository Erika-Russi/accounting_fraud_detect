# %% [markdown]
# ### Final Project Requirements/notes: https://docs.google.com/document/d/1mwYbYJHkB7kpx4tNflKh54jN9_oOscw3p4k5fsmn3bc/edit

# %% [markdown]
# ### Link with all Data: https://www.sec.gov/dera/data/financial-statement-and-notes-data-set.html
# - using NUM file only for now (data set of all numeric XBRL facts presented on the primary financial statements)

# %%
import pandas as pd
q414numbers = pd.read_table('2014q4_notes/num.tsv', encoding ='latin1')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#get details on all columns
q414numbers.describe(include='all')
# Out:
#                         adsh                 tag       version         ddate  \
# count                5906009             5906009       5906009  5.906009e+06
# unique                  7715              247205          7438           NaN
# top     0001193125-14-405655  StockholdersEquity  us-gaap/2014           NaN
# freq                   11563               58253       3490656           NaN
# mean                     NaN                 NaN           NaN  2.013533e+07
# std                      NaN                 NaN           NaN  1.177043e+04
# min                      NaN                 NaN           NaN  1.968123e+07
# 25%                      NaN                 NaN           NaN  2.013093e+07
# 50%                      NaN                 NaN           NaN  2.014053e+07
# 75%                      NaN                 NaN           NaN  2.014093e+07
# max                      NaN                 NaN           NaN  3.013093e+07
#
#                 qtrs      uom        dimh          iprx         value  \
# count   5.906009e+06  5906009     5906009  5.688049e+06  5.751967e+06
# unique           NaN     2822      315900           NaN           NaN
# top              NaN      USD  0x00000000           NaN           NaN
# freq             NaN  5156987     2569806           NaN           NaN
# mean    1.411654e+00      NaN         NaN  9.889155e-04  5.873254e+09
# std     2.484153e+00      NaN         NaN  3.724272e-02  2.098257e+12
# min     0.000000e+00      NaN         NaN  0.000000e+00 -3.015500e+13
# 25%     0.000000e+00      NaN         NaN  0.000000e+00  2.000000e-01
# 50%     1.000000e+00      NaN         NaN  0.000000e+00  9.628770e+05
# 75%     3.000000e+00      NaN         NaN  0.000000e+00  2.540000e+07
# max     3.630000e+02      NaN         NaN  1.000000e+01  1.491809e+15
#
#                                                  footnote       footlen  \
# count                                               23235  5.906009e+06
# unique                                              19771           NaN
# top     Fair value based on forward NYMEX natural gas ...           NaN
# freq                                                   21           NaN
# mean                                                  NaN  8.843681e-01
# std                                                   NaN  2.275170e+01
# min                                                   NaN  0.000000e+00
# 25%                                                   NaN  0.000000e+00
# 50%                                                   NaN  0.000000e+00
# 75%                                                   NaN  0.000000e+00
# max                                                   NaN  1.357700e+04
#
#                 dimn          coreg          durp          datp          dcml
# count   5.906009e+06         381764  5.688049e+06  5.688049e+06  5.688049e+06
# unique           NaN           5293           NaN           NaN           NaN
# top              NaN  ParentCompany           NaN           NaN           NaN
# freq             NaN          70572           NaN           NaN           NaN
# mean    8.053765e-01            NaN  4.775323e-03  1.015961e-01  2.101921e+03
# std     8.953870e-01            NaN  3.873446e-02  1.710748e+00  1.099353e+04
# min     0.000000e+00            NaN -4.986305e-01 -1.500000e+01 -3.276800e+04
# 25%     0.000000e+00            NaN  0.000000e+00  0.000000e+00 -3.000000e+00
# 50%     1.000000e+00            NaN  2.740025e-03  0.000000e+00 -3.000000e+00
# 75%     1.000000e+00            NaN  1.917911e-02  0.000000e+00  0.000000e+00
# max     8.000000e+00            NaN  4.986310e-01  1.500000e+01  3.276700e+04

# %% [markdown]
# ### From "Financial Statement and Notes Data Sets" Readme:
# These fields comprise a unique compound key:
#
# 1) **adsh - EDGAR accession number**: a unique identifier assigned automatically to an accepted submission by the EDGAR Filer System; The first set of numbers (0001193125) is the CIK of the entity submitting the filing. The next 2 numbers (18) represent the year. The last series of numbers represent a sequential count of submitted filings from that CIK. The count is usually, but not always, reset to 0 at the start of each calendar year.
# - **TODO**: separate these numbers to identify a company or a financial filing, there were 6,492 individual filings
#
# 2) **tag** - tag used by the filer
# - **TODO**: may have to separate out first word from tag to identify broader groups such as revenue
#
# 3) **version** – if a standard tag, the taxonomy of origin, otherwise equal to adsh.
#
# 4) **ddate** - period end date
#
# 5) **qtrs** - duration in number of quarters
#
# 6) **uom** - unit of measure
#
# 7) **dimh** - 16-byte dimensional qualifier
#
# 8) **iprx** - a sequential integer used to distinguish otherwise identical facts
#
# 9) **coreg** - If specified, indicates a specific co-registrant, the parent company, or other entity (e.g., guarantor).  NULL indicates the consolidated entity.  Note that this value is a function of the dimension segments.
#
# 10) **durp** - The difference between the reported fact duration and the quarter duration (qtrs), expressed as a fraction of 1.  For example, a fact with duration of 120 days rounded to a 91-day quarter has a durp value of 29/91 = +0.3187.
#
# 11) **datp** - The difference between the reported fact date and the month-end rounded date (ddate), expressed as a fraction of 1.  For example, a fact reported for 29/Dec, with ddate rounded to 31/Dec, has a datp value of minus 2/31 = -0.0645.
#
# 12) **dcml** - The value of the fact "decimals" attribute, with INF represented by 32767.

# %%
q414numbers.isnull().sum()
# Out:
# adsh              0
# tag               0
# version           0
# ddate             0
# qtrs              0
# uom               0
# dimh              0
# iprx         217960
# value        154042
# footnote    5882774
# footlen           0
# dimn              0
# coreg       5524245
# durp         217960
# datp         217960
# dcml         217960
# dtype: int64

# %% [markdown]
# #### A lot of null values for footnotes and coregistrants (majority of rows); will remove these columns for now

# %%
q414numbers = q414numbers.drop(columns=['footnote','coreg'])

# %%
q414numbers.isnull().sum()
# Out:
# adsh            0
# tag             0
# version         0
# ddate           0
# qtrs            0
# uom             0
# dimh            0
# iprx       217960
# value      154042
# footlen         0
# dimn            0
# durp       217960
# datp       217960
# dcml       217960
# dtype: int64

# %% [markdown]
# #### Didn't get rid of blank Value fields, so just get rid of those since there will still be enough data points to analyze

# %%
q414numbers = q414numbers.dropna()

# %%
q414numbers.describe(include='all') #still have 5million+ data points
# Out:
#                         adsh                 tag       version         ddate  \
# count                5538862             5538862       5538862  5.538862e+06
# unique                  7655              239779          7368           NaN
# top     0001193125-14-405655  StockholdersEquity  us-gaap/2014           NaN
# freq                   11560               55620       3298152           NaN
# mean                     NaN                 NaN           NaN  2.013543e+07
# std                      NaN                 NaN           NaN  1.183728e+04
# min                      NaN                 NaN           NaN  1.968123e+07
# 25%                      NaN                 NaN           NaN  2.013093e+07
# 50%                      NaN                 NaN           NaN  2.014063e+07
# 75%                      NaN                 NaN           NaN  2.014093e+07
# max                      NaN                 NaN           NaN  3.013093e+07
#
#                 qtrs      uom        dimh          iprx         value  \
# count   5.538862e+06  5538862     5538862  5.538862e+06  5.538862e+06
# unique           NaN     2740      299276           NaN           NaN
# top              NaN      USD  0x00000000           NaN           NaN
# freq             NaN  4822236     2458846           NaN           NaN
# mean    1.407349e+00      NaN         NaN  9.821512e-04  5.974044e+09
# std     2.497928e+00      NaN         NaN  3.728668e-02  2.137439e+12
# min     0.000000e+00      NaN         NaN  0.000000e+00 -3.015500e+13
# 25%     0.000000e+00      NaN         NaN  0.000000e+00  2.200000e-01
# 50%     1.000000e+00      NaN         NaN  0.000000e+00  9.000000e+05
# 75%     3.000000e+00      NaN         NaN  0.000000e+00  2.400000e+07
# max     3.630000e+02      NaN         NaN  1.000000e+01  1.491809e+15
#
#              footlen          dimn          durp          datp          dcml
# count   5.538862e+06  5.538862e+06  5.538862e+06  5.538862e+06  5.538862e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    8.742092e-01  7.856128e-01  4.730011e-03  1.031539e-01  3.041128e+03
# std     2.277343e+01  8.838732e-01  3.858588e-02  1.725226e+00  9.512136e+03
# min     0.000000e+00  0.000000e+00 -4.986305e-01 -1.500000e+01 -1.200000e+01
# 25%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -3.000000e+00
# 50%     0.000000e+00  1.000000e+00  2.740025e-03  0.000000e+00 -3.000000e+00
# 75%     0.000000e+00  1.000000e+00  1.917911e-02  0.000000e+00  0.000000e+00
# max     1.357700e+04  8.000000e+00  4.986310e-01  1.500000e+01  3.276700e+04

# %%
#break out adsh to cik and filing number
s = q414numbers['adsh'].str.split('-', n = 1, expand = True)

# %%
s.head()
# Out:
#             0          1
# 0  0001171843  14-005353
# 1  0001171843  14-005353
# 2  0001171843  14-005353
# 3  0001171843  14-005353
# 4  0001171843  14-005353

# %%
q414numbers['entity_CIK'] = s[0]
q414numbers['filing_number'] = s[1]
q414numbers.head()

# System; The first set of numbers (0001193125) is the CIK of the entity submitting the filing. 
# The next 2 numbers (18) represent the year. 
# The last series of numbers represent a sequential count of submitted filings from that CIK. 
# The count is usually, but not always, reset to 0 at the start of each calendar year.
# Out:
#                    adsh                                                tag  \
# 0  0001171843-14-005353                  FederalHomeLoanBankStockDividends
# 1  0001171843-14-005353                  FederalHomeLoanBankStockDividends
# 2  0001171843-14-005353                  FederalHomeLoanBankStockDividends
# 3  0001171843-14-005353                  FederalHomeLoanBankStockDividends
# 4  0001171843-14-005353  ShareBasedCompensationArrangementByShareBasedP...
#
#                 version     ddate  qtrs     uom        dimh  iprx      value  \
# 0  0001171843-14-005353  20140930     1     USD  0x00000000   0.0   463000.0
# 1  0001171843-14-005353  20130930     1     USD  0x00000000   0.0   399000.0
# 2  0001171843-14-005353  20140930     3     USD  0x00000000   0.0  1444000.0
# 3  0001171843-14-005353  20130930     3     USD  0x00000000   0.0  1214000.0
# 4  0001171843-14-005353  20140930     0  shares  0x00000000   0.0   217227.0
#
#    footlen  dimn      durp  datp     dcml  entity_CIK filing_number
# 0        0     0  0.002740   0.0     -3.0  0001171843     14-005353
# 1        0     0  0.002740   0.0     -3.0  0001171843     14-005353
# 2        0     0  0.019179   0.0     -3.0  0001171843     14-005353
# 3        0     0  0.019179   0.0     -3.0  0001171843     14-005353
# 4        0     0  0.000000   0.0  32767.0  0001171843     14-005353

# %%
q414numbers.describe(include='all')
# Out:
#                         adsh                 tag       version         ddate  \
# count                5538862             5538862       5538862  5.538862e+06
# unique                  7655              239779          7368           NaN
# top     0001193125-14-405655  StockholdersEquity  us-gaap/2014           NaN
# freq                   11560               55620       3298152           NaN
# mean                     NaN                 NaN           NaN  2.013543e+07
# std                      NaN                 NaN           NaN  1.183728e+04
# min                      NaN                 NaN           NaN  1.968123e+07
# 25%                      NaN                 NaN           NaN  2.013093e+07
# 50%                      NaN                 NaN           NaN  2.014063e+07
# 75%                      NaN                 NaN           NaN  2.014093e+07
# max                      NaN                 NaN           NaN  3.013093e+07
#
#                 qtrs      uom        dimh          iprx         value  \
# count   5.538862e+06  5538862     5538862  5.538862e+06  5.538862e+06
# unique           NaN     2740      299276           NaN           NaN
# top              NaN      USD  0x00000000           NaN           NaN
# freq             NaN  4822236     2458846           NaN           NaN
# mean    1.407349e+00      NaN         NaN  9.821512e-04  5.974044e+09
# std     2.497928e+00      NaN         NaN  3.728668e-02  2.137439e+12
# min     0.000000e+00      NaN         NaN  0.000000e+00 -3.015500e+13
# 25%     0.000000e+00      NaN         NaN  0.000000e+00  2.200000e-01
# 50%     1.000000e+00      NaN         NaN  0.000000e+00  9.000000e+05
# 75%     3.000000e+00      NaN         NaN  0.000000e+00  2.400000e+07
# max     3.630000e+02      NaN         NaN  1.000000e+01  1.491809e+15
#
#              footlen          dimn          durp          datp          dcml  \
# count   5.538862e+06  5.538862e+06  5.538862e+06  5.538862e+06  5.538862e+06
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    8.742092e-01  7.856128e-01  4.730011e-03  1.031539e-01  3.041128e+03
# std     2.277343e+01  8.838732e-01  3.858588e-02  1.725226e+00  9.512136e+03
# min     0.000000e+00  0.000000e+00 -4.986305e-01 -1.500000e+01 -1.200000e+01
# 25%     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -3.000000e+00
# 50%     0.000000e+00  1.000000e+00  2.740025e-03  0.000000e+00 -3.000000e+00
# 75%     0.000000e+00  1.000000e+00  1.917911e-02  0.000000e+00  0.000000e+00
# max     1.357700e+04  8.000000e+00  4.986310e-01  1.500000e+01  3.276700e+04
#
#         entity_CIK filing_number
# count      5538862       5538862
# unique        2385          4859
# top     0001193125     14-000032
# freq        892960         51670
# mean           NaN           NaN
# std            NaN           NaN
# min            NaN           NaN
# 25%            NaN           NaN
# 50%            NaN           NaN
# 75%            NaN           NaN
# max            NaN           NaN

# %%
# q414numbers = q414numbers.drop(columns =["adsh"], inplace = True)
# q414numbers = q414numbers.to_frame()

# %%
#Valeant's numbers
valeant_one_filing = q414numbers.loc[q414numbers['filing_number'] == '14-000073']
valeant_one_filing.head()
# Out:
#                        adsh  \
# 14319  0001498301-14-000073
# 14320  0001498301-14-000073
# 14321  0001498301-14-000073
# 14322  0001498301-14-000073
# 14323  0001498301-14-000073
#
#                                                      tag  \
# 14319  ShareBasedCompensationArrangementByShareBasedP...
# 14320  ShareBasedCompensationArrangementByShareBasedP...
# 14321          IncreaseDecreaseInLeaseRelatedLiabilities
# 56247    ComprehensiveIncomeNetOfTaxIncludingPortionAtt...
# 56248    ComprehensiveIncomeNetOfTaxIncludingPortionAtt...
# 56249    ComprehensiveIncomeNetOfTaxIncludingPortionAtt...
# 56250    ComprehensiveIncomeNetOfTaxIncludingPortionAtt...
# 56251               SellingGeneralAndAdministrativeExpense
# 56252               SellingGeneralAndAdministrativeExpense
# 56253               SellingGeneralAndAdministrativeExpense
# 56254               SellingGeneralAndAdministrativeExpense
# 56255                        GainLossOnDispositionOfAssets
# 56256                        GainLossOnDispositionOfAssets
# 56257                        GainLossOnDispositionOfAssets
# 56258                        GainLossOnDispositionOfAssets
# 184782        PaymentsToAcquireBusinessesNetOfCashAcquired
# 184783        PaymentsToAcquireBusinessesNetOfCashAcquired
# 184784        PaymentsToAcquireBusinessesNetOfCashAcquired
# 184785        PaymentsToAcquireBusinessesNetOfCashAcquired
# 184787              AllocatedShareBasedCompensationExpense
# 184788              AllocatedShareBasedCompensationExpense
# 184789              AllocatedShareBasedCompensationExpense
# 184790              AllocatedShareBasedCompensationExpense
# 184791                        GoodwillAcquiredDuringPeriod
# 184792                              InventoryFinishedGoods
# 184793                              InventoryFinishedGoods
# 184794   StockholdersEquityBeforeComprehensiveIncomeNet...
# 184795   StockholdersEquityBeforeComprehensiveIncomeNet...
# 303683                   GainsLossesOnExtinguishmentOfDebt
# 303684                                    MinorityInterest
# 303685                                    MinorityInterest
# 303686   IncomeLossFromContinuingOperationsBeforeIncome...
# 303687   IncomeLossFromContinuingOperationsBeforeIncome...
# ...                                                    ...
# 5153730  BusinessCombinationRecognizedIdentifiableAsset...
# 5153731  BusinessCombinationRecognizedIdentifiableAsset...
# 5153732  BusinessCombinationRecognizedIdentifiableAsset...
# 5153733  BusinessCombinationRecognizedIdentifiableAsset...
# 5153734  BusinessCombinationRecognizedIdentifiableAsset...
# 5153735  BusinessCombinationRecognizedIdentifiableAsset...
# 5153736  BusinessCombinationRecognizedIdentifiableAsset...
# 5153737  BusinessCombinationRecognizedIdentifiableAsset...
# 5153738  BusinessCombinationSeparatelyRecognizedTransac...
# 5153739  BusinessCombinationContingentConsiderationLiab...
# 5153740                   DebtInstrumentUnamortizedPremium
# 5153741                     DebtInstrumentRedemptionAmount
# 5153742                           DebtInstrumentFaceAmount
# 5153743      ImpairmentOfIntangibleAssetsExcludingGoodwill
# 5153744                ProceedsFromDivestitureOfBusinesses
# 5153745               ExchangeOfCommonStockCommonStockHeld
# 5153746       ExchangeOfCommonStockNumberofSharesAllocable
# 5153747                           GainLossOnSaleOfBusiness
# 5153748                ProceedsFromDivestitureOfBusinesses
# 5153749                            IncomeTaxExpenseBenefit
# 5153750                           GainLossOnSaleOfBusiness
# 5153751                ProceedsFromDivestitureOfBusinesses
# 5153752  BusinessCombinationRecognizedIdentifiableAsset...
# 5153753                      PaymentsForMergerRelatedCosts
# 5153754  BusinessCombinationRecognizedIdentifiableAsset...
# 5153755                                             Assets
# 5153756  BusinessCombinationRecognizedIdentifiableAsset...
# 5153757  ImpairmentOfIntangibleAssetsIndefinitelivedExc...
# 5153732     2  0.000000   0.0     -5.0  0000885590     14-000073
# 5153733     2  0.000000   0.0     -5.0  0000885590     14-000073
# 5153734     2  0.000000   0.0     -5.0  0000885590     14-000073
# 5153735     3  0.000000   0.0     -5.0  0000885590     14-000073
# 5153736     3  0.000000   0.0     -5.0  0000885590     14-000073
# 5153737     3  0.000000   0.0     -5.0  0000885590     14-000073
# 5153738     2  0.002740   0.0     -5.0  0000885590     14-000073
# 5153739     2  0.000000   0.0     -5.0  0000885590     14-000073
# 5153740     2  0.000000 -15.0     -5.0  0000885590     14-000073
# 5153741     2  0.000000 -15.0     -5.0  0000885590     14-000073
# 5153742     2  0.000000 -15.0     -5.0  0000885590     14-000073
# 5153743     1  0.019179   0.0     -5.0  0000885590     14-000073
# 5153744     1 -0.328767   0.0     -6.0  0000885590     14-000073
# 5153745     3  0.019179   0.0  32767.0  0000885590     14-000073
# 5153746     3  0.019179   0.0  32767.0  0000885590     14-000073
# 5153747     1  0.002740   0.0     -5.0  0000885590     14-000073
# 5153748     1  0.000000  -1.0     -5.0  0000885590     14-000073
# 5153749     1  0.002740   0.0     -5.0  0000885590     14-000073
# 5153750     1  0.002740   0.0     -5.0  0000885590     14-000073
# 5153751     1 -0.328767   0.0     -6.0  0000885590     14-000073
# 5153752     3  0.000000  -5.0     -5.0  0000885590     14-000073
# 5153753     2  0.019179   0.0     -5.0  0000885590     14-000073
# 5153754     3  0.000000   0.0     -5.0  0000885590     14-000073
# 5153755     2  0.000000   0.0     -8.0  0000885590     14-000073
# 5153756     3  0.000000  -5.0     -5.0  0000885590     14-000073
# 5153757     2  0.002740   0.0     -5.0  0000885590     14-000073
# 5153758     2  0.000000   0.0     -5.0  0000885590     14-000073
# 5153759     2  0.000000   0.0     -5.0  0000885590     14-000073
#
# [1453 rows x 16 columns]

# %%
valeant_nums = list(set(valeant_one_filing.value.abs()))
valeant_nums
# Out:
# [5190400000.0,
#  204800000.0,
#  0.0,
#  2.0,
#  3.13,
#  19200000.0,
#  1.12,
#  531200000.0,
#  1.13,
#  2.92,
#  6.0,
#  3.0,
#  5.0,
#  13.0,
#  1.0,
#  200000000.0,
#  24.0,
#  26.1,
#  322900000.0,
#  5794900000.0,
#  316500000.0,
#  233300000.0,
#  1436500000.0,
#  54100000.0,
#  86100000.0,
#  1935700000.0,
#  193100000.0,
#  1410900000.0,
#  45.0,
#  50.0,
#  507957.0,
#  62.15,
#  2060200000.0,
#  114600000.0,
#  690600000.0,
#  633000000.0,
#  5800000.0,
#  185600000.0,
#  940200000.0,
#  31400000.0,
#  223400000.0,
#  73.9,
#  72.0,
#  338000.0,
#  1000000000.0,
#  84.51,
#  85.0,
#  1231100000.0,
#  4264700000.0,
#  104700000.0,
#  5979900000.0,
#  100.0,
#  1256700000.0,
#  687100000.0,
#  2300000.0,
#  1607800000.0,
#  725500000.0,
#  25000000.0,
#  1400000000.0,
#  170900000.0,
#  117.82,
#  579300000.0,
#  125.04,
#  440400000.0,
#  606800000.0,
#  24400000.0,
#  222800000.0,
#  16389200000.0,
#  446800000.0,
#  5061200000.0,
#  946000000.0,
#  14398800000.0,
#  56400000.0,
#  135.06,
#  788900000.0,
#  3278500000.0,
#  8100000.0,
#  148900000.0,
#  155300000.0,
#  1700000.0,
#  3021000000.0,
#  358000000.0,
#  149900000.0,
#  149600000.0,
#  149000000.0,
#  1361400000.0,
#  337400000.0,
#  555000000.0,
#  279800000.0,
#  286200000.0,
#  4600000.0,
#  11000000.0,
#  36600000.0,
#  542200000.0,
#  146900000.0,
#  555600000.0,
#  883500000.0,
#  146600000.0,
#  217294.0,
#  209.72,
#  90700000.0,
#  756300000.0,
#  321100000.0,
#  1236300000.0,
#  3885900000.0,
#  20300000.0,
#  596300000.0,
#  65100000.0,
#  1100000.0,
#  45900000.0,
#  1774800000.0,
#  202400000.0,
#  560800000.0,
#  29600000.0,
#  4000000.0,
#  477600000.0,
#  1540000000.0,
#  8260000000.0,
#  332800000.0,
#  676000000.0,
#  61600000.0,
#  269100000.0,
#  328600000.0,
#  28281107.0,
#  940900000.0,
#  275700000.0,
#  378100000.0,
#  500000.0,
#  51700000.0,
#  32500000.0,
#  160500000.0,
#  2022900000.0,
#  762100000.0,
#  115700000.0,
#  45300000.0,
#  57300000.0,
#  112100000.0,
#  111800000.0,
#  80200000.0,
#  3400000.0,
#  12848200000.0,
#  105800000.0,
#  240200000.0,
#  67400000.0,
#  48200000.0,
#  5385800000.0,
#  722900000.0,
#  517200000.0,
#  106100000.0,
#  322.0,
#  104000000.0,
#  22400000.0,
#  0.0175,
#  243100000.0,
#  1023900000.0,
#  70300000.0,
#  896000.0,
#  6300000.0,
#  63900000.0,
#  12700000.0,
#  302200000.0,
#  44700000.0,
#  166300000.0,
#  93800000.0,
#  707000000.0,
#  91700000.0,
#  47600000.0,
#  316400000.0,
#  1289200000.0,
#  2800000.0,
#  27970800000.0,
#  124400000.0,
#  169200000.0,
#  2722800000.0,
#  34800000.0,
#  89300000.0,
#  86900000.0,
#  2544800000.0,
#  4388000000.0,
#  410000.0,
#  5868100000.0,
#  24900000.0,
#  114500000.0,
#  1541700000.0,
#  108100000.0,
#  127300000.0,
#  268100000.0,
#  1375300000.0,
#  18500000.0,
#  56900000.0,
#  1101300000.0,
#  77300000.0,
#  77000000.0,
#  281200000.0,
#  17611183.0,
#  1507900000.0,
#  892300000.0,
#  149400000.0,
#  9467800000.0,
#  341400000.0,
#  2200000.0,
#  8600000.0,
#  15000000.0,
#  40600000.0,
#  610200000.0,
#  399000000.0,
#  6907800000.0,
#  273100000.0,
#  64400000.0,
#  0.1,
#  675800000.0,
#  600300000.0,
#  30700000.0,
#  5100000.0,
#  5118700000.0,
#  0.0242,
#  0.0725,
#  6993900000.0,
#  4248300000.0,
#  0.0241,
#  4209900000.0,
#  1082100000.0,
#  58100000.0,
#  0.01,
#  4358000000.0,
#  259000000.0,
#  258400000.0,
#  5275200000.0,
#  14400000.0,
#  232000000.0,
#  552000000.0,
#  8334400000.0,
#  1600000.0,
#  219200000.0,
#  2318400000.0,
#  155200000.0,
#  2184000000.0,
#  50000000.0,
#  48500000.0,
#  254200000.0,
#  454500000.0,
#  17162900000.0,
#  10900000.0,
#  17367700000.0,
#  446100000.0,
#  5233300000.0,
#  4222100000.0,
#  4500000.0,
#  247700000.0,
#  241300000.0,
#  42900000.0,
#  40400000.0,
#  36200000.0,
#  855400000.0,
#  34400000.0,
#  33800000.0,
#  4333400000.0,
#  340200000.0,
#  20200000.0,
#  1000000.0,
#  97000000.0,
#  378600000.0,
#  794600000.0,
#  45800000.0,
#  77800000.0,
#  58600000.0,
#  13800000.0,
#  234100000.0,
#  29000000.0,
#  437100000.0,
#  0.0386,
#  25700000.0,
#  24200000.0,
#  35900000.0,
#  55100000.0,
#  1943100000.0,
#  74300000.0,
#  1379900000.0,
#  3402300000.0,
#  170300000.0,
#  3900000.0,
#  195900000.0,
#  23100000.0,
#  19700000.0,
#  224200000.0,
#  223900000.0,
#  3090500000.0,
#  17300000.0,
#  629.0,
#  14000000.0,
#  13400000.0,
#  1395600000.0,
#  27059600000.0,
#  205200000.0,
#  8301200000.0,
#  1030800000.0,
#  973200000.0,
#  12800000.0,
#  912000.0,
#  27058824.0,
#  400000.0,
#  11600000.0,
#  10100000.0,
#  11300000.0,
#  334004879.0,
#  6800000.0,
#  209500000.0,
#  4400000.0,
#  16100000.0,
#  169700000.0,
#  1046500000.0,
#  502500000.0,
#  201700000.0,
#  22500000.0,
#  9700000.0,
#  3300000.0,
#  35300000.0,
#  323300000.0,
#  3200000.0,
#  25600000.0,
#  19450200000.0,
#  121400000.0,
#  6200000.0,
#  19000000.0,
#  319800000.0,
#  883000000.0,
#  1055800000.0,
#  4409400000.0,
#  25400000.0,
#  12600000.0,
#  761400000.0,
#  605300000.0,
#  2700000.0,
#  105100000.0,
#  1372300000.0,
#  169100000.0,
#  53900000.0,
#  41100000.0,
#  21900000.0,
#  5122700000.0,
#  393100000.0,
#  130700000.0,
#  750.0,
#  182500000.0,
#  181300000.0,
#  965600000.0,
#  1100000000.0,
#  172000000.0,
#  3608800000.0,
#  18400000.0,
#  12000000.0,
#  63200000.0,
#  31200000.0,
#  127200000.0,
#  5600000.0,
#  2224500000.0,
#  95000.0,
#  341300000.0,
#  14900000.0,
#  46900000.0,
#  110900000.0,
#  98100000.0,
#  8500000.0,
#  366900000.0,
#  40500000.0,
#  2100000.0,
#  251700000.0,
#  169600000.0,
#  0.0375,
#  163000000.0,
#  10571400000.0,
#  1477000000.0,
#  113800000.0,
#  2539400000.0,
#  4158600000.0,
#  1880200000.0,
#  1643400000.0,
#  1310600000.0,
#  160000000.0,
#  11400000.0,
#  33500000.0,
#  59100000.0,
#  27100000.0,
#  5940700000.0,
#  1500000.0,
#  1697500000.0,
#  116700000.0,
#  590300000.0,
#  1581900000.0,
#  349800000.0,
#  554600000.0,
#  551600000.0,
#  6039600000.0,
#  11620400000.0,
#  55600000.0,
#  23600000.0,
#  10800000.0,
#  20350000000.0,
#  478000000.0,
#  30000000.0,
#  261000.0,
#  138400000.0,
#  133000000.0,
#  1770200000.0,
#  916100000.0,
#  1421700000.0,
#  3143300000.0,
#  900000.0,
#  39300000.0,
#  26500000.0,
#  7300000.0,
#  1690500000.0,
#  58500000.0,
#  128500000.0,
#  333000000.0,
#  124900000.0,
#  739300000.0,
#  3000.0,
#  327600000.0,
#  48600000.0,
#  183000000.0,
#  99800000.0,
#  208600000.0,
#  106200000.0,
#  3800000.0,
#  10200000.0,
#  355800000.0,
#  170200000.0,
#  983000000.0,
#  102700000.0,
#  0.02,
#  1619500000.0,
#  15584300000.0,
#  160300000.0,
#  4781100000.0,
#  1113900000.0,
#  300000.0,
#  19500000.0,
#  70700000.0,
#  224300000.0,
#  4617600000.0,
#  112000000.0,
#  315000000.0,
#  311700000.0,
#  106300000.0,
#  665300000.0,
#  104200000.0,
#  41600000.0,
#  16000000.0,
#  1.1,
#  3.07,
#  2.72,
#  208000000.0,
#  9600000.0,
#  48000000.0,
#  0.81,
#  14396800000.0,
#  1.2266,
#  95200000.0,
#  0.0638,
#  94300000.0,
#  1030100000.0,
#  697300000.0,
#  16274900000.0,
#  249300000.0,
#  38100000.0,
#  12500000.0,
#  6100000.0,
#  18900000.0,
#  1574100000.0,
#  498900000.0,
#  294900000.0,
#  500000000.0,
#  89500000.0,
#  292500000.0,
#  50900000.0,
#  85300000.0,
#  335400000.0,
#  34600000.0,
#  111400000.0,
#  83200000.0,
#  0.0688,
#  687400000.0,
#  9000000.0,
#  7157800000.0,
#  81700000.0,
#  81100000.0,
#  76300000.0,
#  280200000.0,
#  333036637.0,
#  4587900000.0,
#  376700000.0,
#  683900000.0,
#  75900000.0,
#  5500000.0,
#  37500000.0,
#  971900000.0,
#  171900000.0,
#  389500000.0,
#  395900000.0,
#  482600000.0,
#  2323400000.0,
#  70000000.0,
#  274500000.0,
#  69400000.0,
#  0.03,
#  68200000.0,
#  67300000.0,
#  2729100000.0,
#  1500000000.0,
#  885600000.0,
#  65800000.0,
#  4469200000.0,
#  2000000.0,
#  21826000000.0,
#  14800000.0,
#  66000000.0,
#  27600000.0,
#  34000000.0,
#  110800000.0,
#  194000000.0,
#  64000000.0,
#  264000000.0,
#  57100000.0,
#  7428700000.0,
#  1867300000.0,
#  504100000.0,
#  254500000.0,
#  6091300000.0,
#  9752100000.0,
#  4900000.0,
#  376100000.0,
#  171300000.0,
#  5163300000.0,
#  3384100000.0,
#  50800000.0,
#  49300000.0,
#  250800000.0,
#  39800000.0,
#  1479800000.0,
#  46200000.0,
#  1108600000.0,
#  910200000.0,
#  327800000.0,
#  1400000.0,
#  14200000.0,
#  379000000.0,
#  7825100000.0,
#  44200000.0,
#  43000000.0,
#  7505100000.0,
#  2269900000.0,
#  618700000.0,
#  241100000.0,
#  17100000.0,
#  989900000.0,
#  100300000.0,
#  119500000.0,
#  33100000.0,
#  548300000.0,
#  30400000.0,
#  28300000.0,
#  641800000.0,
#  26800000.0,
#  800000.0,
#  0.82,
#  128800000.0,
#  333600000.0,
#  487200000.0,
#  4768800000.0,
#  365600000.0,
#  32800000.0,
#  20000000.0,
#  23500000.0,
#  3300000000.0,
#  23800000.0,
#  1046600000.0,
#  20800000.0,
#  225600000.0,
#  415000.0,
#  17500000.0,
#  16900000.0,
#  746100000.0,
#  80500000.0,
#  419700000.0,
#  355700000.0,
#  854900000.0,
#  2512500000.0,
#  54900000.0,
#  3700000.0,
#  208500000.0,
#  2269300000.0,
#  13300000.0,
#  13900000.0,
#  13600000.0,
#  11800000.0,
#  10600000.0,
#  10300000.0,
#  8800000.0,
#  335672637.0,
#  7000000.0,
#  3705800000.0,
#  32200000.0,
#  200000.0,
#  3827400000.0,
#  211200000.0,
#  115400000.0,
#  275400000.0,
#  16800000000.0,
#  6400000.0,
#  6600000.0,
#  4300000.0,
#  5200000.0,
#  415100000.0,
#  3100000.0,
#  41500000.0,
#  15900000.0,
#  9500000.0,
#  303900000.0,
#  111900000.0,
#  182300000.0,
#  540700000.0,
#  131100000.0,
#  0.07,
#  0.0075,
#  1628600000.0,
#  604000000.0,
#  398000000.0,
#  4338800000.0,
#  12400000.0,
#  25200000.0,
#  6000000.0,
#  1676400000.0,
#  582000000.0,
#  18800000.0,
#  2412400000.0,
#  44400000.0,
#  2310000000.0,
#  1128900000.0,
#  2500000.0,
#  34500000.0,
#  15300000.0,
#  40900000.0,
#  66500000.0,
#  4316100000.0,
#  597431.0,
#  1813900000.0,
#  789600000.0,
#  380000000.0,
#  907800000.0,
#  581400000.0,
#  3717400000.0,
#  63000000.0,
#  5400000.0,
#  1234200000.0,
#  18400000000.0,
#  101400000.0,
#  2091800000.0,
#  165400000.0,
#  40300000.0,
#  981100000.0,
#  1141100000.0,
#  891500000.0,
#  14700000.0,
#  309100000.0,
#  4949100000.0,
#  27500000.0,
#  520300000.0,
#  1900000.0,
#  155700000.0,
#  6298800000.0,
#  62400000.0,
#  132800000.0,
#  1.11,
#  5233600000.0,
#  228800000.0,
#  465600000.0,
#  4800000.0,
#  11200000.0,
#  24000000.0,
#  600000000.0,
#  1584800000.0,
#  1130000.0,
#  966800000.0,
#  556300000.0,
#  7706.0,
#  350000000.0,
#  97300000.0,
#  1300000.0,
#  186900000.0,
#  116500000.0,
#  33300000.0,
#  71700000.0,
#  398100000.0,
#  7700000.0,
#  129300000.0,
#  20007200000.0,
#  139800000.0,
#  138900000.0,
#  547900000.0,
#  343400000.0,
#  1501800000.0,
#  4439400000.0,
#  119400000.0,
#  221800000.0,
#  17000000.0,
#  49000000.0,
#  74600000.0,
#  23400000.0,
#  1629800000.0,
#  0.0675,
#  320.0,
#  700000.0,
#  19900000.0,
#  7100000.0,
#  2899900000.0,
#  13500000.0,
#  883900000.0,
#  0.075,
#  123000000.0,
#  401000.0,
#  323900000.0,
#  16675600000.0,
#  10000000.0,
#  982800000.0,
#  54800000.0,
#  3600000.0,
#  726800000.0,
#  650000000.0,
#  10378000000.0,
#  170000000.0,
#  109200000.0,
#  518200000.0,
#  38500000.0,
#  345700000.0,
#  428900000.0,
#  70500000.0,
#  1248100000.0,
#  211300000.0,
#  32100000.0,
#  100000.0,
#  876900000.0,
#  2144100000.0,
#  103500000.0,
#  102300000.0,
#  8700000000.0,
#  97200000.0,
#  15800000.0,
#  60600000.0,
#  22200000.0,
#  988600000.0,
#  35000000.0,
#  233400000.0,
#  26915000000.0,
#  41400000.0,
#  2371000000.0,
#  3000000.0,
#  28878538.0,
#  0.0988,
#  87000000.0,
#  44300000.0,
#  5983500000.0,
#  5900000.0,
#  3193100000.0,
#  498700000.0,
#  18700000.0,
#  69900000.0,
#  12300000.0,
#  225000.0,
#  1605900000.0,
#  2950000000.0,
#  898100000.0,
#  78600000.0,
#  78000000.0,
#  2319200000.0,
#  2300000000.0,
#  15200000.0,
#  124000000.0,
#  1506400000.0,
#  335200000.0,
#  808800000.0,
#  0.83,
#  277600000.0,
#  9628000000.0,
#  75000000.0,
#  1915800000.0,
#  273500000.0,
#  1605300000.0,
#  542900000.0,
#  4613300000.0,
#  1374900000.0,
#  178100000.0,
#  66600000.0,
#  37300000.0,
#  64500000.0,
#  64200000.0,
#  94000.0,
#  60000000.0,
#  58800000.0,
#  468400000.0,
#  545800000.0,
#  2056200000.0,
#  8200000.0,
#  1800000.0,
#  27400000.0,
#  1800200000.0,
#  21000000.0,
#  53000000.0,
#  25749000000.0,
#  129800000.0,
#  670800000.0,
#  56700000.0,
#  243200000.0,
#  261200000.0,
#  0.0563,
#  52800000.0,
#  4700000.0,
#  113500000.0,
#  23900000.0,
#  22737500000.0,
#  36700000.0,
#  439900000.0,
#  932700000.0,
#  267100000.0,
#  11100000.0,
#  43100000.0,
#  46800000.0,
#  47400000.0,
#  45000000.0,
#  861100000.0,
#  39600000.0,
#  122800000.0,
#  2433200000.0,
#  1200000.0,
#  276400000.0,
#  20400000.0,
#  1300400000.0,
#  33200000.0,
#  334000000.0,
#  321200000.0,
#  35700000.0,
#  36000000.0,
#  239000000.0,
#  33600000.0,
#  32400000.0,
#  30600000.0,
#  30300000.0,
#  1054300000.0,
#  93700000.0,
#  157700000.0,
#  4413700000.0,
#  61700000.0,
#  439300000.0,
#  4100000.0,
#  29100000.0,
#  228100000.0,
#  125700000.0,
#  10500000.0,
#  25800000.0,
#  5235800000.0,
#  96600000.0,
#  600000.0,
#  1479000000.0,
#  2407000000.0,
#  327000000.0,
#  1088600000.0,
#  10554200000.0,
#  147800000.0,
#  2221400000.0,
#  837500000.0,
#  16200000.0,
#  18300000.0,
#  15600000.0,
#  18000000.0,
#  3500000.0,
#  1993900000.0,
#  7165100000.0,
#  656300000.0,
#  195500000.0,
#  419200000.0,
#  35500000.0,
#  8400000.0,
#  259500000.0,
#  1142700000.0,
#  6900000.0,
#  7800000.0,
#  7200000.0,
#  5700000.0,
#  4200000.0,
#  2400000.0]

# %%
def first_digit(number):
    return int(str(number)[0])

# %%
benford_valeant = [first_digit(num) for num in valeant_nums] 
len(benford_valeant)
# Out:
# 890

# %%
def frequencies(first_digits):
    counts = [0]*10
    for x in first_digits:
        counts[x] += 1 
    total = sum(counts)
    freq = [count/total for count in counts]
    return freq[1:] #same as going from element 1 through the end (i.e. 9)

# %%
frequencies(benford_valeant)
# Out:
# [0.2910112359550562,
#  0.16741573033707866,
#  0.13595505617977527,
#  0.09550561797752809,
#  0.08426966292134831,
#  0.06629213483146068,
#  0.048314606741573035,
#  0.04269662921348315,
#  0.043820224719101124]

# %%
import math
r = range(10)
benfords_law = [math.log10(1 + 1/digit) for digit in r if digit != 0]
benfords_law
# Out:
# [0.3010299956639812,
#  0.17609125905568124,
#  0.12493873660829993,
#  0.09691001300805642,
#  0.07918124604762482,
#  0.06694678963061322,
#  0.05799194697768673,
#  0.05115252244738129,
#  0.04575749056067514]

# %%
import plotly

plotly.offline.init_notebook_mode(connected=True)
Benfords_Law = {'type': 'scatter', 'x': list(range(1, 10)), 'y': benfords_law}
Valeant = {'type': 'scatter', 'x': list(range(1, 10)), 'y': frequencies(benford_valeant)}


plotly.offline.iplot([Benfords_Law, Valeant])
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="3f87fe77-e0d8-4fcc-acd9-865392d621ee" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3f87fe77-e0d8-4fcc-acd9-865392d621ee", [{"x": [1, 2, 3, 4, 5, 6, 7, 8, 9], "y": [0.3010299956639812, 0.17609125905568124, 0.12493873660829993, 0.09691001300805642, 0.07918124604762482, 0.06694678963061322, 0.05799194697768673, 0.05115252244738129, 0.04575749056067514], "type": "scatter", "uid": "aad7fdeb-f2d6-4e09-8014-9c6c1f234a7a"}, {"x": [1, 2, 3, 4, 5, 6, 7, 8, 9], "y": [0.2910112359550562, 0.16741573033707866, 0.13595505617977527, 0.09550561797752809, 0.08426966292134831, 0.06629213483146068, 0.048314606741573035, 0.04269662921348315, 0.043820224719101124], "type": "scatter", "uid": "bae8fead-71d5-4b28-87a9-8600aef8cd27"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("3f87fe77-e0d8-4fcc-acd9-865392d621ee"));});</script>

# %%
# q414numbers.join(s.apply(lambda x: x.split('-')))

# %%
# q414numbers= q414numbers.drop('adsh', axis=1).join(s.reset_index(drop=True, level=1).rename(['0'],['1'],['2']))

# %%
# q414numbers.head()

# %%
import numpy as np
import random
def p_value(freq):
    n = sum(freq)
    ps = [(math.log(d+1) - math.log(d)) / math.log(10) for d in range(1, 10)]

    ks_obs = freq[1:]

    def ll(ks): # log-likelihood
        z = random.sample(zip(ks, ps), 8)
        return sum([k * math.log(p) for (k, p) in z])

    N = 10000
    P = 0
    for i in range(N):
        ks = np.random.multinomial(n, ps)
        if ll(ks) > ll(ks_obs): P += 1

# %%
p_value(benford_valeant)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-ca619871505f> in <module>
# ----> 1 p_value(benford_valeant)
#
# <ipython-input-59-19aaad0d63cd> in p_value(freq)
#      15     for i in range(N):
#      16         ks = np.random.multinomial(n, ps)
# ---> 17         if ll(ks) > ll(ks_obs): P += 1
#
# <ipython-input-59-19aaad0d63cd> in ll(ks)
#       8
#       9     def ll(ks): # log-likelihood
# ---> 10         z = random.sample(zip(ks, ps), 8)
#      11         return sum([k * math.log(p) for (k, p) in z])
#      12
#
# /anaconda3/lib/python3.6/random.py in sample(self, population, k)
#     314             population = tuple(population)
#     315         if not isinstance(population, _Sequence):
# --> 316             raise TypeError("Population must be a sequence or set.  For dicts, use list(d).")
#     317         randbelow = self._randbelow
#     318         n = len(population)
#
# TypeError: Population must be a sequence or set.  For dicts, use list(d).

# %%
ks_obs = freq[1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-388d0522a393> in <module>
# ----> 1 ks_obs = freq[1:]
#
# NameError: name 'freq' is not defined
