# %% [markdown]
# ### Final Project Requirements/notes: https://docs.google.com/document/d/1mwYbYJHkB7kpx4tNflKh54jN9_oOscw3p4k5fsmn3bc/edit

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %% [markdown]
# ### Link with all Data: https://www.sec.gov/dera/data/financial-statement-data-sets.html
# - using NUM file only for now (data set of all numeric XBRL facts presented on the primary financial statements)

# %% [markdown]
# # 1. Combine frauds data with NonFraud data

# %%
frauds = pd.read_csv('fraudsJoinedwithmaster.csv')
qtrs=sorted(frauds.related_qtr.unique().tolist())
len(qtrs) #missing 2q16, will import that df
# Out:
# 35

# %%
frauds.head()
# Out:
#                    adsh               comp_name related_qtr filing_type  \
# 0  0000023082-10-000036  COMPUTER SCIENCES CORP        2q10         10k
# 1  0000023082-10-000036  COMPUTER SCIENCES CORP        2q10         10k
# 2  0000023082-10-000036  COMPUTER SCIENCES CORP        2q10         10k
# 3  0000023082-10-000036  COMPUTER SCIENCES CORP        2q10         10k
# 4  0000023082-10-000036  COMPUTER SCIENCES CORP        2q10         10k
#
#    fraud                                                tag       version  \
# 0      1                             AccountsPayableCurrent  us-gaap/2009
# 1      1                             AccountsPayableCurrent  us-gaap/2009
# 2      1                          AccruedLiabilitiesCurrent  us-gaap/2009
# 3      1                          AccruedLiabilitiesCurrent  us-gaap/2009
# 4      1  AccumulatedDepreciationDepletionAndAmortizatio...  us-gaap/2009
#
#         ddate  qtrs  uom         value
# 0  20090331.0   0.0  USD  6.360000e+08
# 1  20100331.0   0.0  USD  4.090000e+08
# 2  20090331.0   0.0  USD  1.264000e+09
# 3  20100331.0   0.0  USD  1.344000e+09
# 4  20090331.0   0.0  USD -3.417000e+09

# %%
frauds.isnull().sum()
# Out:
# adsh            0
# comp_name       0
# related_qtr     0
# filing_type     0
# fraud           0
# tag            62
# version        62
# ddate          62
# qtrs           62
# uom            62
# value          62
# dtype: int64

# %%
frauds = frauds.dropna()

# %%
df = pd.read_csv('numsbyquarter/2018q1/num.txt', sep='\t',encoding ='latin1')
df.head()
# Out:
#                    adsh                tag   version coreg     ddate  qtrs  \
# 0  0001683168-18-000002  EntityPublicFloat  dei/2014   NaN  20160630     0
# 1  0001562762-17-000231  EntityPublicFloat  dei/2014   NaN  20170331     0
# 2  0001599916-18-000002  EntityPublicFloat  dei/2014   NaN  20171231     0
# 3  0001614106-18-000003  EntityPublicFloat  dei/2014   NaN  20161231     0
# 4  0001144204-18-000327  EntityPublicFloat  dei/2014   NaN  20170331     0
#
#    uom       value footnote
# 0  USD   3200000.0      NaN
# 1  USD  28500000.0      NaN
# 2  USD    253660.0      NaN
# 3  USD     18247.0      NaN
# 4  USD  23466799.0      NaN

# %%
df.shape
# Out:
# (3030131, 9)

# %%
df.isnull().sum()
# Out:
# adsh              0
# tag               0
# version           0
# coreg       2865204
# ddate             0
# qtrs              0
# uom               0
# value         50173
# footnote    3023631
# dtype: int64

# %%
df = df.drop(columns=['footnote','coreg'])
df = df.dropna()
df.shape
# Out:
# (2979958, 7)

# %%
testfrauds = frauds['adsh']
dftest = df['adsh']

# %%
# testfrauds = testfrauds.set_index(['adsh'])
# dftest = dftest.set_index(['adsh'])

# %%
dftest.head()
# Out:
# 0    0001683168-18-000002
# 1    0001562762-17-000231
# 2    0001599916-18-000002
# 3    0001614106-18-000003
# 4    0001144204-18-000327
# Name: adsh, dtype: object

# %%
testfrauds.head()
# Out:
# 0    0000023082-10-000036
# 1    0000023082-10-000036
# 2    0000023082-10-000036
# 3    0000023082-10-000036
# 4    0000023082-10-000036
# Name: adsh, dtype: object

# %%
result = dftest[dftest.isin(testfrauds)]
result
# Out:
# Series([], Name: adsh, dtype: object)

# %%
combined = frauds.append(df)

# %%
combined.shape
# Out:
# (3040863, 11)

# %%
combined = combined.drop(columns=['comp_name','filing_type','related_qtr'])

# %%
combined.isnull().sum()
# Out:
# adsh             0
# ddate            0
# fraud      2979958
# qtrs             0
# tag              0
# uom              0
# value            0
# version          0
# dtype: int64

# %%
combined = combined.fillna(0)

# %%
combined.isnull().sum()
# Out:
# adsh       0
# ddate      0
# fraud      0
# qtrs       0
# tag        0
# uom        0
# value      0
# version    0
# dtype: int64

# %%
combined.head()
# Out:
#                    adsh       ddate  fraud  qtrs  \
# 0  0000023082-10-000036  20090331.0    1.0   0.0
# 1  0000023082-10-000036  20100331.0    1.0   0.0
# 2  0000023082-10-000036  20090331.0    1.0   0.0
# 3  0000023082-10-000036  20100331.0    1.0   0.0
# 4  0000023082-10-000036  20090331.0    1.0   0.0
#
#                                                  tag  uom         value  \
# 0                             AccountsPayableCurrent  USD  6.360000e+08
# 1                             AccountsPayableCurrent  USD  4.090000e+08
# 2                          AccruedLiabilitiesCurrent  USD  1.264000e+09
# 3                          AccruedLiabilitiesCurrent  USD  1.344000e+09
# 4  AccumulatedDepreciationDepletionAndAmortizatio...  USD -3.417000e+09
#
#         version
# 0  us-gaap/2009
# 1  us-gaap/2009
# 2  us-gaap/2009
# 3  us-gaap/2009
# 4  us-gaap/2009

# %%
combined['tag'] = combined['tag'].str.lower()
combined['2ndindex'] = combined['tag']
combined = combined.set_index(['adsh', '2ndindex'])
combined = combined.loc[combined['uom'] == 'USD']
alltags = combined.tag.unique().tolist()
print(len(alltags))
# for i in allfraudtags:
#     print(i, len(frauds.loc[frauds['tag'] == i ]))
# Out:
# 132350

# %%
currentassets = "cash|commercialpaper|cashand|accountsrec|accountrec|receivable|inventor|asset|uncollectible|taxben|prepaid|fairval"
longtermassets = "land|building|lease|rental|equipment|machinery|depreciation|investment|intangible|longtermasset|trademark"
liabilities = "payable|short-term|borrowing|debt|liabilit|accrued|lineofcredit|provision|contingen"
shareholders = "othercompre|shareholder|controlling|equity|retained|stock"
income = "revenue|product|services|grossprofit|income|loss|incomeloss|proceeds"
expenses = "costof|costsof|research|expense|services|admin|gainon|cost|paid|compensat|charge"

combined = combined.set_value(combined.loc[combined['tag'].
                                                                str.contains(currentassets)].
                                            index, 'tag', 'CurrentAssets')

combined = combined.set_value(combined.loc[combined['tag'].
                                                                str.contains(longtermassets)].
                                            index, 'tag', 'LongtermAssets')


combined = combined.set_value(combined.loc[combined['tag'].
                                                                str.contains('goodwill')].
                                            index, 'tag', 'Goodwill')

combined = combined.set_value(combined.loc[combined['tag'].
                                                                str.contains(liabilities)].
                                            index, 'tag', 'Liabilities')


combined = combined.set_value(combined.loc[combined['tag'].
                                                                str.contains(shareholders)].
                                            index, 'tag', 'ShareholdersEquity')


combined = combined.set_value(combined.loc[combined['tag'].
                                                                str.contains(income)].
                                            index, 'tag', 'Income')


combined = combined.set_value(combined.loc[combined['tag'].
                                                                str.contains(expenses)].
                                            index, 'tag', 'Expenses')

# %%
remainingtags = combined.tag.unique().tolist()
print(len(remainingtags))
# Out:
# 26709

# %%
combined.head()
# Out:
#                                                                               ddate  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                              20090331.0
#                      accountspayablecurrent                              20100331.0
#                      accruedliabilitiescurrent                           20090331.0
#                      accruedliabilitiescurrent                           20100331.0
#                      accumulateddepreciationdepletionandamortization...  20090331.0
#
#                                                                          fraud  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                                1.0
#                      accountspayablecurrent                                1.0
#                      accruedliabilitiescurrent                             1.0
#                      accruedliabilitiescurrent                             1.0
#                      accumulateddepreciationdepletionandamortization...    1.0
#
#                                                                          qtrs  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                               0.0
#                      accountspayablecurrent                               0.0
#                      accruedliabilitiescurrent                            0.0
#                      accruedliabilitiescurrent                            0.0
#                      accumulateddepreciationdepletionandamortization...   0.0
#
#                                                                                     tag  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                                 Liabilities
#                      accountspayablecurrent                                 Liabilities
#                      accruedliabilitiescurrent                              Liabilities
#                      accruedliabilitiescurrent                              Liabilities
#                      accumulateddepreciationdepletionandamortization...  LongtermAssets
#
#                                                                          uom  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                              USD
#                      accountspayablecurrent                              USD
#                      accruedliabilitiescurrent                           USD
#                      accruedliabilitiescurrent                           USD
#                      accumulateddepreciationdepletionandamortization...  USD
#
#                                                                                 value  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                              6.360000e+08
#                      accountspayablecurrent                              4.090000e+08
#                      accruedliabilitiescurrent                           1.264000e+09
#                      accruedliabilitiescurrent                           1.344000e+09
#                      accumulateddepreciationdepletionandamortization... -3.417000e+09
#
#                                                                               version
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                              us-gaap/2009
#                      accountspayablecurrent                              us-gaap/2009
#                      accruedliabilitiescurrent                           us-gaap/2009
#                      accruedliabilitiescurrent                           us-gaap/2009
#                      accumulateddepreciationdepletionandamortization...  us-gaap/2009

# %%
combined.to_csv('combined_df_bucketed_tags.csv')

# %%
bucket_tags = ['CurrentAssets','LongtermAssets','Goodwill','Liabilities','ShareholdersEquity','Income','Expenses']

# %%
bucket_df = combined[combined['tag'].isin(['CurrentAssets','LongtermAssets','Goodwill','Liabilities','ShareholdersEquity','Income','Expenses'])]

# %%
bucket_df
# Out:
#                                                                               ddate  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                              20090331.0
#                      accountspayablecurrent                              20100331.0
#                      accruedliabilitiescurrent                           20090331.0
#                      accruedliabilitiescurrent                           20100331.0
#                      accumulateddepreciationdepletionandamortization...  20090331.0
#                      accumulateddepreciationdepletionandamortization...  20100331.0
#                      accumulatedothercomprehensiveincomelossnetoftax     20090331.0
#                      accumulatedothercomprehensiveincomelossnetoftax     20100331.0
#                      additionalpaidincapital                             20090331.0
#                      additionalpaidincapital                             20100331.0
#                      allowancefordoubtfulaccountsreceivablecurrent       20090331.0
#                      allowancefordoubtfulaccountsreceivablecurrent       20100331.0
#                      assets                                              20090331.0
#                      assets                                              20100331.0
#                      assetscurrent                                       20090331.0
#                      assetscurrent                                       20100331.0
#                      cashandcashequivalentsatcarryingvalue               20070331.0
#                      cashandcashequivalentsatcarryingvalue               20080331.0
#                      cashandcashequivalentsatcarryingvalue               20090331.0
#                      cashandcashequivalentsatcarryingvalue               20100331.0
#                      cashandcashequivalentsperiodincreasedecrease        20080331.0
#                      cashandcashequivalentsperiodincreasedecrease        20090331.0
#                      cashandcashequivalentsperiodincreasedecrease        20100331.0
#                      commonstockvalue                                    20090331.0
#                      commonstockvalue                                    20100331.0
#                      costofservices                                      20080331.0
#                      costofservices                                      20090331.0
#                      costofservices                                      20100331.0
#                      debtcurrent                                         20090331.0
#                      debtcurrent                                         20100331.0
# ...                                                                             ...
# 0001493152-18-004278 capitalizedcostsofprovedpropertiesbeingamortiza...  20161231.0
#                      capitalizedcostsofprovedpropertiesbeingamortiza...  20171231.0
#                      capitalizedcostsofprovedpropertiesoilandgasprod...  20161231.0
#                      capitalizedcostsofprovedpropertiesoilandgasprod...  20171231.0
#                      changesinproductionratesandother                    20161231.0
#                      changesinproductionratesandother                    20171231.0
#                      conversionofseriesandseriesbpreferredstocktocom...  20171231.0
#                      costsnotbeingamortized                              20161231.0
#                      costsnotbeingamortized                              20171231.0
#                      costssubjecttoamortization                          20161231.0
#                      costssubjecttoamortization                          20171231.0
#                      debtdiscountfromissuanceofwarrantsasdebtinducement  20171231.0
#                      developmentcostsnotsubjecttoamortization            20171231.0
#                      earningspershareeffectofsharebasedcompensatione...  20161231.0
#                      earningspershareeffectofsharebasedcompensatione...  20171231.0
#                      increaseinreserveforpluggingandabandonmentcosts     20161231.0
#                      increaseinreserveforpluggingandabandonmentcosts     20171231.0
#                      investmentindevelopmentofoilandgasproperties        20171231.0
#                      sharebasedcompensationarrangementbysharebasedpa...  20171231.0
# 0001564590-18-007187 accountspayableandaccruedexpenses                   20171231.0
#                      dealermanagerfeeexpenses                            20171231.0
#                      dispositionfeesonprincipalamountofdebt              20161231.0
#                      dispositionfeesonprincipalamountofdebt              20171231.0
#                      noncashdistributionreinvestment                     20171231.0
#                      noncashdistributionspayable                         20171231.0
#                      operatingsupportfromadviseracquisitionexpenses      20161231.0
#                      operatingsupportfromadviseracquisitionexpenses      20171231.0
#                      relatedpartytransactionfeesandexpensespaid          20171231.0
# 0001683168-18-000821 goodwillsandindefinitelivedintangibles              20161231.0
#                      goodwillsandindefinitelivedintangibles              20171231.0
#
#                                                                          fraud  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                                1.0
#                      accountspayablecurrent                                1.0
#                      accruedliabilitiescurrent                             1.0
#                      accruedliabilitiescurrent                             1.0
#                      accumulateddepreciationdepletionandamortization...    1.0
#                      accumulateddepreciationdepletionandamortization...    1.0
#                      accumulatedothercomprehensiveincomelossnetoftax       1.0
#                      accumulatedothercomprehensiveincomelossnetoftax       1.0
#                      additionalpaidincapital                               1.0
#                      additionalpaidincapital                               1.0
#                      allowancefordoubtfulaccountsreceivablecurrent         1.0
#                      allowancefordoubtfulaccountsreceivablecurrent         1.0
#                      assets                                                1.0
#                      assets                                                1.0
#                      assetscurrent                                         1.0
#                      assetscurrent                                         1.0
#                      cashandcashequivalentsatcarryingvalue                 1.0
#                      cashandcashequivalentsatcarryingvalue                 1.0
#                      cashandcashequivalentsatcarryingvalue                 1.0
#                      cashandcashequivalentsatcarryingvalue                 1.0
#                      cashandcashequivalentsperiodincreasedecrease          1.0
#                      cashandcashequivalentsperiodincreasedecrease          1.0
#                      cashandcashequivalentsperiodincreasedecrease          1.0
#                      commonstockvalue                                      1.0
#                      commonstockvalue                                      1.0
#                      costofservices                                        1.0
#                      costofservices                                        1.0
#                      costofservices                                        1.0
#                      debtcurrent                                           1.0
#                      debtcurrent                                           1.0
# ...                                                                        ...
# 0001493152-18-004278 capitalizedcostsofprovedpropertiesbeingamortiza...    0.0
#                      capitalizedcostsofprovedpropertiesbeingamortiza...    0.0
#                      capitalizedcostsofprovedpropertiesoilandgasprod...    0.0
#                      capitalizedcostsofprovedpropertiesoilandgasprod...    0.0
#                      changesinproductionratesandother                      0.0
#                      changesinproductionratesandother                      0.0
#                      conversionofseriesandseriesbpreferredstocktocom...    0.0
#                      costsnotbeingamortized                                0.0
#                      costsnotbeingamortized                                0.0
#                      costssubjecttoamortization                            0.0
#                      costssubjecttoamortization                            0.0
#                      debtdiscountfromissuanceofwarrantsasdebtinducement    0.0
#                      developmentcostsnotsubjecttoamortization              0.0
#                      earningspershareeffectofsharebasedcompensatione...    0.0
#                      earningspershareeffectofsharebasedcompensatione...    0.0
#                      increaseinreserveforpluggingandabandonmentcosts       0.0
#                      increaseinreserveforpluggingandabandonmentcosts       0.0
#                      investmentindevelopmentofoilandgasproperties          0.0
#                      sharebasedcompensationarrangementbysharebasedpa...    0.0
# 0001564590-18-007187 accountspayableandaccruedexpenses                     0.0
#                      dealermanagerfeeexpenses                              0.0
#                      dispositionfeesonprincipalamountofdebt                0.0
#                      dispositionfeesonprincipalamountofdebt                0.0
#                      noncashdistributionreinvestment                       0.0
#                      noncashdistributionspayable                           0.0
#                      operatingsupportfromadviseracquisitionexpenses        0.0
#                      operatingsupportfromadviseracquisitionexpenses        0.0
#                      relatedpartytransactionfeesandexpensespaid            0.0
# 0001683168-18-000821 goodwillsandindefinitelivedintangibles                0.0
#                      goodwillsandindefinitelivedintangibles                0.0
#
#                                                                          qtrs  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                               0.0
#                      accountspayablecurrent                               0.0
#                      accruedliabilitiescurrent                            0.0
#                      accruedliabilitiescurrent                            0.0
#                      accumulateddepreciationdepletionandamortization...   0.0
#                      accumulateddepreciationdepletionandamortization...   0.0
#                      accumulatedothercomprehensiveincomelossnetoftax      0.0
#                      accumulatedothercomprehensiveincomelossnetoftax      0.0
#                      additionalpaidincapital                              0.0
#                      additionalpaidincapital                              0.0
#                      allowancefordoubtfulaccountsreceivablecurrent        0.0
#                      allowancefordoubtfulaccountsreceivablecurrent        0.0
#                      assets                                               0.0
#                      assets                                               0.0
#                      assetscurrent                                        0.0
#                      assetscurrent                                        0.0
#                      cashandcashequivalentsatcarryingvalue                0.0
#                      cashandcashequivalentsatcarryingvalue                0.0
#                      cashandcashequivalentsatcarryingvalue                0.0
#                      cashandcashequivalentsatcarryingvalue                0.0
#                      cashandcashequivalentsperiodincreasedecrease         4.0
#                      cashandcashequivalentsperiodincreasedecrease         4.0
#                      cashandcashequivalentsperiodincreasedecrease         4.0
#                      commonstockvalue                                     0.0
#                      commonstockvalue                                     0.0
#                      costofservices                                       4.0
#                      costofservices                                       4.0
#                      costofservices                                       4.0
#                      debtcurrent                                          0.0
#                      debtcurrent                                          0.0
# ...                                                                       ...
# 0001493152-18-004278 capitalizedcostsofprovedpropertiesbeingamortiza...   0.0
#                      capitalizedcostsofprovedpropertiesbeingamortiza...   0.0
#                      capitalizedcostsofprovedpropertiesoilandgasprod...   0.0
#                      capitalizedcostsofprovedpropertiesoilandgasprod...   0.0
#                      changesinproductionratesandother                     4.0
#                      changesinproductionratesandother                     4.0
#                      conversionofseriesandseriesbpreferredstocktocom...   4.0
#                      costsnotbeingamortized                               0.0
#                      costsnotbeingamortized                               0.0
#                      costssubjecttoamortization                           0.0
#                      costssubjecttoamortization                           0.0
#                      debtdiscountfromissuanceofwarrantsasdebtinducement   4.0
#                      developmentcostsnotsubjecttoamortization             4.0
#                      earningspershareeffectofsharebasedcompensatione...   4.0
#                      earningspershareeffectofsharebasedcompensatione...   4.0
#                      increaseinreserveforpluggingandabandonmentcosts      4.0
#                      increaseinreserveforpluggingandabandonmentcosts      4.0
#                      investmentindevelopmentofoilandgasproperties         4.0
#                      sharebasedcompensationarrangementbysharebasedpa...   0.0
# 0001564590-18-007187 accountspayableandaccruedexpenses                    0.0
#                      dealermanagerfeeexpenses                             4.0
#                      dispositionfeesonprincipalamountofdebt               4.0
#                      dispositionfeesonprincipalamountofdebt               4.0
#                      noncashdistributionreinvestment                      4.0
#                      noncashdistributionspayable                          4.0
#                      operatingsupportfromadviseracquisitionexpenses       4.0
#                      operatingsupportfromadviseracquisitionexpenses       4.0
#                      relatedpartytransactionfeesandexpensespaid           4.0
# 0001683168-18-000821 goodwillsandindefinitelivedintangibles               0.0
#                      goodwillsandindefinitelivedintangibles               0.0
#
#                                                                                         tag  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                                     Liabilities
#                      accountspayablecurrent                                     Liabilities
#                      accruedliabilitiescurrent                                  Liabilities
#                      accruedliabilitiescurrent                                  Liabilities
#                      accumulateddepreciationdepletionandamortization...      LongtermAssets
#                      accumulateddepreciationdepletionandamortization...      LongtermAssets
#                      accumulatedothercomprehensiveincomelossnetoftax     ShareholdersEquity
#                      accumulatedothercomprehensiveincomelossnetoftax     ShareholdersEquity
#                      additionalpaidincapital                                       Expenses
#                      additionalpaidincapital                                       Expenses
#                      allowancefordoubtfulaccountsreceivablecurrent            CurrentAssets
#                      allowancefordoubtfulaccountsreceivablecurrent            CurrentAssets
#                      assets                                                   CurrentAssets
#                      assets                                                   CurrentAssets
#                      assetscurrent                                            CurrentAssets
#                      assetscurrent                                            CurrentAssets
#                      cashandcashequivalentsatcarryingvalue                    CurrentAssets
#                      cashandcashequivalentsatcarryingvalue                    CurrentAssets
#                      cashandcashequivalentsatcarryingvalue                    CurrentAssets
#                      cashandcashequivalentsatcarryingvalue                    CurrentAssets
#                      cashandcashequivalentsperiodincreasedecrease             CurrentAssets
#                      cashandcashequivalentsperiodincreasedecrease             CurrentAssets
#                      cashandcashequivalentsperiodincreasedecrease             CurrentAssets
#                      commonstockvalue                                    ShareholdersEquity
#                      commonstockvalue                                    ShareholdersEquity
#                      costofservices                                                  Income
#                      costofservices                                                  Income
#                      costofservices                                                  Income
#                      debtcurrent                                                Liabilities
#                      debtcurrent                                                Liabilities
# ...                                                                                     ...
# 0001493152-18-004278 capitalizedcostsofprovedpropertiesbeingamortiza...            Expenses
#                      capitalizedcostsofprovedpropertiesbeingamortiza...            Expenses
#                      capitalizedcostsofprovedpropertiesoilandgasprod...      LongtermAssets
#                      capitalizedcostsofprovedpropertiesoilandgasprod...      LongtermAssets
#                      changesinproductionratesandother                                Income
#                      changesinproductionratesandother                                Income
#                      conversionofseriesandseriesbpreferredstocktocom...  ShareholdersEquity
#                      costsnotbeingamortized                                        Expenses
#                      costsnotbeingamortized                                        Expenses
#                      costssubjecttoamortization                                    Expenses
#                      costssubjecttoamortization                                    Expenses
#                      debtdiscountfromissuanceofwarrantsasdebtinducement         Liabilities
#                      developmentcostsnotsubjecttoamortization                      Expenses
#                      earningspershareeffectofsharebasedcompensatione...            Expenses
#                      earningspershareeffectofsharebasedcompensatione...            Expenses
#                      increaseinreserveforpluggingandabandonmentcosts               Expenses
#                      increaseinreserveforpluggingandabandonmentcosts               Expenses
#                      investmentindevelopmentofoilandgasproperties            LongtermAssets
#                      sharebasedcompensationarrangementbysharebasedpa...            Expenses
# 0001564590-18-007187 accountspayableandaccruedexpenses                          Liabilities
#                      dealermanagerfeeexpenses                                      Expenses
#                      dispositionfeesonprincipalamountofdebt                     Liabilities
#                      dispositionfeesonprincipalamountofdebt                     Liabilities
#                      noncashdistributionreinvestment                          CurrentAssets
#                      noncashdistributionspayable                              CurrentAssets
#                      operatingsupportfromadviseracquisitionexpenses                Expenses
#                      operatingsupportfromadviseracquisitionexpenses                Expenses
#                      relatedpartytransactionfeesandexpensespaid                    Expenses
# 0001683168-18-000821 goodwillsandindefinitelivedintangibles                  LongtermAssets
#                      goodwillsandindefinitelivedintangibles                  LongtermAssets
#
#                                                                          uom  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                              USD
#                      accountspayablecurrent                              USD
#                      accruedliabilitiescurrent                           USD
#                      accruedliabilitiescurrent                           USD
#                      accumulateddepreciationdepletionandamortization...  USD
#                      accumulateddepreciationdepletionandamortization...  USD
#                      accumulatedothercomprehensiveincomelossnetoftax     USD
#                      accumulatedothercomprehensiveincomelossnetoftax     USD
#                      additionalpaidincapital                             USD
#                      additionalpaidincapital                             USD
#                      allowancefordoubtfulaccountsreceivablecurrent       USD
#                      allowancefordoubtfulaccountsreceivablecurrent       USD
#                      assets                                              USD
#                      assets                                              USD
#                      assetscurrent                                       USD
#                      assetscurrent                                       USD
#                      cashandcashequivalentsatcarryingvalue               USD
#                      cashandcashequivalentsatcarryingvalue               USD
#                      cashandcashequivalentsatcarryingvalue               USD
#                      cashandcashequivalentsatcarryingvalue               USD
#                      cashandcashequivalentsperiodincreasedecrease        USD
#                      cashandcashequivalentsperiodincreasedecrease        USD
#                      cashandcashequivalentsperiodincreasedecrease        USD
#                      commonstockvalue                                    USD
#                      commonstockvalue                                    USD
#                      costofservices                                      USD
#                      costofservices                                      USD
#                      costofservices                                      USD
#                      debtcurrent                                         USD
#                      debtcurrent                                         USD
# ...                                                                      ...
# 0001493152-18-004278 capitalizedcostsofprovedpropertiesbeingamortiza...  USD
#                      capitalizedcostsofprovedpropertiesbeingamortiza...  USD
#                      capitalizedcostsofprovedpropertiesoilandgasprod...  USD
#                      capitalizedcostsofprovedpropertiesoilandgasprod...  USD
#                      changesinproductionratesandother                    USD
#                      changesinproductionratesandother                    USD
#                      conversionofseriesandseriesbpreferredstocktocom...  USD
#                      costsnotbeingamortized                              USD
#                      costsnotbeingamortized                              USD
#                      costssubjecttoamortization                          USD
#                      costssubjecttoamortization                          USD
#                      debtdiscountfromissuanceofwarrantsasdebtinducement  USD
#                      developmentcostsnotsubjecttoamortization            USD
#                      earningspershareeffectofsharebasedcompensatione...  USD
#                      earningspershareeffectofsharebasedcompensatione...  USD
#                      increaseinreserveforpluggingandabandonmentcosts     USD
#                      increaseinreserveforpluggingandabandonmentcosts     USD
#                      investmentindevelopmentofoilandgasproperties        USD
#                      sharebasedcompensationarrangementbysharebasedpa...  USD
# 0001564590-18-007187 accountspayableandaccruedexpenses                   USD
#                      dealermanagerfeeexpenses                            USD
#                      dispositionfeesonprincipalamountofdebt              USD
#                      dispositionfeesonprincipalamountofdebt              USD
#                      noncashdistributionreinvestment                     USD
#                      noncashdistributionspayable                         USD
#                      operatingsupportfromadviseracquisitionexpenses      USD
#                      operatingsupportfromadviseracquisitionexpenses      USD
#                      relatedpartytransactionfeesandexpensespaid          USD
# 0001683168-18-000821 goodwillsandindefinitelivedintangibles              USD
#                      goodwillsandindefinitelivedintangibles              USD
#
#                                                                                 value  \
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                              6.360000e+08
#                      accountspayablecurrent                              4.090000e+08
#                      accruedliabilitiescurrent                           1.264000e+09
#                      accruedliabilitiescurrent                           1.344000e+09
#                      accumulateddepreciationdepletionandamortization... -3.417000e+09
#                      accumulateddepreciationdepletionandamortization... -3.731000e+09
#                      accumulatedothercomprehensiveincomelossnetoftax    -1.004000e+09
#                      accumulatedothercomprehensiveincomelossnetoftax    -1.052000e+09
#                      additionalpaidincapital                             1.836000e+09
#                      additionalpaidincapital                             2.006000e+09
#                      allowancefordoubtfulaccountsreceivablecurrent       3.786000e+09
#                      allowancefordoubtfulaccountsreceivablecurrent       3.849000e+09
#                      assets                                              1.561900e+10
#                      assets                                              1.645500e+10
#                      assetscurrent                                       7.707000e+09
#                      assetscurrent                                       8.422000e+09
#                      cashandcashequivalentsatcarryingvalue               1.050000e+09
#                      cashandcashequivalentsatcarryingvalue               6.990000e+08
#                      cashandcashequivalentsatcarryingvalue               2.297000e+09
#                      cashandcashequivalentsatcarryingvalue               2.784000e+09
#                      cashandcashequivalentsperiodincreasedecrease       -3.510000e+08
#                      cashandcashequivalentsperiodincreasedecrease        1.598000e+09
#                      cashandcashequivalentsperiodincreasedecrease        4.870000e+08
#                      commonstockvalue                                    1.600000e+08
#                      commonstockvalue                                    1.620000e+08
#                      costofservices                                      1.315000e+10
#                      costofservices                                      1.326800e+10
#                      costofservices                                      1.279700e+10
#                      debtcurrent                                         6.200000e+07
#                      debtcurrent                                         7.500000e+07
# ...                                                                               ...
# 0001493152-18-004278 capitalizedcostsofprovedpropertiesbeingamortiza...  5.563933e+07
#                      capitalizedcostsofprovedpropertiesbeingamortiza...  6.013953e+07
#                      capitalizedcostsofprovedpropertiesoilandgasprod...  1.656350e+05
#                      capitalizedcostsofprovedpropertiesoilandgasprod...  4.504450e+06
#                      changesinproductionratesandother                    1.434900e+05
#                      changesinproductionratesandother                    5.379629e+06
#                      conversionofseriesandseriesbpreferredstocktocom...  1.650000e+02
#                      costsnotbeingamortized                              2.291181e+06
#                      costsnotbeingamortized                              2.309341e+06
#                      costssubjecttoamortization                          5.563933e+07
#                      costssubjecttoamortization                          6.013953e+07
#                      debtdiscountfromissuanceofwarrantsasdebtinducement  1.287340e+05
#                      developmentcostsnotsubjecttoamortization            2.515400e+04
#                      earningspershareeffectofsharebasedcompensatione...  0.000000e+00
#                      earningspershareeffectofsharebasedcompensatione...  0.000000e+00
#                      increaseinreserveforpluggingandabandonmentcosts     1.630000e+03
#                      increaseinreserveforpluggingandabandonmentcosts     6.000000e+03
#                      investmentindevelopmentofoilandgasproperties        4.512353e+06
#                      sharebasedcompensationarrangementbysharebasedpa...  4.400000e-01
# 0001564590-18-007187 accountspayableandaccruedexpenses                   2.900710e+05
#                      dealermanagerfeeexpenses                            5.440790e+05
#                      dispositionfeesonprincipalamountofdebt              0.000000e+00
#                      dispositionfeesonprincipalamountofdebt              0.000000e+00
#                      noncashdistributionreinvestment                     5.558000e+04
#                      noncashdistributionspayable                         1.011740e+05
#                      operatingsupportfromadviseracquisitionexpenses      0.000000e+00
#                      operatingsupportfromadviseracquisitionexpenses      0.000000e+00
#                      relatedpartytransactionfeesandexpensespaid          8.072290e+05
# 0001683168-18-000821 goodwillsandindefinitelivedintangibles              1.406800e+07
#                      goodwillsandindefinitelivedintangibles              1.406800e+07
#
#                                                                                       version
# adsh                 2ndindex
# 0000023082-10-000036 accountspayablecurrent                                      us-gaap/2009
#                      accountspayablecurrent                                      us-gaap/2009
#                      accruedliabilitiescurrent                                   us-gaap/2009
#                      accruedliabilitiescurrent                                   us-gaap/2009
#                      accumulateddepreciationdepletionandamortization...          us-gaap/2009
#                      accumulateddepreciationdepletionandamortization...          us-gaap/2009
#                      accumulatedothercomprehensiveincomelossnetoftax             us-gaap/2009
#                      accumulatedothercomprehensiveincomelossnetoftax             us-gaap/2009
#                      additionalpaidincapital                                     us-gaap/2009
#                      additionalpaidincapital                                     us-gaap/2009
#                      allowancefordoubtfulaccountsreceivablecurrent               us-gaap/2009
#                      allowancefordoubtfulaccountsreceivablecurrent               us-gaap/2009
#                      assets                                                      us-gaap/2009
#                      assets                                                      us-gaap/2009
#                      assetscurrent                                               us-gaap/2009
#                      assetscurrent                                               us-gaap/2009
#                      cashandcashequivalentsatcarryingvalue                       us-gaap/2009
#                      cashandcashequivalentsatcarryingvalue                       us-gaap/2009
#                      cashandcashequivalentsatcarryingvalue                       us-gaap/2009
#                      cashandcashequivalentsatcarryingvalue                       us-gaap/2009
#                      cashandcashequivalentsperiodincreasedecrease                us-gaap/2009
#                      cashandcashequivalentsperiodincreasedecrease                us-gaap/2009
#                      cashandcashequivalentsperiodincreasedecrease                us-gaap/2009
#                      commonstockvalue                                            us-gaap/2009
#                      commonstockvalue                                            us-gaap/2009
#                      costofservices                                              us-gaap/2009
#                      costofservices                                              us-gaap/2009
#                      costofservices                                              us-gaap/2009
#                      debtcurrent                                                 us-gaap/2009
#                      debtcurrent                                                 us-gaap/2009
# ...                                                                                       ...
# 0001493152-18-004278 capitalizedcostsofprovedpropertiesbeingamortiza...  0001493152-18-004278
#                      capitalizedcostsofprovedpropertiesbeingamortiza...  0001493152-18-004278
#                      capitalizedcostsofprovedpropertiesoilandgasprod...  0001493152-18-004278
#                      capitalizedcostsofprovedpropertiesoilandgasprod...  0001493152-18-004278
#                      changesinproductionratesandother                    0001493152-18-004278
#                      changesinproductionratesandother                    0001493152-18-004278
#                      conversionofseriesandseriesbpreferredstocktocom...  0001493152-18-004278
#                      costsnotbeingamortized                              0001493152-18-004278
#                      costsnotbeingamortized                              0001493152-18-004278
#                      costssubjecttoamortization                          0001493152-18-004278
#                      costssubjecttoamortization                          0001493152-18-004278
#                      debtdiscountfromissuanceofwarrantsasdebtinducement  0001493152-18-004278
#                      developmentcostsnotsubjecttoamortization            0001493152-18-004278
#                      earningspershareeffectofsharebasedcompensatione...  0001493152-18-004278
#                      earningspershareeffectofsharebasedcompensatione...  0001493152-18-004278
#                      increaseinreserveforpluggingandabandonmentcosts     0001493152-18-004278
#                      increaseinreserveforpluggingandabandonmentcosts     0001493152-18-004278
#                      investmentindevelopmentofoilandgasproperties        0001493152-18-004278
#                      sharebasedcompensationarrangementbysharebasedpa...  0001493152-18-004278
# 0001564590-18-007187 accountspayableandaccruedexpenses                   0001564590-18-007187
#                      dealermanagerfeeexpenses                            0001564590-18-007187
#                      dispositionfeesonprincipalamountofdebt              0001564590-18-007187
#                      dispositionfeesonprincipalamountofdebt              0001564590-18-007187
#                      noncashdistributionreinvestment                     0001564590-18-007187
#                      noncashdistributionspayable                         0001564590-18-007187
#                      operatingsupportfromadviseracquisitionexpenses      0001564590-18-007187
#                      operatingsupportfromadviseracquisitionexpenses      0001564590-18-007187
#                      relatedpartytransactionfeesandexpensespaid          0001564590-18-007187
# 0001683168-18-000821 goodwillsandindefinitelivedintangibles              0001683168-18-000821
#                      goodwillsandindefinitelivedintangibles              0001683168-18-000821
#
# [2359177 rows x 7 columns]

# %%
for i in bucket_tags:
    print(i, len(combined.loc[combined['tag'] == i ]))
# Out:
# CurrentAssets 665082
# LongtermAssets 275662
# Goodwill 19144
# Liabilities 326122
# ShareholdersEquity 323017
# Income 490626
# Expenses 259524

# %%
len(bucket_df.index.unique())
# Out:
# 952672

# %%
bucket_df.to_csv('combined_df_filtered_for_7_tags.csv')

# %%
df = pd.read_csv('combined_df_filtered_for_7_tags.csv')

# %%
len(df.adsh.unique())
# Out:
# 6034

# %%
fraudsters = df.loc[df.fraud == 1]

# %%
len(fraudsters.adsh.unique())
# Out:
# 121

# %%
nonfrauds = df.loc[df.fraud == 0]
len(nonfrauds.adsh.unique())
# Out:
# 5913

# %%
121/6034
# Out:
# 0.020053032814053694

# %%
df.head()
# Out:
#                    adsh                                           2ndindex  \
# 0  0000023082-10-000036                             accountspayablecurrent
# 1  0000023082-10-000036                             accountspayablecurrent
# 2  0000023082-10-000036                          accruedliabilitiescurrent
# 3  0000023082-10-000036                          accruedliabilitiescurrent
# 4  0000023082-10-000036  accumulateddepreciationdepletionandamortizatio...
#
#         ddate  fraud  qtrs             tag  uom         value       version
# 0  20090331.0    1.0   0.0     Liabilities  USD  6.360000e+08  us-gaap/2009
# 1  20100331.0    1.0   0.0     Liabilities  USD  4.090000e+08  us-gaap/2009
# 2  20090331.0    1.0   0.0     Liabilities  USD  1.264000e+09  us-gaap/2009
# 3  20100331.0    1.0   0.0     Liabilities  USD  1.344000e+09  us-gaap/2009
# 4  20090331.0    1.0   0.0  LongtermAssets  USD -3.417000e+09  us-gaap/2009

# %%
df.describe(include = 'all')
# Out:
#                         adsh       2ndindex         ddate         fraud  \
# count                2359177        2359177  2.359177e+06  2.359177e+06
# unique                  6034         105648           NaN           NaN
# top     0001628280-18-001324  netincomeloss           NaN           NaN
# freq                    4775          35621           NaN           NaN
# mean                     NaN            NaN  2.016333e+07  2.237094e-02
# std                      NaN            NaN  1.040859e+04  1.478867e-01
# min                      NaN            NaN  1.985123e+07  0.000000e+00
# 25%                      NaN            NaN  2.016123e+07  0.000000e+00
# 50%                      NaN            NaN  2.016123e+07  0.000000e+00
# 75%                      NaN            NaN  2.017123e+07  0.000000e+00
# max                      NaN            NaN  2.037123e+07  1.000000e+00
#
#                 qtrs            tag      uom         value       version
# count   2.359177e+06        2359177  2359177  2.359177e+06       2359177
# unique           NaN              7        1           NaN          5773
# top              NaN  CurrentAssets      USD           NaN  us-gaap/2017
# freq             NaN         665082  2359177           NaN       1728233
# mean    2.161360e+00            NaN      NaN  8.305880e+08           NaN
# std     1.952828e+00            NaN      NaN  3.108051e+10           NaN
# min     0.000000e+00            NaN      NaN -4.200290e+11           NaN
# 25%     0.000000e+00            NaN      NaN  1.753000e+04           NaN
# 50%     3.000000e+00            NaN      NaN  3.900000e+06           NaN
# 75%     4.000000e+00            NaN      NaN  5.850000e+07           NaN
# max     1.520000e+02            NaN      NaN  1.646000e+13           NaN

# %%
df_for_pivot = df.drop(columns= ['2ndindex', 'qtrs', 'uom','version'])
df_for_pivot.head()
# Out:
#                    adsh       ddate  fraud             tag         value
# 0  0000023082-10-000036  20090331.0    1.0     Liabilities  6.360000e+08
# 1  0000023082-10-000036  20100331.0    1.0     Liabilities  4.090000e+08
# 2  0000023082-10-000036  20090331.0    1.0     Liabilities  1.264000e+09
# 3  0000023082-10-000036  20100331.0    1.0     Liabilities  1.344000e+09
# 4  0000023082-10-000036  20090331.0    1.0  LongtermAssets -3.417000e+09

# %%
df.value.sum()
# Out:
# 1959504099034806.2

# %%
bucket_tag_sum = 0
for i in bucket_tags:
    combined_pivot[i].sum() += bucket_tag_sum

bucket_tag_sum
# for i in bucket_tags:
#     print(i, len(combined.loc[combined['tag'] == i ]))
# Out:
#   File "<ipython-input-176-1640f319b351>", line 3
#     combined_pivot[i].sum() += bucket_tag_sum
#     ^
# SyntaxError: can't assign to function call

# %%
combined_pivot["CurrentAssets"].sum()
# Out:
# 671622798610447.0

# %%
combined_pivot = pd.pivot_table(df_for_pivot,index=['fraud',"adsh","ddate",], columns= ['tag'], values= ['value'], aggfunc='sum')
# explore2.head()

# %%
combined_pivot
# Out:
#                                               value                \
# tag                                   CurrentAssets      Expenses
# fraud adsh                 ddate
# 0.0   0000002178-18-000009 20141231.0  9.857100e+07           NaN
#                            20151231.0  1.026290e+08  3.847024e+09
#                            20160331.0           NaN           NaN
#                            20160630.0           NaN           NaN
#                            20160930.0           NaN           NaN
#                            20161231.0  7.170870e+08  2.229644e+09
#                            20170331.0           NaN           NaN
#                            20170430.0 -3.630000e+05  1.909000e+06
#                            20170531.0           NaN           NaN
#                            20170630.0           NaN           NaN
#                            20170831.0           NaN  4.000000e+05
#                            20170930.0           NaN           NaN
#                            20171231.0  8.748190e+08  2.633350e+09
#       0000002488-18-000042 20130930.0           NaN           NaN
#                            20141231.0  8.330000e+08           NaN
#                            20151231.0  1.140000e+09  4.681000e+09
#                            20160331.0           NaN  8.420000e+08
#                            20160630.0           NaN  9.850000e+08
#                            20160831.0           NaN           NaN
#                            20160930.0           NaN  1.548000e+09
#                            20161231.0  2.323400e+10  6.401000e+09
#                            20170331.0           NaN  9.510000e+08
#                            20170630.0           NaN  1.129000e+09
#                            20170930.0           NaN  1.416000e+09
#                            20171231.0  1.981400e+10  6.814000e+09
#       0000002969-18-000014 20160930.0  1.330800e+09           NaN
#                            20161231.0  1.917000e+08  1.501000e+08
#                            20170930.0  4.787950e+10  2.362000e+08
#                            20171231.0  4.587050e+10  6.261000e+08
#       0000003499-18-000006 20141231.0  6.248340e+08           NaN
# ...                                             ...           ...
# 1.0   0001193125-16-701058 20160630.0  3.665264e+10  2.874215e+09
#       0001193125-16-759676 20140930.0           NaN  1.290000e+07
#                            20141231.0  8.035220e+08           NaN
#                            20150930.0  2.915845e+09  3.957418e+09
#                            20151231.0  3.886842e+10           NaN
#                            20160430.0           NaN           NaN
#                            20160531.0  1.500000e+01           NaN
#                            20160731.0  1.500000e+01           NaN
#                            20160831.0           NaN           NaN
#                            20160930.0  3.965233e+10  3.844138e+09
#       0001354488-11-003677 20100430.0  2.994634e+06           NaN
#                            20100731.0 -3.011267e+06  9.661529e+06
#                            20110430.0  5.651878e+08  4.907666e+07
#                            20110731.0  6.084990e+08  7.047002e+07
#       0001354488-11-004960 20100430.0  2.994634e+06           NaN
#                            20101031.0 -2.972908e+06  3.286408e+07
#                            20110430.0  5.651878e+08  4.907666e+07
#                            20111031.0  6.022836e+08  1.210155e+08
#       0001354488-12-001090 20100430.0  2.994634e+06           NaN
#                            20110131.0  6.121031e+06  3.626925e+07
#                            20110430.0  5.651878e+08  4.907666e+07
#                            20120131.0  6.085809e+08  1.344342e+08
#       0001558370-15-002707 20131231.0  2.416000e+06           NaN
#                            20140331.0           NaN  2.212000e+06
#                            20140630.0           NaN  2.924000e+06
#                            20140930.0  2.002100e+07  6.296100e+07
#                            20141231.0  3.115510e+08  5.430800e+07
#                            20150331.0  4.165600e+07  4.290000e+06
#                            20150630.0  4.868400e+07  1.457400e+07
#                            20150930.0  3.661590e+08  1.289000e+08
#
#                                                                    \
# tag                                        Goodwill        Income
# fraud adsh                 ddate
# 0.0   0000002178-18-000009 20141231.0           NaN           NaN
#                            20151231.0           NaN  4.323837e+09
#                            20160331.0           NaN  2.543000e+08
#                            20160630.0           NaN  3.021680e+08
#                            20160930.0           NaN  2.529020e+08
#                            20161231.0           NaN  2.825005e+09
#                            20170331.0           NaN  3.006430e+08
#                            20170430.0           NaN -1.890000e+05
#                            20170531.0           NaN           NaN
#                            20170630.0           NaN  3.155390e+08
#                            20170831.0           NaN           NaN
#                            20170930.0           NaN  2.909880e+08
#                            20171231.0           NaN  3.258047e+09
#       0000002488-18-000042 20130930.0           NaN           NaN
#                            20141231.0           NaN           NaN
#                            20151231.0  4.764000e+09  7.003000e+09
#                            20160331.0           NaN  9.320000e+08
#                            20160630.0           NaN  1.612000e+09
#                            20160831.0           NaN           NaN
#                            20160930.0           NaN  6.320000e+08
#                            20161231.0  3.310000e+08  9.780000e+09
#                            20170331.0           NaN  1.240000e+09
#                            20170630.0           NaN  1.660000e+09
#                            20170930.0           NaN  2.429000e+09
#                            20171231.0  4.786000e+09  1.553200e+10
#       0000002969-18-000014 20160930.0           NaN           NaN
#                            20161231.0           NaN  4.711200e+09
#                            20170930.0  2.277400e+09           NaN
#                            20171231.0  2.521100e+09  5.733700e+09
#       0000003499-18-000006 20141231.0           NaN           NaN
# ...                                             ...           ...
# 1.0   0001193125-16-701058 20160630.0  5.623090e+09  1.865656e+10
#       0001193125-16-759676 20140930.0           NaN           NaN
#                            20141231.0           NaN           NaN
#                            20150930.0           NaN  2.871503e+10
#                            20151231.0  5.673830e+09           NaN
#                            20160430.0           NaN           NaN
#                            20160531.0           NaN           NaN
#                            20160731.0           NaN           NaN
#                            20160831.0           NaN           NaN
#                            20160930.0  5.611364e+09  2.360353e+10
#       0001354488-11-003677 20100430.0           NaN           NaN
#                            20100731.0           NaN  2.755392e+06
#                            20110430.0           NaN           NaN
#                            20110731.0           NaN  9.556433e+06
#       0001354488-11-004960 20100430.0           NaN           NaN
#                            20101031.0           NaN -7.104091e+06
#                            20110430.0           NaN           NaN
#                            20111031.0           NaN  7.471231e+06
#       0001354488-12-001090 20100430.0           NaN           NaN
#                            20110131.0           NaN  1.032372e+07
#                            20110430.0           NaN           NaN
#                            20120131.0           NaN -2.561384e+07
#       0001558370-15-002707 20131231.0           NaN           NaN
#                            20140331.0           NaN  1.728500e+07
#                            20140630.0           NaN  2.222800e+07
#                            20140930.0           NaN  1.116660e+08
#                            20141231.0           NaN  1.366500e+08
#                            20150331.0           NaN  3.483500e+07
#                            20150630.0           NaN  1.176170e+08
#                            20150930.0           NaN  3.121640e+08
#
#                                                                     \
# tag                                     Liabilities LongtermAssets
# fraud adsh                 ddate
# 0.0   0000002178-18-000009 20141231.0           NaN            NaN
#                            20151231.0 -8.742700e+07   9.504800e+07
#                            20160331.0           NaN  -3.000000e-02
#                            20160630.0           NaN  -3.000000e-02
#                            20160930.0           NaN  -2.800000e-01
#                            20161231.0  5.493170e+08   6.014220e+08
#                            20170331.0           NaN   0.000000e+00
#                            20170430.0           NaN   6.920000e+06
#                            20170531.0 -5.000000e+05            NaN
#                            20170630.0           NaN   0.000000e+00
#                            20170831.0           NaN            NaN
#                            20170930.0           NaN   0.000000e+00
#                            20171231.0  7.364500e+08   3.140450e+08
#       0000002488-18-000042 20130930.0           NaN   1.400000e+07
#                            20141231.0           NaN            NaN
#                            20151231.0 -8.500000e+07   2.480000e+08
#                            20160331.0           NaN   1.050000e+08
#                            20160630.0           NaN   1.140000e+08
#                            20160831.0  8.000000e+00            NaN
#                            20160930.0           NaN   1.120000e+08
#                            20161231.0  1.439400e+10   3.124000e+09
#                            20170331.0           NaN   1.190000e+08
#                            20170630.0           NaN   1.220000e+08
#                            20170930.0           NaN   1.300000e+08
#                            20171231.0  1.556200e+10   4.799000e+09
#       0000002969-18-000014 20160930.0           NaN            NaN
#                            20161231.0 -7.462000e+08   6.962000e+08
#                            20170930.0  3.949350e+10   4.573710e+10
#                            20171231.0  3.988480e+10   4.737430e+10
#       0000003499-18-000006 20141231.0           NaN   2.100250e+08
# ...                                             ...            ...
# 1.0   0001193125-16-701058 20160630.0  4.863927e+10   6.128858e+09
#       0001193125-16-759676 20140930.0           NaN            NaN
#                            20141231.0           NaN            NaN
#                            20150930.0  8.655307e+09   1.423790e+09
#                            20151231.0  5.136505e+10   4.545106e+09
#                            20160430.0  4.500000e+06            NaN
#                            20160531.0           NaN            NaN
#                            20160731.0           NaN            NaN
#                            20160831.0  2.200000e+06            NaN
#                            20160930.0  5.136879e+10   6.156941e+09
#       0001354488-11-003677 20100430.0           NaN            NaN
#                            20100731.0  1.266356e+06   1.077091e+07
#                            20110430.0  1.132805e+09   9.808433e+08
#                            20110731.0  1.213121e+09   1.019531e+09
#       0001354488-11-004960 20100430.0           NaN            NaN
#                            20101031.0  2.307960e+06   4.221868e+07
#                            20110430.0  1.132805e+09   9.808433e+08
#                            20111031.0  1.225114e+09   1.070458e+09
#       0001354488-12-001090 20100430.0           NaN            NaN
#                            20110131.0  9.558951e+06   6.957496e+07
#                            20110430.0  1.132805e+09   1.014962e+09
#                            20120131.0  1.242610e+09   1.207968e+09
#       0001558370-15-002707 20131231.0           NaN            NaN
#                            20140331.0           NaN            NaN
#                            20140630.0           NaN            NaN
#                            20140930.0  4.827000e+06   4.089100e+07
#                            20141231.0  2.091640e+08   1.440700e+07
#                            20150331.0  1.449800e+07   1.273600e+07
#                            20150630.0  1.283500e+07   4.079400e+07
#                            20150930.0  2.093980e+08   8.469000e+07
#
#
# tag                                   ShareholdersEquity
# fraud adsh                 ddate
# 0.0   0000002178-18-000009 20141231.0       1.574970e+08
#                            20151231.0       1.512350e+08
#                            20160331.0       1.554000e+06
#                            20160630.0       3.540000e+06
#                            20160930.0      -9.830000e+05
#                            20161231.0       2.947060e+08
#                            20170331.0      -8.600000e+05
#                            20170430.0                NaN
#                            20170531.0                NaN
#                            20170630.0      -2.820000e+05
#                            20170831.0                NaN
#                            20170930.0      -3.033000e+06
#                            20171231.0       2.857560e+08
#       0000002488-18-000042 20130930.0                NaN
#                            20141231.0       1.870000e+08
#                            20151231.0      -1.104000e+09
#                            20160331.0      -1.080000e+08
#                            20160630.0       1.010000e+08
#                            20160831.0                NaN
#                            20160930.0       2.930000e+08
#                            20161231.0       2.205000e+09
#                            20170331.0      -6.600000e+07
#                            20170630.0      -1.000000e+07
#                            20170930.0       9.200000e+07
#                            20171231.0       1.713000e+09
#       0000002969-18-000014 20160930.0       7.213400e+09
#                            20161231.0       8.099900e+09
#                            20170930.0       3.468490e+10
#                            20171231.0       3.702060e+10
#       0000003499-18-000006 20141231.0       3.483990e+08
# ...                                                  ...
# 1.0   0001193125-16-701058 20160630.0       1.804084e+10
#       0001193125-16-759676 20140930.0                NaN
#                            20141231.0                NaN
#                            20150930.0       9.181390e+08
#                            20151231.0       1.840255e+10
#                            20160430.0                NaN
#                            20160531.0                NaN
#                            20160731.0                NaN
#                            20160831.0                NaN
#                            20160930.0       1.846667e+10
#       0001354488-11-003677 20100430.0                NaN
#                            20100731.0      -1.327663e+06
#                            20110430.0       5.404700e+08
#                            20110731.0       5.438924e+08
#       0001354488-11-004960 20100430.0                NaN
#                            20101031.0      -1.270345e+07
#                            20110430.0       5.404700e+08
#                            20111031.0       5.255098e+08
#       0001354488-12-001090 20100430.0                NaN
#                            20110131.0      -8.405949e+06
#                            20110430.0       5.404700e+08
#                            20120131.0       5.024542e+08
#       0001558370-15-002707 20131231.0                NaN
#                            20140331.0      -1.365000e+06
#                            20140630.0      -1.885000e+06
#                            20140930.0      -4.740000e+05
#                            20141231.0       1.636090e+08
#                            20150331.0       8.466400e+07
#                            20150630.0       8.763500e+07
#                            20150930.0       1.698400e+08
#
# [48818 rows x 7 columns]

# %%
combined_pivot.to_excel('first_model_data.xls')

# %%
first_model= pd.read_csv('first_model_data.csv') #now tags_bucketed_for_first_model.csv

# %%
first_model
# Out:
#       Unnamed: 0            Unnamed: 1  Unnamed: 2          value  \
# 0            tag                   NaN         NaN  CurrentAssets
# 1          fraud                  adsh       ddate            NaN
# 2            0.0  0000002178-18-000009  20141231.0     98571000.0
# 3            0.0  0000002178-18-000009  20151231.0    102629000.0
# 4            0.0  0000002178-18-000009  20160331.0            NaN
# 5            0.0  0000002178-18-000009  20160630.0            NaN
# 6            0.0  0000002178-18-000009  20160930.0            NaN
# 7            0.0  0000002178-18-000009  20161231.0    717087000.0
# 8            0.0  0000002178-18-000009  20170331.0            NaN
# 9            0.0  0000002178-18-000009  20170430.0      -363000.0
# 10           0.0  0000002178-18-000009  20170531.0            NaN
# 11           0.0  0000002178-18-000009  20170630.0            NaN
# 12           0.0  0000002178-18-000009  20170831.0            NaN
# 13           0.0  0000002178-18-000009  20170930.0            NaN
# 14           0.0  0000002178-18-000009  20171231.0    874819000.0
# 15           0.0  0000002488-18-000042  20130930.0            NaN
# 16           0.0  0000002488-18-000042  20141231.0    833000000.0
# 17           0.0  0000002488-18-000042  20151231.0   1140000000.0
# 18           0.0  0000002488-18-000042  20160331.0            NaN
# 19           0.0  0000002488-18-000042  20160630.0            NaN
# 20           0.0  0000002488-18-000042  20160831.0            NaN
# 21           0.0  0000002488-18-000042  20160930.0            NaN
# 22           0.0  0000002488-18-000042  20161231.0  23234000000.0
# 23           0.0  0000002488-18-000042  20170331.0            NaN
# 24           0.0  0000002488-18-000042  20170630.0            NaN
# 25           0.0  0000002488-18-000042  20170930.0            NaN
# 26           0.0  0000002488-18-000042  20171231.0  19814000000.0
# 27           0.0  0000002969-18-000014  20160930.0   1330800000.0
# 28           0.0  0000002969-18-000014  20161231.0    191700000.0
# 29           0.0  0000002969-18-000014  20170930.0  47879500000.0
# ...          ...                   ...         ...            ...
# 48790        1.0  0001193125-16-701058  20160630.0  36652635000.0
# 48791        1.0  0001193125-16-759676  20140930.0            NaN
# 48792        1.0  0001193125-16-759676  20141231.0    803522000.0
# 48793        1.0  0001193125-16-759676  20150930.0   2915845000.0
# 48794        1.0  0001193125-16-759676  20151231.0  38868420000.0
# 48795        1.0  0001193125-16-759676  20160430.0            NaN
# 48796        1.0  0001193125-16-759676  20160531.0           15.0
# 48797        1.0  0001193125-16-759676  20160731.0           15.0
# 48798        1.0  0001193125-16-759676  20160831.0            NaN
# 48799        1.0  0001193125-16-759676  20160930.0  39652333000.0
# 48800        1.0  0001354488-11-003677  20100430.0      2994634.0
# 48801        1.0  0001354488-11-003677  20100731.0     -3011267.0
# 48802        1.0  0001354488-11-003677  20110430.0    565187848.0
# 48803        1.0  0001354488-11-003677  20110731.0    608499036.0
# 48804        1.0  0001354488-11-004960  20100430.0      2994634.0
# 48805        1.0  0001354488-11-004960  20101031.0     -2972908.0
# 48806        1.0  0001354488-11-004960  20110430.0    565187848.0
# 48807        1.0  0001354488-11-004960  20111031.0    602283564.0
# 48808        1.0  0001354488-12-001090  20100430.0      2994634.0
# 48809        1.0  0001354488-12-001090  20110131.0      6121031.0
# 48810        1.0  0001354488-12-001090  20110430.0    565187848.0
# 48811        1.0  0001354488-12-001090  20120131.0    608580921.0
# 48812        1.0  0001558370-15-002707  20131231.0      2416000.0
# 48813        1.0  0001558370-15-002707  20140331.0            NaN
# 48814        1.0  0001558370-15-002707  20140630.0            NaN
# 48815        1.0  0001558370-15-002707  20140930.0     20021000.0
# 48816        1.0  0001558370-15-002707  20141231.0    311551000.0
# 48817        1.0  0001558370-15-002707  20150331.0     41656000.0
# 48818        1.0  0001558370-15-002707  20150630.0     48684000.0
# 48819        1.0  0001558370-15-002707  20150930.0    366159000.0
#
#             value.1       value.2             value.3        value.4  \
# 0          Expenses      Goodwill              Income    Liabilities
# 1               NaN           NaN                 NaN            NaN
# 2               NaN           NaN                 NaN            NaN
# 3      3847024000.0           NaN        4323836999.7    -87427000.0
# 4               NaN           NaN        254300000.37            NaN
# 5               NaN           NaN        302168000.84            NaN
# 6               NaN           NaN        252901999.77            NaN
# 7      2229644000.0           NaN        2825005000.9    549317000.0
# 8               NaN           NaN         300642999.8            NaN
# 9         1909000.0           NaN           -189000.0            NaN
# 10              NaN           NaN                 NaN      -500000.0
# 11              NaN           NaN        315538999.93            NaN
# 12         400000.0           NaN                 NaN            NaN
# 13              NaN           NaN        290987999.28            NaN
# 14     2633350000.0           NaN       3258047000.77    736450000.0
# 15              NaN           NaN                 NaN            NaN
# 16              NaN           NaN                 NaN            NaN
# 17     4681000000.0  4764000000.0        7003000000.0    -85000000.0
# 18      842000000.0           NaN         932000000.0            NaN
# 19      985000000.0           NaN        1612000000.0            NaN
# 20              NaN           NaN                 NaN            8.0
# 21     1548000000.0           NaN         632000000.0            NaN
# 22     6401000000.0   331000000.0        9780000000.0  14394000000.0
# 23      951000000.0           NaN        1240000000.0            NaN
# 24     1129000000.0           NaN        1660000000.0            NaN
# 25     1416000000.0           NaN        2429000000.0            NaN
# 26     6814000000.0  4786000000.0       15532000000.0  15562000000.0
# 27              NaN           NaN                 NaN            NaN
# 28      150100000.0           NaN       4711200002.75   -746200000.0
# 29      236200000.0  2277400000.0                 NaN  39493500000.0
# ...             ...           ...                 ...            ...
# 48790  2874215000.0  5623090000.0       18656558997.8  48639273000.0
# 48791    12900000.0           NaN                 NaN            NaN
# 48792           NaN           NaN                 NaN            NaN
# 48793  3957418000.0           NaN  28715027006.989998   8655307000.0
# 48794           NaN  5673830000.0                 NaN  51365046000.0
# 48795           NaN           NaN                 NaN      4500000.0
# 48796           NaN           NaN                 NaN            NaN
# 48797           NaN           NaN                 NaN            NaN
# 48798           NaN           NaN                 NaN      2200000.0
# 48799  3844138000.0  5611364000.0      23603531999.48  51368789000.0
# 48800           NaN           NaN                 NaN            NaN
# 48801     9661529.0           NaN           2755392.0      1266356.0
# 48802    49076662.0           NaN                 NaN   1132805389.0
# 48803    70470016.0           NaN           9556433.0   1213120945.0
# 48804           NaN           NaN                 NaN            NaN
# 48805    32864085.0           NaN          -7104091.0      2307960.0
# 48806    49076662.0           NaN                 NaN   1132805389.0
# 48807   121015470.0           NaN           7471231.0   1225114284.0
# 48808           NaN           NaN                 NaN            NaN
# 48809    36269250.0           NaN          10323720.0      9558951.0
# 48810    49076662.0           NaN                 NaN   1132805389.0
# 48811   134434234.0           NaN         -25613840.0   1242609719.0
# 48812           NaN           NaN                 NaN            NaN
# 48813     2212000.0           NaN          17285000.0            NaN
# 48814     2924000.0           NaN          22228000.0            NaN
# 48815    62961000.0           NaN        111665999.88      4827000.0
# 48816    54308000.0           NaN         136650000.0    209164000.0
# 48817     4290000.0           NaN          34835000.0     14498000.0
# 48818    14574000.0           NaN         117617000.0     12835000.0
# 48819   128900000.0           NaN         312164000.0    209398000.0
#
#               value.5             value.6
# 0      LongtermAssets  ShareholdersEquity
# 1                 NaN                 NaN
# 2                 NaN         157497000.0
# 3          95048000.0        151235000.88
# 4               -0.03           1554000.0
# 5               -0.03           3540000.0
# 6               -0.28           -983000.0
# 7        601421999.66        294706001.98
# 8                 0.0           -860000.0
# 9           6920000.0                 NaN
# 10                NaN                 NaN
# 11                0.0           -282000.0
# 12                NaN                 NaN
# 13                0.0          -3033000.0
# 14        314045000.0        285756001.98
# 15         14000000.0                 NaN
# 16                NaN         187000000.0
# 17        248000000.0       -1104000000.0
# 18        105000000.0        -108000000.0
# 19        114000000.0         101000000.0
# 20                NaN                 NaN
# 21        112000000.0        293000000.01
# 22       3124000000.0       2205000000.01
# 23        119000000.0         -66000000.0
# 24        122000000.0         -10000000.0
# 25        130000000.0          92000000.0
# 26       4799000000.0  1713000000.0100002
# 27                NaN        7213400000.0
# 28        696200000.0       8099900000.86
# 29      45737100000.0       34684900001.0
# ...               ...                 ...
# 48790    6128858000.0     18040838000.002
# 48791             NaN                 NaN
# 48792             NaN                 NaN
# 48793    1423790000.0         918139000.0
# 48794    4545106000.0     18402550000.002
# 48795             NaN                 NaN
# 48796             NaN                 NaN
# 48797             NaN                 NaN
# 48798             NaN                 NaN
# 48799    6156941000.0     18466670000.002
# 48800             NaN                 NaN
# 48801      10770906.0          -1327663.0
# 48802     980843320.0      540469995.0001
# 48803    1019531329.0      543892357.0001
# 48804             NaN                 NaN
# 48805      42218681.0         -12703446.0
# 48806     980843320.0      540469995.0001
# 48807    1070457887.0      525509833.0001
# 48808             NaN                 NaN
# 48809      69574965.0          -8405949.0
# 48810    1014962472.0      540469995.0001
# 48811    1207968195.0      502454231.0001
# 48812             NaN                 NaN
# 48813             NaN          -1365000.0
# 48814             NaN          -1885000.0
# 48815      40891000.0           -474000.0
# 48816      14407000.0       163609000.001
# 48817      12736000.0          84664000.0
# 48818      40794000.0          87635000.0
# 48819      84690000.0  169840017.24100003
#
# [48820 rows x 10 columns]
