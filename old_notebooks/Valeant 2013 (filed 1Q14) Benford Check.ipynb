# %% [markdown]
# ### Final Project Requirements/notes: https://docs.google.com/document/d/1mwYbYJHkB7kpx4tNflKh54jN9_oOscw3p4k5fsmn3bc/edit

# %% [markdown]
# ### Link with all Data: https://www.sec.gov/dera/data/financial-statement-and-notes-data-set.html
# - using NUM file only for now (data set of all numeric XBRL facts presented on the primary financial statements)

# %%
import pandas as pd
q114numbers = pd.read_table('2014q1_notes/num.tsv', encoding ='latin1')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#get details on all columns
q114numbers.describe(include='all')
# Out:
#                         adsh                 tag       version         ddate  \
# count                8047269             8047269       8047269  8.047269e+06
# unique                  7161              364765          6984           NaN
# top     0001104659-14-010697  StockholdersEquity  us-gaap/2013           NaN
# freq                   25851               96149       5645985           NaN
# mean                     NaN                 NaN           NaN  2.012429e+07
# std                      NaN                 NaN           NaN  1.092064e+04
# min                      NaN                 NaN           NaN  1.963063e+07
# 25%                      NaN                 NaN           NaN  2.012123e+07
# 50%                      NaN                 NaN           NaN  2.013033e+07
# 75%                      NaN                 NaN           NaN  2.013123e+07
# max                      NaN                 NaN           NaN  2.048093e+07
#
#                 qtrs      uom        dimh          iprx         value  \
# count   8.047269e+06  8047269     8047269  7.397212e+06  7.813542e+06
# unique           NaN     3467      478982           NaN           NaN
# top              NaN      USD  0x00000000           NaN           NaN
# freq             NaN  6919631     3318312           NaN           NaN
# mean    1.970625e+00      NaN         NaN  9.592803e-04 -2.643271e+10
# std     3.300027e+00      NaN         NaN  4.284528e-02  8.658719e+13
# min     0.000000e+00      NaN         NaN  0.000000e+00 -2.420141e+17
# 25%     0.000000e+00      NaN         NaN  0.000000e+00  4.000000e-01
# 50%     1.000000e+00      NaN         NaN  0.000000e+00  1.100000e+06
# 75%     4.000000e+00      NaN         NaN  0.000000e+00  2.527600e+07
# max     1.860000e+02      NaN         NaN  1.100000e+01  1.335800e+15
#
#                                                  footnote       footlen  \
# count                                               32410  8.047269e+06
# unique                                              28014           NaN
# top     Fair value based on forward NYMEX natural gas ...           NaN
# freq                                                   21           NaN
# mean                                                  NaN  8.900422e-01
# std                                                   NaN  2.306192e+01
# min                                                   NaN  0.000000e+00
# 25%                                                   NaN  0.000000e+00
# 50%                                                   NaN  0.000000e+00
# 75%                                                   NaN  0.000000e+00
# max                                                   NaN  1.510300e+04
#
#                 dimn          coreg          durp          datp          dcml
# count   8.047269e+06         524781  7.397212e+06  7.397212e+06  7.397212e+06
# unique           NaN           7561           NaN           NaN           NaN
# top              NaN  ParentCompany           NaN           NaN           NaN
# freq             NaN         136050           NaN           NaN           NaN
# mean    8.271273e-01            NaN  1.627351e-03  1.064738e-01  1.737750e+03
# std     8.817800e-01            NaN  4.504874e-02  1.592975e+00  1.082029e+04
# min     0.000000e+00            NaN -4.986305e-01 -1.500000e+01 -3.276800e+04
# 25%     0.000000e+00            NaN  0.000000e+00  0.000000e+00 -3.000000e+00
# 50%     1.000000e+00            NaN  0.000000e+00  0.000000e+00 -3.000000e+00
# 75%     1.000000e+00            NaN  1.095891e-02  0.000000e+00  0.000000e+00
# max     8.000000e+00            NaN  4.986310e-01  1.500000e+01  3.276700e+04

# %% [markdown]
# ### From "Financial Statement and Notes Data Sets" Readme:
# These fields comprise a unique compound key:
#
# 1) **adsh - EDGAR accession number**: a unique identifier assigned automatically to an accepted submission by the EDGAR Filer System; The first set of numbers (0001193125) is the CIK of the entity submitting the filing. The next 2 numbers (18) represent the year. The last series of numbers represent a sequential count of submitted filings from that CIK. The count is usually, but not always, reset to 0 at the start of each calendar year.
# - **TODO**: separate these numbers to identify a company or a financial filing, there were 6,492 individual filings
#
# 2) **tag** - tag used by the filer
# - **TODO**: may have to separate out first word from tag to identify broader groups such as revenue
#
# 3) **version** – if a standard tag, the taxonomy of origin, otherwise equal to adsh.
#
# 4) **ddate** - period end date
#
# 5) **qtrs** - duration in number of quarters
#
# 6) **uom** - unit of measure
#
# 7) **dimh** - 16-byte dimensional qualifier
#
# 8) **iprx** - a sequential integer used to distinguish otherwise identical facts
#
# 9) **coreg** - If specified, indicates a specific co-registrant, the parent company, or other entity (e.g., guarantor).  NULL indicates the consolidated entity.  Note that this value is a function of the dimension segments.
#
# 10) **durp** - The difference between the reported fact duration and the quarter duration (qtrs), expressed as a fraction of 1.  For example, a fact with duration of 120 days rounded to a 91-day quarter has a durp value of 29/91 = +0.3187.
#
# 11) **datp** - The difference between the reported fact date and the month-end rounded date (ddate), expressed as a fraction of 1.  For example, a fact reported for 29/Dec, with ddate rounded to 31/Dec, has a datp value of minus 2/31 = -0.0645.
#
# 12) **dcml** - The value of the fact "decimals" attribute, with INF represented by 32767.

# %%
q114numbers.isnull().sum()
# Out:
# adsh              0
# tag               0
# version           0
# ddate             0
# qtrs              0
# uom               0
# dimh              0
# iprx         650057
# value        233727
# footnote    8014859
# footlen           0
# dimn              0
# coreg       7522488
# durp         650057
# datp         650057
# dcml         650057
# dtype: int64

# %% [markdown]
# #### A lot of null values for footnotes and coregistrants (majority of rows); will remove these columns for now

# %%
q114numbers = q114numbers.drop(columns=['footnote','coreg'])

# %%
q114numbers.isnull().sum()
# Out:
# adsh            0
# tag             0
# version         0
# ddate           0
# qtrs            0
# uom             0
# dimh            0
# iprx       650057
# value      233727
# footlen         0
# dimn            0
# durp       650057
# datp       650057
# dcml       650057
# dtype: int64

# %%
q114numbers = q114numbers.drop(columns=['iprx','durp','datp','dcml'])

# %% [markdown]
# #### Didn't get rid of blank Value fields, so just get rid of those since there will still be enough data points to analyze

# %%
q114numbers = q114numbers.dropna()

# %%
q114numbers.describe(include='all') #still have 7million+ data points
# Out:
#                         adsh                 tag       version         ddate  \
# count                7813542             7813542       7813542  7.813542e+06
# unique                  7161              363442          6982           NaN
# top     0001104659-14-010697  StockholdersEquity  us-gaap/2013           NaN
# freq                   25849               92920       5470777           NaN
# mean                     NaN                 NaN           NaN  2.012436e+07
# std                      NaN                 NaN           NaN  1.062755e+04
# min                      NaN                 NaN           NaN  1.963063e+07
# 25%                      NaN                 NaN           NaN  2.012123e+07
# 50%                      NaN                 NaN           NaN  2.013033e+07
# 75%                      NaN                 NaN           NaN  2.013123e+07
# max                      NaN                 NaN           NaN  2.048093e+07
#
#                 qtrs      uom        dimh         value       footlen  \
# count   7.813542e+06  7813542     7813542  7.813542e+06  7.813542e+06
# unique           NaN     3467      473091           NaN           NaN
# top              NaN      USD  0x00000000           NaN           NaN
# freq             NaN  6705184     3242279           NaN           NaN
# mean    1.964117e+00      NaN         NaN -2.643271e+10  9.017542e-01
# std     3.290258e+00      NaN         NaN  8.658719e+13  2.301161e+01
# min     0.000000e+00      NaN         NaN -2.420141e+17  0.000000e+00
# 25%     0.000000e+00      NaN         NaN  4.000000e-01  0.000000e+00
# 50%     1.000000e+00      NaN         NaN  1.100000e+06  0.000000e+00
# 75%     4.000000e+00      NaN         NaN  2.527600e+07  0.000000e+00
# max     1.860000e+02      NaN         NaN  1.335800e+15  1.510300e+04
#
#                 dimn
# count   7.813542e+06
# unique           NaN
# top              NaN
# freq             NaN
# mean    8.231845e-01
# std     8.812625e-01
# min     0.000000e+00
# 25%     0.000000e+00
# 50%     1.000000e+00
# 75%     1.000000e+00
# max     8.000000e+00

# %%
#break out adsh to cik and filing number
# s = q114numbers['adsh'].str.split('-', n = 1, expand = True)

# %%
# s.head()

# %%
# q114numbers['entity_CIK'] = s[0]
# q114numbers['filing_number'] = s[1]
# q114numbers.head()

# System; The first set of numbers (0001193125) is the CIK of the entity submitting the filing. 
# The next 2 numbers (18) represent the year. 
# The last series of numbers represent a sequential count of submitted filings from that CIK. 
# The count is usually, but not always, reset to 0 at the start of each calendar year.

# %%
# q414numbers = q414numbers.drop(columns =["adsh"], inplace = True)
# q414numbers = q414numbers.to_frame()

# %%
#Valeant's numbers
valeant_10k = q114numbers.loc[q114numbers['adsh'] == '0000885590-14-000025']
valeant_USD = valeant_10k.loc[valeant_10k['uom']== 'USD']
valeant_USD
# Out:
#                          adsh  \
# 76663    0000885590-14-000025
# 76664    0000885590-14-000025
# 76665    0000885590-14-000025
# 76666    0000885590-14-000025
# 76667    0000885590-14-000025
# 76668    0000885590-14-000025
# 76669    0000885590-14-000025
# 76670    0000885590-14-000025
# 76671    0000885590-14-000025
# 76695    0000885590-14-000025
# 76696    0000885590-14-000025
# 76697    0000885590-14-000025
# 76698    0000885590-14-000025
# 76699    0000885590-14-000025
# 76700    0000885590-14-000025
# 76701    0000885590-14-000025
# 76702    0000885590-14-000025
# 76703    0000885590-14-000025
# 76706    0000885590-14-000025
# 76707    0000885590-14-000025
# 76708    0000885590-14-000025
# 76709    0000885590-14-000025
# 76710    0000885590-14-000025
# 76711    0000885590-14-000025
# 76712    0000885590-14-000025
# 76713    0000885590-14-000025
# 76714    0000885590-14-000025
# 76715    0000885590-14-000025
# 76716    0000885590-14-000025
# 76717    0000885590-14-000025
# ...                       ...
# 6764461  0000885590-14-000025
# 6764462  0000885590-14-000025
# 6764463  0000885590-14-000025
# 6764464  0000885590-14-000025
# 6764465  0000885590-14-000025
# 6764466  0000885590-14-000025
# 6764467  0000885590-14-000025
# 6764468  0000885590-14-000025
# 6764469  0000885590-14-000025
# 6764470  0000885590-14-000025
# 6764471  0000885590-14-000025
# 6764474  0000885590-14-000025
# 6764475  0000885590-14-000025
# 6764476  0000885590-14-000025
# 6764477  0000885590-14-000025
# 6764478  0000885590-14-000025
# 6764479  0000885590-14-000025
# 6764480  0000885590-14-000025
# 6764481  0000885590-14-000025
# 6764482  0000885590-14-000025
# 6764483  0000885590-14-000025
# 6764484  0000885590-14-000025
# 6764485  0000885590-14-000025
# 6764486  0000885590-14-000025
# 6764487  0000885590-14-000025
# 6764488  0000885590-14-000025
# 6764489  0000885590-14-000025
# 6764490  0000885590-14-000025
# 6764492  0000885590-14-000025
# 6764494  0000885590-14-000025
#
#                                                        tag  \
# 76663                          ComprehensiveIncomeNetOfTax
# 76664                          ComprehensiveIncomeNetOfTax
# 76665                          ComprehensiveIncomeNetOfTax
# 76666                            OtherNoncashIncomeExpense
# 76667                            OtherNoncashIncomeExpense
# 76668                            OtherNoncashIncomeExpense
# 76669                                             Revenues
# 76670                                             Revenues
# 76671                                             Revenues
# 76695                    DebtInstrumentUnamortizedDiscount
# 76696            BusinessAcquisitionsProFormaNetIncomeLoss
# 76697            BusinessAcquisitionsProFormaNetIncomeLoss
# 76698                               ShareBasedCompensation
# 76699                               ShareBasedCompensation
# 76700                               ShareBasedCompensation
# 76701                                      CostOfGoodsSold
# 76702                                      CostOfGoodsSold
# 76703                                      CostOfGoodsSold
# 76706    DeferredTaxAssetsTaxDeferredExpenseCompensatio...
# 76707    DeferredTaxAssetsTaxDeferredExpenseCompensatio...
# 76708                       GoodwillTranslationAdjustments
# 76709                       GoodwillTranslationAdjustments
# 76710    UnrecognizedTaxBenefitsIncreasesResultingFromC...
# 76711    UnrecognizedTaxBenefitsIncreasesResultingFromC...
# 76712    UnrecognizedTaxBenefitsIncreasesResultingFromC...
# 76713    AllowancesForLossesOnAccountsReceivableAndInve...
# 76714    AllowancesForLossesOnAccountsReceivableAndInve...
# 76715    AllowancesForLossesOnAccountsReceivableAndInve...
# 76716                    PaymentsOfContingentConsideration
# 76717                    PaymentsOfContingentConsideration
# ...                                                    ...
# 6764461  BusinessCombinationRecognizedIdentifiableAsset...
# 6764462  BusinessCombinationRecognizedIdentifiableAsset...
# 6764463                                           Goodwill
# 6764464  BusinessCombinationRecognizedIdentifiableAsset...
# 6764465  BusinessCombinationRecognizedIdentifiableAsset...
# 6764466  BusinessCombinationRecognizedIdentifiableAsset...
# 6764467  BusinessCombinationRecognizedIdentifiableAsset...
# 6764468  BusinessCombinationRecognizedIdentifiableAsset...
# 6764469  BusinessCombinationRecognizedIdentifiableAsset...
# 6764470  BusinessCombinationRecognizedIdentifiableAsset...
# 6764471  BusinessCombinationRecognizedIdentifiableAsset...
# 6764474              AssetsFairValueDisclosureNonrecurring
# 6764475            DefinedBenefitPlanFairValueOfPlanAssets
# 6764476            RestructuringReserveSettledWithoutCash1
# 6764474  0xf4e7faae0d65319a9c695f23b534c110  1.000000e+06        0     3
# 6764475  0xf53752a79121f56129142009d9061b2c  0.000000e+00        0     4
# 6764476  0xf57bb01d9580bcb2ac02208d5907d297  9.890000e+05        0     2
# 6764477  0xf57bb01d9580bcb2ac02208d5907d297  2.680000e+05        0     2
# 6764478  0xf57bb01d9580bcb2ac02208d5907d297  0.000000e+00        0     2
# 6764479  0xf57bb01d9580bcb2ac02208d5907d297  2.478900e+07        0     2
# 6764480  0xf57bb01d9580bcb2ac02208d5907d297  2.158000e+06        0     2
# 6764481  0xf57bb01d9580bcb2ac02208d5907d297  2.070000e+05        0     2
# 6764482  0xf57bb01d9580bcb2ac02208d5907d297  5.872700e+07        0     2
# 6764483  0xf57bb01d9580bcb2ac02208d5907d297  1.454800e+07        0     2
# 6764484  0xf57bb01d9580bcb2ac02208d5907d297  1.654000e+06        0     2
# 6764485  0xf57bb01d9580bcb2ac02208d5907d297  3.393800e+07        0     2
# 6764486  0xf57bb01d9580bcb2ac02208d5907d297  3.816800e+07        0     2
# 6764487  0xf57bb01d9580bcb2ac02208d5907d297  3.873000e+06        0     2
# 6764488  0xf992efd7e2e8e3769780521e40901681  5.172000e+06        0     4
# 6764489  0xfb05a5bc20407e52c054e4529249872d  1.655100e+07        0     4
# 6764490  0xfb7c36364e4a8d9a1f128e35fb5e8f3d -4.303200e+07        0     3
# 6764492  0xfbe28de0c680cac602e6e3350d9c70d5  8.500000e+08        0     2
# 6764494  0xfbe28de0c680cac602e6e3350d9c70d5  4.250000e+07        0     2
#
# [2504 rows x 10 columns]

# %%
# all_valeant = q114numbers[q114numbers['adsh'].str.match('0000885590')]

# s.str.startswith('a', na=False)
# 0000885590

# %%
# len(all_valeant)

# %%
len(valeant_10k)
# Out:
# 2886

# %%
valeant_nums = list(set(valeant_USD.value.abs()))
valeant_nums
# Out:
# [0.0,
#  128000000.0,
#  1.0,
#  6144000.0,
#  76800000.0,
#  3200000000.0,
#  24789000.0,
#  9.59,
#  10.54,
#  11.68,
#  455082000.0,
#  6570000.0,
#  18.97,
#  19.57,
#  20.76,
#  19.71,
#  22.85,
#  20.42,
#  284287000.0,
#  25.07,
#  19071000.0,
#  25.42,
#  24.0,
#  30.19,
#  30.47,
#  2900000.0,
#  33.43,
#  34.11,
#  28500000.0,
#  38.13,
#  39.74,
#  39.35,
#  39.11,
#  43.4,
#  44.4,
#  44.0,
#  29950000.0,
#  50.56,
#  51.06,
#  51.86,
#  110035000.0,
#  7635000.0,
#  59.03,
#  59.15,
#  8872000.0,
#  5800000.0,
#  364200000.0,
#  69.35,
#  262226000.0,
#  80.47,
#  84.01,
#  85.0,
#  14631000.0,
#  219431000.0,
#  88.73,
#  91.12,
#  93.6,
#  46588000.0,
#  8700000.0,
#  59900000.0,
#  384508000.0,
#  102.22,
#  104.21,
#  879526000.0,
#  2171000.0,
#  56443000.0,
#  336000.0,
#  229712000.0,
#  114000000.0,
#  57893000.0,
#  35365000.0,
#  217450000.0,
#  855402000.0,
#  563775000.0,
#  106047000.0,
#  88639000.0,
#  807487000.0,
#  372500000.0,
#  14100000.0,
#  4073000.0,
#  7358000.0,
#  31934000.0,
#  616000.0,
#  93800000.0,
#  30525000.0,
#  1853000.0,
#  130279000.0,
#  1762535000.0,
#  19900000.0,
#  4150929000.0,
#  891537000.0,
#  14395000.0,
#  18491000.0,
#  74000000.0,
#  25872000.0,
#  100000.0,
#  116025000.0,
#  11577000.0,
#  32057000.0,
#  455395000.0,
#  3000000.0,
#  25528000.0,
#  2051000000.0,
#  5640333000.0,
#  4387981000.0,
#  9783000.0,
#  78604000.0,
#  31500000.0,
#  65505000.0,
#  33761000.0,
#  8161000.0,
#  65718000.0,
#  395000.0,
#  8587000.0,
#  700000000.0,
#  1008224000.0,
#  8800000.0,
#  60000000.0,
#  4293216000.0,
#  136800000.0,
#  3082000.0,
#  450783000.0,
#  11700000.0,
#  37300000.0,
#  3721000.0,
#  4745000.0,
#  8841000.0,
#  866142000.0,
#  377907000.0,
#  1676339000.0,
#  22792000.0,
#  91400000.0,
#  31410000.0,
#  905095000.0,
#  3975000.0,
#  220039000.0,
#  258951000.0,
#  45959000.0,
#  138332000.0,
#  1604700000.0,
#  92000.0,
#  1329000.0,
#  40667000.0,
#  29829000.0,
#  20826000.0,
#  15706000.0,
#  10571311000.0,
#  76548000.0,
#  3844000.0,
#  74500000.0,
#  230148000.0,
#  985000.0,
#  22489000.0,
#  25561000.0,
#  97667000.0,
#  3459000.0,
#  8792000.0,
#  9575000000.0,
#  745474000.0,
#  29100000.0,
#  5940652000.0,
#  306604000.0,
#  172460000.0,
#  498305000.0,
#  3497814000.0,
#  10070000.0,
#  33835000.0,
#  60459000.0,
#  1256704000.0,
#  256000.0,
#  2.7,
#  6400000.0,
#  4.29,
#  4.2,
#  6.61,
#  57600000.0,
#  83413000.0,
#  5233322000.0,
#  87722000.0,
#  2730000.0,
#  626559000.0,
#  10324000.0,
#  9300000.0,
#  1135700000.0,
#  60500000.0,
#  27945000.0,
#  42920000.0,
#  1050536000.0,
#  410536000.0,
#  1625000000.0,
#  345000000.0,
#  16.78,
#  42535000.0,
#  764000.0,
#  66300000.0,
#  15100000.0,
#  349137000.0,
#  73894000.0,
#  379000.0,
#  18000000.0,
#  30288000.0,
#  43600000.0,
#  7760000.0,
#  555600000.0,
#  1978960000.0,
#  1476389000.0,
#  19450000.0,
#  207000.0,
#  3492000.0,
#  755108000.0,
#  430500000.0,
#  18375289000.0,
#  23374000.0,
#  224291000.0,
#  22776000.0,
#  23800000.0,
#  75000000.0,
#  129272000.0,
#  27896000.0,
#  189901000.0,
#  90573000.0,
#  2144119000.0,
#  132172000.0,
#  717900000.0,
#  1100000.0,
#  257100000.0,
#  3226700000.0,
#  766028000.0,
#  103926000.0,
#  2073078000.0,
#  65014000.0,
#  37366000.0,
#  125643000.0,
#  0.38,
#  157600000.0,
#  4000000.0,
#  900000000.0,
#  928885000.0,
#  3189000.0,
#  175000.0,
#  90500000.0,
#  75140000.0,
#  12676000.0,
#  9171332000.0,
#  13700000.0,
#  26414000.0,
#  2862000.0,
#  3000.0,
#  41987000.0,
#  1453000.0,
#  781954000.0,
#  8023000.0,
#  1345367000.0,
#  915500000.0,
#  147500000.0,
#  1068000.0,
#  45100000.0,
#  11521000.0,
#  50433000.0,
#  24833000.0,
#  2518000.0,
#  293547000.0,
#  17950379000.0,
#  3755000.0,
#  22187000.0,
#  683000.0,
#  37760000.0,
#  141184000.0,
#  2.47,
#  675712000.0,
#  99200000.0,
#  406400000.0,
#  110890000.0,
#  5388799000.0,
#  25300000.0,
#  2030292000.0,
#  258985000.0,
#  664915000.0,
#  21843000.0,
#  1023315000.0,
#  552000.0,
#  2600000.0,
#  13053000.0,
#  36605000.0,
#  701181000.0,
#  388861000.0,
#  5074000.0,
#  18386000.0,
#  61607000.0,
#  16551000.0,
#  380000.0,
#  5500000.0,
#  31100000.0,
#  131067000.0,
#  666619000.0,
#  178384000.0,
#  136400000.0,
#  12441808000.0,
#  34213000.0,
#  2682000.0,
#  33402000.0,
#  11300000.0,
#  62500000.0,
#  497700000.0,
#  9465000.0,
#  120057000.0,
#  1273000.0,
#  448163000.0,
#  3194531000.0,
#  7032000.0,
#  59256000.0,
#  475000000.0,
#  180301000.0,
#  5380386000.0,
#  196898000.0,
#  11554000.0,
#  36343000.0,
#  3575000.0,
#  1527000.0,
#  247500000.0,
#  68300000.0,
#  119500000.0,
#  1213345000.0,
#  57249000.0,
#  2323361000.0,
#  6049000.0,
#  107638000.0,
#  3403000.0,
#  171339000.0,
#  331000.0,
#  20000000.0,
#  224800000.0,
#  45600000.0,
#  55840000.0,
#  2592000.0,
#  506400000.0,
#  1300000000.0,
#  41717000.0,
#  234442000.0,
#  135114000.0,
#  102559000.0,
#  19828000.0,
#  22900000.0,
#  1396000.0,
#  48500000.0,
#  12660000.0,
#  143945000.0,
#  43593000.0,
#  815902000.0,
#  3400691000.0,
#  687091000.0,
#  188616000.0,
#  200000.0,
#  205000000.0,
#  25800000.0,
#  21917000.0,
#  1437000.0,
#  77426000.0,
#  931442000.0,
#  209522000.0,
#  94023000.0,
#  159559000.0,
#  3911000.0,
#  27676000.0,
#  56348000.0,
#  178204000.0,
#  284700000.0,
#  1814769000.0,
#  19910000.0,
#  104902000.0,
#  31600000.0,
#  415600000.0,
#  140144000.0,
#  2950000000.0,
#  520261000.0,
#  1306000.0,
#  18714000.0,
#  23023000.0,
#  8900000.0,
#  623300000.0,
#  1406660000.0,
#  979652000.0,
#  34500000.0,
#  136900000.0,
#  162500000.0,
#  825241000.0,
#  1245081000.0,
#  986222000.0,
#  2158000.0,
#  1278275000.0,
#  344387000.0,
#  40472000.0,
#  198168000.0,
#  160493000.0,
#  65687000.0,
#  77975000.0,
#  751980000.0,
#  2464108000.0,
#  2307436000.0,
#  25964000.0,
#  466284000.0,
#  782700000.0,
#  11841000.0,
#  8982000.0,
#  42987000.0,
#  302059000.0,
#  883904000.0,
#  0.49,
#  978112000.0,
#  120000000.0,
#  17600000.0,
#  14232981000.0,
#  5738000.0,
#  6377000.0,
#  142782000.0,
#  2225000000.0,
#  5992000.0,
#  6205000.0,
#  2322000.0,
#  5607000.0,
#  33255000.0,
#  66236000.0,
#  51900000.0,
#  2808508000.0,
#  26300000.0,
#  11366000.0,
#  8507000.0,
#  313659000.0,
#  106000000.0,
#  54800000.0,
#  3288592000.0,
#  8720000.0,
#  3600000.0,
#  164581000.0,
#  318181000.0,
#  741000.0,
#  111972000.0,
#  79204000.0,
#  6500000.0,
#  83300000.0,
#  4665000.0,
#  230158000.0,
#  32526000.0,
#  995000.0,
#  397000.0,
#  17805000.0,
#  1634000.0,
#  37474000.0,
#  6967000.0,
#  35639000.0,
#  10039000.0,
#  130060000.0,
#  3084000.0,
#  1585164000.0,
#  37900000.0,
#  58806000.0,
#  13750000.0,
#  4747000.0,
#  25227000.0,
#  651000.0,
#  1500000000.0,
#  121696000.0,
#  15200000.0,
#  296800000.0,
#  168800000.0,
#  53000.0,
#  2101000.0,
#  120885000.0,
#  642101000.0,
#  639242000.0,
#  28938000.0,
#  27103000.0,
#  4575000.0,
#  18100000.0,
#  534196000.0,
#  754356000.0,
#  1770164000.0,
#  18313000.0,
#  20361000.0,
#  402313000.0,
#  3166000.0,
#  4403000.0,
#  414003000.0,
#  64819000.0,
#  149000000.0,
#  14045000.0,
#  4829000.0,
#  321245000.0,
#  223965000.0,
#  269234000.0,
#  130183000.0,
#  177500000.0,
#  10801000.0,
#  64049000.0,
#  1453019000.0,
#  4272000.0,
#  1200000.0,
#  492720000.0,
#  ...]

# %%
len(valeant_nums)
# Out:
# 1890

# %%
def first_digit(number):
    return int(str(number)[0])

# %%
benford_valeant = [first_digit(num) for num in valeant_nums] 
len(benford_valeant)
# Out:
# 1890

# %%
benford_valeant
# Out:
# [0,
#  1,
#  1,
#  6,
#  7,
#  3,
#  2,
#  9,
#  1,
#  1,
#  4,
#  6,
#  1,
#  1,
#  2,
#  1,
#  2,
#  2,
#  2,
#  2,
#  1,
#  2,
#  2,
#  3,
#  3,
#  2,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  4,
#  4,
#  4,
#  2,
#  5,
#  5,
#  5,
#  1,
#  7,
#  5,
#  5,
#  8,
#  5,
#  3,
#  6,
#  2,
#  8,
#  8,
#  8,
#  1,
#  2,
#  8,
#  9,
#  9,
#  4,
#  8,
#  5,
#  3,
#  1,
#  1,
#  8,
#  2,
#  5,
#  3,
#  2,
#  1,
#  5,
#  3,
#  1,
#  1,
#  1,
#  1,
#  1,
#  9,
#  1,
#  1,
#  4,
#  1,
#  2,
#  5,
#  8,
#  1,
#  3,
#  3,
#  2,
#  5,
#  1,
#  3,
#  5,
#  9,
#  2,
#  1,
#  2,
#  1,
#  3,
#  2,
#  1,
#  5,
#  2,
#  7,
#  1,
#  4,
#  3,
#  3,
#  3,
#  3,
#  6,
#  5,
#  7,
#  3,
#  5,
#  2,
#  3,
#  1,
#  1,
#  9,
#  1,
#  1,
#  3,
#  9,
#  3,
#  1,
#  1,
#  1,
#  3,
#  8,
#  9,
#  1,
#  1,
#  6,
#  1,
#  8,
#  3,
#  1,
#  4,
#  1,
#  8,
#  1,
#  1,
#  2,
#  3,
#  3,
#  2,
#  1,
#  4,
#  4,
#  1,
#  2,
#  4,
#  2,
#  1,
#  2,
#  1,
#  1,
#  1,
#  9,
#  4,
#  2,
#  1,
#  9,
#  3,
#  2,
#  2,
#  8,
#  7,
#  6,
#  5,
#  1,
#  1,
#  1,
#  6,
#  6,
#  3,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  1,
#  1,
#  6,
#  9,
#  5,
#  8,
#  1,
#  1,
#  8,
#  1,
#  2,
#  1,
#  2,
#  6,
#  1,
#  8,
#  7,
#  3,
#  1,
#  2,
#  2,
#  2,
#  1,
#  7,
#  6,
#  3,
#  3,
#  5,
#  2,
#  1,
#  4,
#  2,
#  1,
#  3,
#  6,
#  3,
#  1,
#  9,
#  3,
#  6,
#  2,
#  2,
#  2,
#  2,
#  1,
#  4,
#  1,
#  2,
#  1,
#  3,
#  4,
#  8,
#  2,
#  3,
#  9,
#  1,
#  1,
#  2,
#  3,
#  1,
#  1,
#  2,
#  9,
#  2,
#  1,
#  1,
#  1,
#  9,
#  8,
#  1,
#  4,
#  1,
#  1,
#  1,
#  2,
#  5,
#  5,
#  1,
#  7,
#  1,
#  1,
#  4,
#  2,
#  5,
#  2,
#  5,
#  8,
#  1,
#  1,
#  1,
#  1,
#  9,
#  3,
#  0,
#  1,
#  3,
#  2,
#  6,
#  1,
#  1,
#  4,
#  2,
#  4,
#  5,
#  6,
#  7,
#  4,
#  2,
#  2,
#  8,
#  2,
#  2,
#  1,
#  1,
#  1,
#  9,
#  2,
#  5,
#  1,
#  8,
#  5,
#  8,
#  2,
#  2,
#  6,
#  1,
#  1,
#  1,
#  5,
#  2,
#  5,
#  1,
#  1,
#  1,
#  2,
#  4,
#  1,
#  6,
#  4,
#  2,
#  9,
#  1,
#  2,
#  1,
#  1,
#  1,
#  2,
#  3,
#  4,
#  2,
#  2,
#  5,
#  8,
#  5,
#  7,
#  3,
#  2,
#  2,
#  1,
#  2,
#  8,
#  6,
#  6,
#  3,
#  9,
#  2,
#  2,
#  1,
#  7,
#  4,
#  2,
#  7,
#  1,
#  3,
#  5,
#  2,
#  1,
#  2,
#  7,
#  2,
#  1,
#  2,
#  3,
#  4,
#  6,
#  4,
#  2,
#  6,
#  2,
#  5,
#  7,
#  1,
#  2,
#  2,
#  1,
#  2,
#  2,
#  4,
#  2,
#  1,
#  2,
#  2,
#  5,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  0,
#  3,
#  2,
#  7,
#  1,
#  2,
#  7,
#  4,
#  1,
#  6,
#  1,
#  8,
#  7,
#  2,
#  8,
#  5,
#  1,
#  8,
#  8,
#  3,
#  1,
#  4,
#  7,
#  3,
#  6,
#  9,
#  3,
#  1,
#  1,
#  1,
#  1,
#  4,
#  8,
#  1,
#  1,
#  7,
#  2,
#  1,
#  1,
#  1,
#  3,
#  4,
#  3,
#  2,
#  2,
#  5,
#  4,
#  9,
#  7,
#  3,
#  6,
#  3,
#  8,
#  6,
#  3,
#  8,
#  7,
#  1,
#  8,
#  6,
#  4,
#  1,
#  3,
#  4,
#  1,
#  3,
#  3,
#  4,
#  8,
#  8,
#  3,
#  1,
#  2,
#  9,
#  3,
#  9,
#  3,
#  2,
#  2,
#  4,
#  1,
#  1,
#  9,
#  1,
#  4,
#  2,
#  2,
#  1,
#  1,
#  7,
#  3,
#  7,
#  2,
#  9,
#  2,
#  2,
#  9,
#  3,
#  8,
#  9,
#  7,
#  2,
#  5,
#  3,
#  1,
#  4,
#  3,
#  1,
#  3,
#  6,
#  1,
#  2,
#  2,
#  6,
#  4,
#  4,
#  6,
#  5,
#  8,
#  5,
#  8,
#  2,
#  6,
#  1,
#  9,
#  1,
#  6,
#  2,
#  4,
#  1,
#  4,
#  1,
#  3,
#  1,
#  4,
#  7,
#  6,
#  1,
#  3,
#  7,
#  3,
#  1,
#  3,
#  4,
#  7,
#  5,
#  1,
#  1,
#  1,
#  2,
#  3,
#  7,
#  4,
#  1,
#  2,
#  2,
#  2,
#  2,
#  7,
#  1,
#  2,
#  1,
#  9,
#  2,
#  1,
#  7,
#  1,
#  2,
#  3,
#  7,
#  1,
#  2,
#  6,
#  3,
#  1,
#  0,
#  1,
#  4,
#  9,
#  9,
#  3,
#  1,
#  4,
#  5,
#  2,
#  4,
#  3,
#  6,
#  2,
#  2,
#  1,
#  2,
#  7,
#  3,
#  1,
#  3,
#  3,
#  9,
#  1,
#  6,
#  2,
#  1,
#  6,
#  2,
#  3,
#  1,
#  3,
#  8,
#  1,
#  2,
#  6,
#  1,
#  3,
#  2,
#  1,
#  2,
#  1,
#  6,
#  4,
#  1,
#  2,
#  9,
#  2,
#  3,
#  1,
#  5,
#  2,
#  4,
#  2,
#  1,
#  8,
#  3,
#  2,
#  4,
#  2,
#  1,
#  3,
#  1,
#  1,
#  2,
#  4,
#  1,
#  1,
#  7,
#  6,
#  4,
#  8,
#  8,
#  3,
#  4,
#  4,
#  3,
#  6,
#  4,
#  4,
#  1,
#  4,
#  1,
#  5,
#  3,
#  7,
#  1,
#  2,
#  5,
#  7,
#  2,
#  1,
#  9,
#  9,
#  5,
#  2,
#  1,
#  5,
#  1,
#  1,
#  3,
#  6,
#  3,
#  2,
#  2,
#  1,
#  2,
#  1,
#  3,
#  4,
#  1,
#  4,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  2,
#  3,
#  5,
#  1,
#  1,
#  4,
#  1,
#  3,
#  3,
#  1,
#  1,
#  4,
#  7,
#  4,
#  8,
#  3,
#  4,
#  3,
#  1,
#  4,
#  2,
#  1,
#  5,
#  1,
#  1,
#  2,
#  3,
#  2,
#  3,
#  7,
#  2,
#  6,
#  7,
#  1,
#  5,
#  1,
#  1,
#  4,
#  1,
#  5,
#  2,
#  1,
#  1,
#  5,
#  7,
#  3,
#  3,
#  6,
#  9,
#  6,
#  1,
#  6,
#  1,
#  2,
#  1,
#  1,
#  9,
#  7,
#  1,
#  9,
#  1,
#  2,
#  2,
#  3,
#  4,
#  1,
#  7,
#  8,
#  1,
#  9,
#  1,
#  1,
#  4,
#  1,
#  5,
#  2,
#  2,
#  2,
#  1,
#  3,
#  2,
#  6,
#  3,
#  1,
#  2,
#  6,
#  9,
#  4,
#  1,
#  5,
#  2,
#  2,
#  2,
#  6,
#  2,
#  1,
#  5,
#  2,
#  1,
#  3,
#  7,
#  3,
#  5,
#  1,
#  6,
#  1,
#  3,
#  5,
#  3,
#  1,
#  6,
#  1,
#  1,
#  1,
#  3,
#  2,
#  3,
#  1,
#  6,
#  4,
#  9,
#  1,
#  1,
#  4,
#  3,
#  7,
#  5,
#  4,
#  1,
#  5,
#  1,
#  1,
#  3,
#  3,
#  1,
#  2,
#  6,
#  1,
#  1,
#  5,
#  2,
#  6,
#  1,
#  3,
#  1,
#  3,
#  2,
#  2,
#  4,
#  5,
#  2,
#  5,
#  1,
#  4,
#  2,
#  1,
#  1,
#  1,
#  2,
#  1,
#  4,
#  1,
#  1,
#  4,
#  8,
#  3,
#  6,
#  1,
#  2,
#  2,
#  2,
#  2,
#  1,
#  7,
#  9,
#  2,
#  9,
#  1,
#  3,
#  2,
#  5,
#  1,
#  2,
#  1,
#  1,
#  1,
#  3,
#  4,
#  1,
#  2,
#  5,
#  1,
#  1,
#  2,
#  8,
#  6,
#  1,
#  9,
#  3,
#  1,
#  1,
#  8,
#  1,
#  9,
#  2,
#  1,
#  3,
#  4,
#  1,
#  1,
#  6,
#  7,
#  7,
#  2,
#  2,
#  2,
#  4,
#  7,
#  1,
#  8,
#  4,
#  3,
#  8,
#  0,
#  9,
#  1,
#  1,
#  1,
#  5,
#  6,
#  1,
#  2,
#  5,
#  6,
#  2,
#  5,
#  3,
#  6,
#  5,
#  2,
#  2,
#  1,
#  8,
#  3,
#  1,
#  5,
#  3,
#  8,
#  3,
#  1,
#  3,
#  7,
#  1,
#  7,
#  6,
#  8,
#  4,
#  2,
#  3,
#  9,
#  3,
#  1,
#  1,
#  3,
#  6,
#  3,
#  1,
#  1,
#  3,
#  1,
#  3,
#  5,
#  1,
#  4,
#  2,
#  6,
#  1,
#  1,
#  1,
#  2,
#  1,
#  5,
#  2,
#  1,
#  6,
#  6,
#  2,
#  2,
#  4,
#  1,
#  5,
#  7,
#  1,
#  1,
#  2,
#  4,
#  3,
#  4,
#  4,
#  6,
#  1,
#  1,
#  4,
#  3,
#  2,
#  2,
#  1,
#  1,
#  1,
#  6,
#  1,
#  4,
#  1,
#  4,
#  ...]

# %%
def frequencies(first_digits):
    counts = [0]*10
    for x in first_digits:
        if x > 0:
            counts[x] += 1 
    total = sum(counts)
    freq = [count/total for count in counts]
    print(sum(freq))
    return freq[1:] #same as going from element 1 through the end (i.e. 9)

# %%
frequencies(benford_valeant)
# Out:
# 1.0000000000000002
# [0.2791932059447983,
#  0.18471337579617833,
#  0.131104033970276,
#  0.09554140127388536,
#  0.08227176220806794,
#  0.07537154989384288,
#  0.05148619957537155,
#  0.056794055201698515,
#  0.0435244161358811]

# %%
import math
r = range(10)
benfords_law = [math.log10(1 + 1/digit) for digit in r if digit != 0]
benfords_law
# Out:
# [0.3010299956639812,
#  0.17609125905568124,
#  0.12493873660829993,
#  0.09691001300805642,
#  0.07918124604762482,
#  0.06694678963061322,
#  0.05799194697768673,
#  0.05115252244738129,
#  0.04575749056067514]

# %%
len(benford_valeant)
# Out:
# 1890

# %%
import plotly

plotly.offline.init_notebook_mode(connected=True)
Benfords_Law = {'type': 'scatter', 'x': list(range(1, 10)), 'y': benfords_law}
Valeant = {'type': 'scatter', 'x': list(range(1, 10)), 'y': frequencies(benford_valeant)}


plotly.offline.iplot([Benfords_Law, Valeant])
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="5f6bb6be-b74f-4919-b549-8f1962ad9c35" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5f6bb6be-b74f-4919-b549-8f1962ad9c35", [{"x": [1, 2, 3, 4, 5, 6, 7, 8, 9], "y": [0.3010299956639812, 0.17609125905568124, 0.12493873660829993, 0.09691001300805642, 0.07918124604762482, 0.06694678963061322, 0.05799194697768673, 0.05115252244738129, 0.04575749056067514], "type": "scatter", "uid": "d4c33200-f768-49c6-a7df-267c7fe66cd8"}, {"x": [1, 2, 3, 4, 5, 6, 7, 8, 9], "y": [0.2791932059447983, 0.18471337579617833, 0.131104033970276, 0.09554140127388536, 0.08227176220806794, 0.07537154989384288, 0.05148619957537155, 0.056794055201698515, 0.0435244161358811], "type": "scatter", "uid": "89aa78c3-bb09-4763-a30c-440a9341da96"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("5f6bb6be-b74f-4919-b549-8f1962ad9c35"));});</script>

# %%
import math
def kl_divergence(freq):
    kl_div = 0.0
    for d in range(1, 10):
        Q = (math.log(d+1) - math.log(d)) / math.log(10) #calculates theoretical benfords (perfect benny freqs)
        P = freq[d-1]
        kl_div += math.log(P / Q) * P
#         print((freq))

    return float(kl_div)

# %%
kl_divergence(frequencies(benford_valeant))
# Out:
# 0.0024374317777151335

# %%
kl_divergence(benfords_law)
# Out:
# 4.6614422691971963e-17

# %%
# q414numbers.join(s.apply(lambda x: x.split('-')))

# %%
# q414numbers= q414numbers.drop('adsh', axis=1).join(s.reset_index(drop=True, level=1).rename(['0'],['1'],['2']))

# %%
# q414numbers.head()

# %%
import numpy as np
import random
def p_value(freq):
    n = sum(freq)
    ps = [(math.log(d+1) - math.log(d)) / math.log(10) for d in range(1, 10)]

    ks_obs = freq[1:]

    def ll(ks): # log-likelihood
        z = random.sample(zip(ks, ps), 8)
        return sum([k * math.log(p) for (k, p) in z])

    N = 10000
    P = 0
    for i in range(N):
        ks = np.random.multinomial(n, ps)
        if ll(ks) > ll(ks_obs): P += 1

# %%
p_value(benford_valeant)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-ca619871505f> in <module>
# ----> 1 p_value(benford_valeant)
#
# <ipython-input-33-19aaad0d63cd> in p_value(freq)
#      15     for i in range(N):
#      16         ks = np.random.multinomial(n, ps)
# ---> 17         if ll(ks) > ll(ks_obs): P += 1
#
# <ipython-input-33-19aaad0d63cd> in ll(ks)
#       8
#       9     def ll(ks): # log-likelihood
# ---> 10         z = random.sample(zip(ks, ps), 8)
#      11         return sum([k * math.log(p) for (k, p) in z])
#      12
#
# /anaconda3/lib/python3.6/random.py in sample(self, population, k)
#     314             population = tuple(population)
#     315         if not isinstance(population, _Sequence):
# --> 316             raise TypeError("Population must be a sequence or set.  For dicts, use list(d).")
#     317         randbelow = self._randbelow
#     318         n = len(population)
#
# TypeError: Population must be a sequence or set.  For dicts, use list(d).

# %%
ks_obs = freq[1:]
