# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
df = pd.read_csv('pivot_table_groupedby_adsh_with_finratios_added.csv')
df.head()
# Out:
#    Unnamed: 0                  adsh  fraud  AccountsReceivable          Cash  \
# 0           0  0000002178-18-000009    0.0        1.939190e+08  3.910830e+08
# 1           1  0000002488-18-000042    0.0        3.670000e+08  4.719000e+09
# 2           2  0000002969-18-000014    0.0        2.337100e+09  1.333080e+10
# 3           3  0000003499-18-000006    0.0        1.797337e+09  2.928676e+09
# 4           4  0000003545-18-000021    0.0        3.092700e+07  4.077000e+06
#
#    CashFlowfromOps  CurrentLiabilities  Depreciation      Expenses  \
# 0     5.484600e+07        2.057540e+08  3.608060e+08  8.634819e+09
# 1    -6.800000e+07        7.206000e+09  2.143000e+09  2.505300e+10
# 2     1.091700e+09        4.203800e+09  2.294970e+10  4.373600e+09
# 3     3.604470e+08        2.394690e+09  8.263830e+09  8.957640e+08
# 4    -2.657900e+07        2.743400e+07  7.406000e+06  3.747720e+08
#
#    IntangibleAssets    ...     DebtToEquityRatio     NetIncome  ProfitMargin  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# adsh                     0
# fraud                    0
# AccountsReceivable       0
# Cash                     0
# CashFlowfromOps          0
# CurrentLiabilities       0
# Depreciation             0
# Expenses                 0
# IntangibleAssets         0
# OtherCurrentAssets       0
# OtherIncome              0
# OtherLiabilities         0
# PPE                      0
# Sales                    0
# ShareholdersEquity       0
# sum_of_first_digits      0
# total_deviation          0
# TotalCurrentAssets       0
# CurrentRatio            25
# TotalLiabilities         0
# DebtToEquityRatio       24
# NetIncome                0
# ProfitMargin            63
# ReceivableTurnover     496
# CollectionRatio        496
# DSRI                   496
# TotalAssets              0
# AQI                     34
# DEPI                   211
# TATA                    23
# dtype: int64

# %%
df= df.fillna(0)
df.isnull().sum()
# Out:
# Unnamed: 0             0
# adsh                   0
# fraud                  0
# AccountsReceivable     0
# Cash                   0
# CashFlowfromOps        0
# CurrentLiabilities     0
# Depreciation           0
# Expenses               0
# IntangibleAssets       0
# OtherCurrentAssets     0
# OtherIncome            0
# OtherLiabilities       0
# PPE                    0
# Sales                  0
# ShareholdersEquity     0
# sum_of_first_digits    0
# total_deviation        0
# TotalCurrentAssets     0
# CurrentRatio           0
# TotalLiabilities       0
# DebtToEquityRatio      0
# NetIncome              0
# ProfitMargin           0
# ReceivableTurnover     0
# CollectionRatio        0
# DSRI                   0
# TotalAssets            0
# AQI                    0
# DEPI                   0
# TATA                   0
# dtype: int64

# %%
df.to_csv('pivot_table_groupedby_adsh_with_finratios_and_no_nullvals.csv')

# %%
df.describe(include = 'all')
# Out:
#          Unnamed: 0                  adsh        fraud  AccountsReceivable  \
# count   6032.000000                  6032  6032.000000        6.032000e+03
# unique          NaN                  6032          NaN                 NaN
# top             NaN  0001437749-18-002506          NaN                 NaN
# freq            NaN                     1          NaN                 NaN
# mean    3015.500000                   NaN     0.020060        2.432070e+10
# std     1741.432743                   NaN     0.140216        4.587488e+11
# min        0.000000                   NaN     0.000000       -3.329931e+09
# 25%     1507.750000                   NaN     0.000000        1.336965e+06
# 50%     3015.500000                   NaN     0.000000        1.089030e+08
# 75%     4523.250000                   NaN     0.000000        1.376592e+09
# max     6031.000000                   NaN     1.000000        2.777212e+13
#
# ...

# %%
import numpy as np
df = df.replace([np.inf, -np.inf], np.nan)
df = df.fillna(0)

# %%
df.describe(include= 'all')
# Out:
#          Unnamed: 0                  adsh        fraud  AccountsReceivable  \
# count   6032.000000                  6032  6032.000000        6.032000e+03
# unique          NaN                  6032          NaN                 NaN
# top             NaN  0001437749-18-002506          NaN                 NaN
# freq            NaN                     1          NaN                 NaN
# mean    3015.500000                   NaN     0.020060        2.432070e+10
# std     1741.432743                   NaN     0.140216        4.587488e+11
# min        0.000000                   NaN     0.000000       -3.329931e+09
# 25%     1507.750000                   NaN     0.000000        1.336965e+06
# 50%     3015.500000                   NaN     0.000000        1.089030e+08
# 75%     4523.250000                   NaN     0.000000        1.376592e+09
# max     6031.000000                   NaN     1.000000        2.777212e+13
#
# ...

# %%
df.to_csv('pivot_table_groupedby_adsh_with_finratios_and_no_nullvals_or_inf.csv')
