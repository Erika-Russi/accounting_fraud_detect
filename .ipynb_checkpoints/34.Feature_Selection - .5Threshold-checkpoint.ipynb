# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
df = pd.read_csv('739to4000_with_tags,KL_divergence,FinRatios.csv')
df.head()
# Out:
#                    adsh  fraud       ddate  AccountsReceivable          Cash  \
# 0  0000002178-18-000009    0.0  20161231.0         106756000.0  7.875000e+07
# 1  0000002488-18-000042    0.0  20161231.0         126000000.0  2.010000e+09
# 2  0000002969-18-000014    0.0  20161231.0         -57400000.0  5.735000e+08
# 3  0000003499-18-000006    0.0  20161231.0         182581000.0  8.456940e+08
# 4  0000003545-18-000021    0.0  20161231.0           7177000.0 -6.183000e+06
#
#    CashFlowfromOps  CurrentLiabilities  Depreciation      Expenses  \
# 0        6504000.0        1.114280e+08  2.210870e+08  2.163510e+09
# 1       90000000.0        3.825000e+09  9.210000e+08  6.611000e+09
# 2      525400000.0        1.040000e+07  2.061000e+08  1.587700e+09
# 3      130820000.0        1.110608e+09  1.655981e+09  3.176400e+08
# 4      -16890000.0       -4.823000e+06  3.916000e+06  3.149000e+06
#
#    IntangibleAssets    ...     DebtToEquityRatio     NetIncome  ProfitMargin  \
# 0               0.0    ...              0.539227  6.440080e+08      0.229387
# 1       948000000.0    ...              1.464384  3.287000e+09      0.332087
# 2               0.0    ...              0.003057  2.948000e+08      0.156600
# 3               0.0    ...              0.822055  1.179930e+08      0.270854
# 4               0.0    ...              2.353128  2.942400e+07      0.903325
#
#    ReceivableTurnover  CollectionRatio      DSRI   TotalAssets       AQI  \
# 0           26.298456        13.879142  0.038025  1.139030e+09  0.000000
# 1           78.555556         4.646393  0.012730  2.617100e+10  0.036223
# 2          -32.796167       -11.129349 -0.030491  1.062500e+09  0.000000
# 3            2.385971       152.977541  0.419117  5.371457e+09  0.000000
# 4            4.538526        80.422589  0.220336  7.572000e+06  0.000000
#
#        DEPI      TATA
# 0  0.316076  0.559690
# 1  0.261277  0.122158
# 2  0.320778 -0.217035
# 3  0.367267 -0.002388
# 4  0.370623  6.116482
#
# [5 rows x 31 columns]

# %%
target = df.fraud

# %%
features = df.drop(['adsh','ddate','fraud'], axis=1)
features.head()
# Out:
#    AccountsReceivable          Cash  CashFlowfromOps  CurrentLiabilities  \
# 0         106756000.0  7.875000e+07        6504000.0        1.114280e+08
# 1         126000000.0  2.010000e+09       90000000.0        3.825000e+09
# 2         -57400000.0  5.735000e+08      525400000.0        1.040000e+07
# 3         182581000.0  8.456940e+08      130820000.0        1.110608e+09
# 4           7177000.0 -6.183000e+06      -16890000.0       -4.823000e+06
#
#    Depreciation      Expenses  IntangibleAssets  OtherCurrentAssets  \
# 0  2.210870e+08  2.163510e+09               0.0        4.751370e+08
# 1  9.210000e+08  6.611000e+09       948000000.0        2.048300e+10
# 2  2.061000e+08  1.587700e+09               0.0        1.100000e+08
# 3  1.655981e+09  3.176400e+08               0.0        1.490230e+09
# 4  3.916000e+06  3.149000e+06               0.0       -7.200000e+04
#
#     OtherIncome  OtherLiabilities    ...     DebtToEquityRatio     NetIncome  \
# 0  4.700000e+06      1.910170e+08    ...              0.539227  6.440080e+08
# 1  1.559000e+09      4.727000e+09    ...              1.464384  3.287000e+09
# 2 -7.588000e+08      1.440000e+07    ...              0.003057  2.948000e+08
# 3  0.000000e+00      1.104726e+09    ...              0.822055  1.179930e+08
# 4  2.194500e+07     -1.121000e+06    ...              2.353128  2.942400e+07
#
#    ProfitMargin  ReceivableTurnover  CollectionRatio      DSRI   TotalAssets  \
# 0      0.229387           26.298456        13.879142  0.038025  1.139030e+09
# 1      0.332087           78.555556         4.646393  0.012730  2.617100e+10
# 2      0.156600          -32.796167       -11.129349 -0.030491  1.062500e+09
# 3      0.270854            2.385971       152.977541  0.419117  5.371457e+09
# 4      0.903325            4.538526        80.422589  0.220336  7.572000e+06
#
#         AQI      DEPI      TATA
# 0  0.000000  0.316076  0.559690
# 1  0.036223  0.261277  0.122158
# 2  0.000000  0.320778 -0.217035
# 3  0.000000  0.367267 -0.002388
# 4  0.000000  0.370623  6.116482
#
# [5 rows x 28 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
scaled_df.head()
# Out:
#    AccountsReceivable      Cash  CashFlowfromOps  CurrentLiabilities  \
# 0           -0.049149 -0.047866        -0.188882           -0.115455
# 1           -0.049063  0.039445        -0.155622            0.110438
# 2           -0.049886 -0.025498         0.017818           -0.121601
# 3           -0.048809 -0.013192        -0.139362           -0.054676
# 4           -0.049596 -0.051705        -0.198201           -0.122527
#
#    Depreciation  Expenses  IntangibleAssets  OtherCurrentAssets  OtherIncome  \
# 0     -0.133843 -0.093800          -0.15116           -0.077214    -0.066630
# 1     -0.053649  0.001734          -0.09378           -0.030408    -0.040274
# 2     -0.135561 -0.106169          -0.15116           -0.078068    -0.079576
# 3      0.030564 -0.133451          -0.15116           -0.074839    -0.066710
# 4     -0.158726 -0.140206          -0.15116           -0.078325    -0.066337
#
#    OtherLiabilities    ...     DebtToEquityRatio  NetIncome  ProfitMargin  \
# 0         -0.073339    ...             -0.013332   0.043272      0.027361
# 1         -0.060752    ...             -0.013332   0.109684      0.027402
# 2         -0.073830    ...             -0.013332   0.034498      0.027331
# 3         -0.070804    ...             -0.013332   0.030055      0.027377
# 4         -0.073873    ...             -0.013332   0.027830      0.027631
#
#    ReceivableTurnover  CollectionRatio      DSRI  TotalAssets       AQI  \
# 0           -0.015921        -0.020880 -0.020880    -0.091132 -0.225344
# 1            0.026730        -0.020881 -0.020881    -0.049329 -0.124785
# 2           -0.064152        -0.020882 -0.020882    -0.091260 -0.225344
# 3           -0.035438        -0.020870 -0.020870    -0.084064 -0.225344
# 4           -0.033681        -0.020875 -0.020875    -0.093022 -0.225344
#
#        DEPI      TATA
# 0  0.271118  0.043936
# 1  0.171077 -0.007698
# 2  0.279702 -0.047727
# 3  0.364571 -0.022396
# 4  0.370698  0.699700
#
# [5 rows x 28 columns]

# %%
import seaborn as sns

sns.pairplot(features, vars=['Expenses', 'NetIncome'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=32,test_size=0.2)

# %%
from sklearn.feature_selection import VarianceThreshold

thresholder = VarianceThreshold(threshold=.5)

def variance_threshold_selector(data, threshold=0.5):
    selector = VarianceThreshold(threshold)
    selector.fit(data)
    return data[data.columns[selector.get_support(indices=True)]]

features_selected_train = variance_threshold_selector(X_train)

# %%
features_selected_train.head()
# Out:
#       AccountsReceivable         Cash  CashFlowfromOps  CurrentLiabilities  \
# 4015        1.479608e+08    5175186.0     2.783300e+04        5.273510e+05
# 2745        4.313000e+09   44000000.0     3.502000e+09        1.905600e+10
# 466         1.931436e+10  -14111000.0     7.231400e+07        2.630200e+07
# 1279        0.000000e+00          0.0     0.000000e+00        0.000000e+00
# 3109       -5.740000e+05  134267000.0     4.975100e+07        4.230000e+05
#
#       Depreciation      Expenses  IntangibleAssets  OtherCurrentAssets  \
# 4015 -2.645333e+06  4.457173e+07      0.000000e+00        1.955873e+08
# 2745  2.461000e+09  1.920100e+10      2.769000e+09        4.975800e+10
# 466   4.088400e+07  1.027008e+09      6.895000e+06        5.123605e+09
# 1279  0.000000e+00  5.304900e+07      0.000000e+00        6.350000e+05
# 3109  0.000000e+00  9.026000e+06      0.000000e+00        5.108290e+08
#
#       OtherIncome  OtherLiabilities    ...     CurrentRatio  TotalLiabilities  \
# 4015    6291867.0      8.410868e+07    ...       661.273535      8.463603e+07
# 2745          0.0      2.208500e+10    ...         2.839788      4.114100e+10
# 466   621381000.0      7.858866e+09    ...       928.592959      7.885168e+09
# 1279          0.0      0.000000e+00    ...         0.000000      0.000000e+00
# 3109   45128000.0      2.950300e+07    ...      1523.692671      2.992600e+07
#
#       DebtToEquityRatio     NetIncome  ProfitMargin  ReceivableTurnover  \
# 4015           0.428036 -4.453214e+07  -1125.003613            0.000268
# 2745           1.139135  4.775000e+09      0.199157            5.559008
# 466            0.511636 -1.023968e+09   -336.831584            0.000157
# 1279           0.000000  1.432000e+06      0.026284            0.000000
# 3109           0.020419 -9.026000e+06      0.000000           -0.000000
#
#       CollectionRatio         DSRI   TotalAssets      TATA
# 4015     1.364331e+06  3737.893492  3.542005e+08 -0.125804
# 2745     6.565920e+01     0.179888  6.471300e+10  0.019671
# 466      2.318994e+06  6353.407237  2.462441e+10 -0.044520
# 1279     0.000000e+00     0.000000  6.350000e+05  2.255118
# 3109     0.000000e+00     0.000000  6.810050e+08 -0.086309
#
# [5 rows x 25 columns]

# %%
import numpy as np
from matplotlib import pyplot as plt
sns.set(style="white")


# Compute the correlation matrix
corr = features_selected_train.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 1})

# %%
def calculate_cols_to_drop(upper):
    #to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
    shape = upper.shape
    print(shape)
    row_index = upper.index
    col_index = upper.columns
    to_drop = []
    
    for row in range(0, shape[0]):
        for col in range(0, shape[1]):
            #print(upper.iloc[row,col])
            if upper.iloc[row, col] > 0.5:
                if row_index[row] in to_drop or col_index[col] in to_drop:
                    pass
                else:
                    to_drop.append(col_index[col])
    return to_drop

# %%
corr_matrix = features_selected_train.corr().abs()

# Select upper triangle of correlation matrix (so as not to include self-correlations of 1)
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.5)]

features_selected_train.drop(columns=to_drop, inplace=True)

# %%
to_drop
# Out:
# ['CurrentLiabilities',
#  'Depreciation',
#  'Expenses',
#  'IntangibleAssets',
#  'OtherCurrentAssets',
#  'OtherLiabilities',
#  'PPE',
#  'Sales',
#  'ShareholdersEquity',
#  'TotalCurrentAssets',
#  'TotalLiabilities',
#  'NetIncome',
#  'CollectionRatio',
#  'DSRI',
#  'TotalAssets']

# %%
df = pd.read_csv('739to4000_with_tags,KL_divergence,FinRatios.csv')
df.head()
# Out:
#                    adsh  fraud       ddate  AccountsReceivable          Cash  \
# 0  0000002178-18-000009    0.0  20161231.0         106756000.0  7.875000e+07
# 1  0000002488-18-000042    0.0  20161231.0         126000000.0  2.010000e+09
# 2  0000002969-18-000014    0.0  20161231.0         -57400000.0  5.735000e+08
# 3  0000003499-18-000006    0.0  20161231.0         182581000.0  8.456940e+08
# 4  0000003545-18-000021    0.0  20161231.0           7177000.0 -6.183000e+06
#
#    CashFlowfromOps  CurrentLiabilities  Depreciation      Expenses  \
# 0        6504000.0        1.114280e+08  2.210870e+08  2.163510e+09
# 1       90000000.0        3.825000e+09  9.210000e+08  6.611000e+09
# 2      525400000.0        1.040000e+07  2.061000e+08  1.587700e+09
# 3      130820000.0        1.110608e+09  1.655981e+09  3.176400e+08
# 4      -16890000.0       -4.823000e+06  3.916000e+06  3.149000e+06
#
#    IntangibleAssets    ...     DebtToEquityRatio     NetIncome  ProfitMargin  \
# 0               0.0    ...              0.539227  6.440080e+08      0.229387
# 1       948000000.0    ...              1.464384  3.287000e+09      0.332087
# 2               0.0    ...              0.003057  2.948000e+08      0.156600
# 3               0.0    ...              0.822055  1.179930e+08      0.270854
# 4               0.0    ...              2.353128  2.942400e+07      0.903325
#
#    ReceivableTurnover  CollectionRatio      DSRI   TotalAssets       AQI  \
# 0           26.298456        13.879142  0.038025  1.139030e+09  0.000000
# 1           78.555556         4.646393  0.012730  2.617100e+10  0.036223
# 2          -32.796167       -11.129349 -0.030491  1.062500e+09  0.000000
# 3            2.385971       152.977541  0.419117  5.371457e+09  0.000000
# 4            4.538526        80.422589  0.220336  7.572000e+06  0.000000
#
#        DEPI      TATA
# 0  0.316076  0.559690
# 1  0.261277  0.122158
# 2  0.320778 -0.217035
# 3  0.367267 -0.002388
# 4  0.370623  6.116482
#
# [5 rows x 31 columns]

# %%
df = df.drop(to_drop, axis=1)
df.head()
# Out:
#                    adsh  fraud       ddate  AccountsReceivable          Cash  \
# 0  0000002178-18-000009    0.0  20161231.0         106756000.0  7.875000e+07
# 1  0000002488-18-000042    0.0  20161231.0         126000000.0  2.010000e+09
# 2  0000002969-18-000014    0.0  20161231.0         -57400000.0  5.735000e+08
# 3  0000003499-18-000006    0.0  20161231.0         182581000.0  8.456940e+08
# 4  0000003545-18-000021    0.0  20161231.0           7177000.0 -6.183000e+06
#
#    CashFlowfromOps   OtherIncome  sum_of_first_digits  total_deviation  \
# 0        6504000.0  4.700000e+06                  944         0.002008
# 1       90000000.0  1.559000e+09                 1162         0.003766
# 2      525400000.0 -7.588000e+08                  596         0.008125
# 3      130820000.0  0.000000e+00                  660         0.023214
# 4      -16890000.0  2.194500e+07                  400         0.034988
#
#    CurrentRatio  DebtToEquityRatio  ProfitMargin  ReceivableTurnover  \
# 0      5.928878           0.539227      0.229387           26.298456
# 1      5.913464           1.464384      0.332087           78.555556
# 2     60.201923           0.003057      0.156600          -32.796167
# 3      2.267681           0.822055      0.270854            2.385971
# 4     -0.191167           2.353128      0.903325            4.538526
#
#         AQI      DEPI      TATA
# 0  0.000000  0.316076  0.559690
# 1  0.036223  0.261277  0.122158
# 2  0.000000  0.320778 -0.217035
# 3  0.000000  0.367267 -0.002388
# 4  0.000000  0.370623  6.116482

# %%
len(df)
# Out:
# 5808

# %%
df = df.set_index('adsh')
len(df)
# Out:
# 5808

# %%
df.to_csv('739to4000_with_tags,KL_divergence,FinRatios,features_lessthan50%_selected.csv')
